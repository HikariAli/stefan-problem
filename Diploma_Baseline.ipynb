# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import numpy as np
import timeit
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.11/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name=None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name

    def sample(self, N):
        x = self.coords[0:1, :] + (self.coords[1:2, :] - self.coords[0:1, :]) * np.random.uniform(0, 1, size=(N, self.dim))
        y = self.func(x)
        return x, y

class DataSampler:
    # Initialize the class
    def __init__(self, X, Y, name = None):
        self.X = X
        self.Y = Y
        self.N = self.X.shape[0]

    def sample(self, batch_size):
        idx = np.random.choice(self.N, batch_size, replace=True)
        X_batch = self.X[idx, :]
        Y_batch = self.Y[idx, :]
        return X_batch, Y_batch

# %%
class Stefan1D_2P_inverse_I:
    def __init__(self, layers_u, layers_s, ics_sampler, ft_sampler, res_sampler):
        # Normalization constants
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_x, self.sigma_x = self.mu_X[0], self.sigma_X[0]
        self.mu_t, self.sigma_t = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.ics_sampler = ics_sampler
        self.ft_sampler = ft_sampler
        self.res_sampler = res_sampler

        # Initialize network weights and biases
        self.layers_u = layers_u
        self.weights_u, self.biases_u = self.initialize_NN(layers_u)

        self.layers_s = layers_s
        self.weights_s, self.biases_s = self.initialize_NN(layers_s)

        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))

        # Define placeholders and computational graph
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1)) # [0, 1]
        self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1)) # [0, 1]
        self.t_0_tf = tf.placeholder(tf.float32, shape=(None, 1)) # t = 0
        self.s_0_tf = tf.placeholder(tf.float32, shape=(None, 1)) # s(0)

        self.x1_ic_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.t1_ic_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u1_ic_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x2_ic_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.t2_ic_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u2_ic_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x1_T_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.t1_T_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u1_T_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x2_T_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.t2_T_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u2_T_tf = tf.placeholder(tf.float32, shape=(None, 1))

        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))

        # Evaluate predictions
        self.s_pred = self.net_s(self.t_u_tf)
        self.u1_pred, self.u2_pred = self.net_u1u2(self.x_r_tf, self.t_r_tf)
        self.u_pred = self.net_u(self.x_u_tf, self.t_u_tf)

        self.u1_0_pred, _ = self.net_u1u2(self.x1_ic_tf, self.t1_ic_tf)
        _, self.u2_0_pred = self.net_u1u2(self.x2_ic_tf, self.t2_ic_tf)

        self.u1_T_pred, _ = self.net_u1u2(self.x1_T_tf, self.t1_T_tf)
        _, self.u2_T_pred = self.net_u1u2(self.x2_T_tf, self.t2_T_tf)

        self.s_bc1_pred, self.s_bc2_pred = self.net_u1u2((self.net_s(self.t_r_tf) - self.mu_x) / self.sigma_x, self.t_r_tf)

        self.r_u1_pred, self.r_u2_pred = self.net_r_u1u2(self.x_r_tf, self.t_r_tf)
        self.r_Nc_pred = self.net_r_Nc(self.t_r_tf)

        # Boundary loss
        self.loss_u1_T = tf.reduce_mean(tf.square(self.u1_T_pred - self.u1_T_tf))
        self.loss_u2_T = tf.reduce_mean(tf.square(self.u2_T_pred - self.u2_T_tf))
        self.loss_u_T = self.loss_u1_T + self.loss_u2_T

        # Initial Loss
        self.loss_u1_ic = tf.reduce_mean(tf.square(self.u1_0_pred - self.u1_ic_tf))
        self.loss_u2_ic = tf.reduce_mean(tf.square(self.u2_0_pred - self.u2_ic_tf))
        self.loss_u_ics = self.loss_u1_ic + self.loss_u2_ic

        # Stefan loss
        self.loss_Sbc1 = tf.reduce_mean(tf.square(self.s_bc1_pred)) # u1(s(t),t) = u2(s(t), t) = 0
        self.loss_Sbc2 = tf.reduce_mean(tf.square(self.s_bc2_pred)) # u1(s(t),t) = u2(s(t), t) = 0
        self.loss_s_0 = tf.reduce_mean(tf.square(self.net_s(self.t1_ic_tf) - 0.5)) # s(0) = 0.5
        self.loss_SNc = tf.reduce_mean(tf.square(self.r_Nc_pred)) # Neumann Condition
        self.loss_Scs = self.loss_Sbc1 + self.loss_Sbc2 + self.loss_s_0 + self.loss_SNc

        # Residual loss
        self.loss_res_u1 = tf.reduce_mean(tf.square(self.r_u1_pred))
        self.loss_res_u2 = tf.reduce_mean(tf.square(self.r_u2_pred))
        self.loss_res = self.loss_res_u1 + self.loss_res_u2

        # Total loss
        self.loss_u = self.loss_u_ics + self.loss_u_T
        self.loss = self.loss_res + self.loss_u + self.loss_Scs

        # Define optimizer with learning rate schedule
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,
                                                       1000, 0.9, staircase=False)
        # Passing global_step to minimize() will increment it at each step.
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        # Initialize loss log arrays
        self.loss_total_log = [] 
        self.loss_u_log = []
        self.loss_Scs_log = []
        self.loss_res_log = []

        self.saver = tf.train.Saver()

        # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    # Xavier initialization
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
        return tf.Variable(tf.random_normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,
                          dtype=tf.float32)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H, weights, biases):
        num_layers = len(weights)
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

    # Forward pass for u1, u2
    def net_u1u2(self, x, t):
        u = self.forward_pass(tf.concat([x, t], 1), self.weights_u, self.biases_u)
        u1 = u[:,0:1]
        u2 = u[:,1:2]
        return u1, u2

    def net_u1u2_x(self, x, t):
        u1, u2 = self.net_u1u2(x, t)
        u1_x = tf.gradients(u1, x)[0] / self.sigma_x
        u2_x = tf.gradients(u2, x)[0] / self.sigma_x
        return u1_x, u2_x

    # Forward pass for s
    def net_s(self, t):
        s = self.forward_pass(t, self.weights_s, self.biases_s)
        return s

    # Forward pass for u
    def net_u(self, x, t):
        u1, u2 = self.net_u1u2(x, t)
        s = self.net_s(t) # consider normalization
        # demoralizing x coordinates
        x_hat = x * self.sigma_x + self.mu_x
        # consider s = x_hat
        u = tf.multiply(u1, 0.5 * (tf.sign(s - x_hat) + 1)) + tf.multiply(u2, 0.5 * (tf.sign(x_hat - s) + 1))
        return u

    # Forward pass for residual
    def net_r_u1u2(self, x, t):
        u1, u2 = self.net_u1u2(x, t)

        u1_t = tf.gradients(u1, t)[0] / self.sigma_t
        u1_x = tf.gradients(u1, x)[0] / self.sigma_x
        u1_xx = tf.gradients(u1_x, x)[0] / self.sigma_x
        r_u1 = u1_t - 2 * u1_xx

        u2_t = tf.gradients(u2, t)[0] / self.sigma_t
        u2_x = tf.gradients(u2, x)[0] / self.sigma_x
        u2_xx = tf.gradients(u2_x, x)[0] / self.sigma_x
        r_u2 = u2_t - u2_xx

        return r_u1, r_u2

    def net_r_Nc(self, t):
        s = self.net_s(t)
        s_t = tf.gradients(s, t)[0] / self.sigma_t
        # Normalizing s
        s = (s - self.mu_x) / self.sigma_x
        u1_x, u2_x = self.net_u1u2_x(s, t)
        residual = s_t - u2_x + 2 * u1_x
        return residual

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

    def train(self, nIter=10000, batch_size=128):
        start_time = timeit.default_timer()

        for it in range(nIter):
            # Fetch boundary and data mini-batches
            X1_ic_batch, u1_ic_batch = self.fetch_minibatch(self.ics_sampler[0], batch_size)
            X2_ic_batch, u2_ic_batch = self.fetch_minibatch(self.ics_sampler[1], batch_size)

            X1_T_batch, u1_T_batch = self.fetch_minibatch(self.ft_sampler[0], batch_size)
            X2_T_batch, u2_T_batch = self.fetch_minibatch(self.ft_sampler[1], batch_size)

            # Fetch residual mini-batch
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.x_u_tf: X_res_batch[:, 0:1], self.t_u_tf: X_res_batch[:, 1:2],
                      self.x1_ic_tf: X1_ic_batch[:, 0:1], self.t1_ic_tf: X1_ic_batch[:, 1:2],
                      self.u1_ic_tf: u1_ic_batch,
                      self.x2_ic_tf: X2_ic_batch[:, 0:1], self.t2_ic_tf: X2_ic_batch[:, 1:2],
                      self.u2_ic_tf: u2_ic_batch,
                      self.x1_T_tf: X1_T_batch[:, 0:1], self.t1_T_tf: X1_T_batch[:, 1:2],
                      self.u1_T_tf: u1_T_batch,
                      self.x2_T_tf: X2_T_batch[:, 0:1], self.t2_T_tf: X2_T_batch[:, 1:2],
                      self.u2_T_tf: u2_T_batch,
                      self.x_r_tf: X_res_batch[:, 0:1], self.t_r_tf: X_res_batch[:, 1:2]}

            self.sess.run(self.train_op, tf_dict)

            # Print
            if it % 10 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                loss_u_value, loss_Scs_value, loss_res_value = self.sess.run(
                    [self.loss_u, self.loss_Scs, self.loss_res], tf_dict)

                self.loss_total_log.append(loss_value)
                self.loss_u_log.append(loss_u_value)
                self.loss_Scs_log.append(loss_Scs_value)
                self.loss_res_log.append(loss_res_value)

                print('It: %d, Loss: %.3e, Loss_u: %.3e, Loss_Scs: %.3e, Loss_res: %.3e, Time: %.2f' %
                     (it, loss_value, loss_u_value, loss_Scs_value, loss_res_value, elapsed))
                start_time = timeit.default_timer()

    # Predictions for u
    def predict_u(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.x_u_tf: X_star[:, 0:1], self.t_u_tf: X_star[:, 1:2]}
        u_star = self.sess.run(self.u_pred, tf_dict)
        return u_star

    # Predictions for s
    def predict_s(self, X_star):
        X_star = (X_star - self.mu_X) / self.sigma_X
        tf_dict = {self.t_u_tf: X_star[:, 1:2]}
        s_star = self.sess.run(self.s_pred, tf_dict)
        return s_star

# %%
if __name__ == '__main__':
    # Exact u1
    def u1(x):
        # x = (x, t)
        t = x[:, 1:2]
        x = x[:, 0:1]
        u1 = 2 * (np.exp((t + 0.5 - x) / 2) - 1)
        return u1

    # Exact u2
    def u2(x):
        # x = (x, t)
        t = x[:, 1:2]
        x = x[:, 0:1]
        u2 = np.exp(t + 0.5 - x) - 1
        return u2

    # Exact s
    def s(x):
        t = x[:, 1:2]
        s = t + 0.5
        return s

    # Exact u
    def u(x):
        return np.where(x[:, 0:1] <= s(x), u1(x), u2(x))

    # condition at the final time
    def u1_T(x):
        x = x[:, 0:1]
        u1_T = 2 * (np.exp((1 + 0.5 - x) / 2) - 1)
        return u1_T

    def u2_T(x):
        x = x[:, 0:1]
        u2_T = np.exp(1 + 0.5 - x) - 1
        return u2_T

    # Initial condition for s
    def s_0(x):
        z = 0.5
        N = x.shape[0]
        return z * np.ones((N, 1))

    # Initial condition for u1
    def u1_0(x):
        x = x[:, 0:1]
        u1_0 = 2 * (np.exp((0.5 - x) / 2) - 1)
        return u1_0

    # Initial condition for u2
    def u2_0(x):
        x = x[:, 0:1]
        u2 = np.exp(0.5 - x) - 1
        return u2

    # Domain boundaries
    ics_coords = np.array([[0.0, 0.0],
                           [2.0, 0.0]])

    ft_coords = np.array([[0.0, 1.0],
                           [2.0, 1.0]])

    dom_coords = np.array([[0.0, 0.0],
                           [2.0, 1.0]])

    ic1_sampler = Sampler(2, ics_coords, lambda x: u1_0(x), name='Initial Condition')
    ic2_sampler = Sampler(2, ics_coords, lambda x: u2_0(x), name='Initial Condition')
    ics_sampler = [ic1_sampler, ic2_sampler]

    ft1_sampler = Sampler(2, ft_coords, lambda x: u1_T(x), name='Final Time Condition')
    ft2_sampler = Sampler(2, ft_coords, lambda x: u2_T(x), name='Final Time Condition')
    ft_sampler = [ft1_sampler, ft2_sampler]

    # Create residual sampler
    res_sampler = Sampler(2, dom_coords, lambda x: u(x), name='Forcing')

    # Define model
    layers_u = [2, 100, 100, 100, 2]
    layers_s = [1, 100, 100, 100, 1]
    model = Stefan1D_2P_inverse_I(layers_u, layers_s, ics_sampler, ft_sampler, res_sampler)

    # Train the model
    model.train(nIter=40000, batch_size=128)

    # Test data
    nn = 100
    x = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
    t = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
    X, T = np.meshgrid(x, t)
    X_star = np.hstack((X.flatten()[:, None], T.flatten()[:, None]))

    u_star = u(X_star)
    s_star = s(X_star)

    # Predictions
    u_pred = model.predict_u(X_star)
    s_pred = model.predict_s(X_star)

    # Errors
    error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
    error_s = np.linalg.norm(s_star - s_pred, 2) / np.linalg.norm(s_star, 2)

    print('Relative L2 error_u: {:.2e}'.format(error_u))
    print('Relative L2 error_s: {:.2e}'.format(error_s))
# Out:
# Device mapping: no known devices.
# It: 0, Loss: 3.379e+00, Loss_u: 2.772e+00, Loss_Scs: 2.843e-01, Loss_res: 3.230e-01, Time: 0.62
# It: 10, Loss: 2.791e+00, Loss_u: 1.974e+00, Loss_Scs: 6.042e-01, Loss_res: 2.125e-01, Time: 0.07
# It: 20, Loss: 2.456e+00, Loss_u: 1.799e+00, Loss_Scs: 3.486e-01, Loss_res: 3.079e-01, Time: 0.06
# It: 30, Loss: 1.843e+00, Loss_u: 1.198e+00, Loss_Scs: 2.077e-01, Loss_res: 4.379e-01, Time: 0.07
# It: 40, Loss: 1.392e+00, Loss_u: 9.529e-01, Loss_Scs: 9.228e-02, Loss_res: 3.468e-01, Time: 0.07
# It: 50, Loss: 1.478e+00, Loss_u: 9.539e-01, Loss_Scs: 1.136e-01, Loss_res: 4.101e-01, Time: 0.12
# It: 60, Loss: 1.345e+00, Loss_u: 8.927e-01, Loss_Scs: 1.057e-01, Loss_res: 3.468e-01, Time: 0.12
# It: 70, Loss: 1.232e+00, Loss_u: 8.316e-01, Loss_Scs: 7.429e-02, Loss_res: 3.257e-01, Time: 0.13
# It: 80, Loss: 1.177e+00, Loss_u: 7.944e-01, Loss_Scs: 6.422e-02, Loss_res: 3.179e-01, Time: 0.13
# It: 90, Loss: 1.179e+00, Loss_u: 7.616e-01, Loss_Scs: 5.914e-02, Loss_res: 3.586e-01, Time: 0.13
# It: 100, Loss: 1.076e+00, Loss_u: 7.740e-01, Loss_Scs: 5.040e-02, Loss_res: 2.518e-01, Time: 0.13
# It: 110, Loss: 9.814e-01, Loss_u: 6.249e-01, Loss_Scs: 5.135e-02, Loss_res: 3.051e-01, Time: 0.12
# It: 120, Loss: 9.577e-01, Loss_u: 6.511e-01, Loss_Scs: 5.159e-02, Loss_res: 2.550e-01, Time: 0.12
# It: 130, Loss: 1.006e+00, Loss_u: 6.717e-01, Loss_Scs: 4.457e-02, Loss_res: 2.899e-01, Time: 0.12
# It: 140, Loss: 8.387e-01, Loss_u: 4.899e-01, Loss_Scs: 3.823e-02, Loss_res: 3.106e-01, Time: 0.13
# It: 150, Loss: 7.547e-01, Loss_u: 4.744e-01, Loss_Scs: 2.951e-02, Loss_res: 2.508e-01, Time: 0.12
# It: 160, Loss: 6.976e-01, Loss_u: 4.201e-01, Loss_Scs: 2.665e-02, Loss_res: 2.508e-01, Time: 0.13
# It: 170, Loss: 6.644e-01, Loss_u: 3.834e-01, Loss_Scs: 2.340e-02, Loss_res: 2.576e-01, Time: 0.12
# It: 180, Loss: 4.712e-01, Loss_u: 2.935e-01, Loss_Scs: 2.156e-02, Loss_res: 1.562e-01, Time: 0.12
# It: 190, Loss: 4.113e-01, Loss_u: 2.314e-01, Loss_Scs: 1.592e-02, Loss_res: 1.640e-01, Time: 0.12
# It: 200, Loss: 3.560e-01, Loss_u: 1.914e-01, Loss_Scs: 1.154e-02, Loss_res: 1.531e-01, Time: 0.12
# It: 210, Loss: 3.157e-01, Loss_u: 1.329e-01, Loss_Scs: 1.152e-02, Loss_res: 1.712e-01, Time: 0.12
# It: 220, Loss: 2.175e-01, Loss_u: 1.049e-01, Loss_Scs: 8.619e-03, Loss_res: 1.040e-01, Time: 0.12
# It: 230, Loss: 1.573e-01, Loss_u: 8.486e-02, Loss_Scs: 6.030e-03, Loss_res: 6.636e-02, Time: 0.13
# It: 240, Loss: 1.308e-01, Loss_u: 5.505e-02, Loss_Scs: 4.850e-03, Loss_res: 7.091e-02, Time: 0.14
# It: 250, Loss: 1.343e-01, Loss_u: 5.808e-02, Loss_Scs: 3.604e-03, Loss_res: 7.261e-02, Time: 0.08
# It: 260, Loss: 7.683e-02, Loss_u: 4.224e-02, Loss_Scs: 2.675e-03, Loss_res: 3.192e-02, Time: 0.06
# It: 270, Loss: 8.441e-02, Loss_u: 4.364e-02, Loss_Scs: 2.098e-03, Loss_res: 3.867e-02, Time: 0.07
# It: 280, Loss: 6.196e-02, Loss_u: 2.596e-02, Loss_Scs: 3.279e-03, Loss_res: 3.272e-02, Time: 0.07
# It: 290, Loss: 6.083e-02, Loss_u: 2.960e-02, Loss_Scs: 2.313e-03, Loss_res: 2.892e-02, Time: 0.06
# It: 300, Loss: 5.569e-02, Loss_u: 2.812e-02, Loss_Scs: 1.778e-03, Loss_res: 2.580e-02, Time: 0.07
# It: 310, Loss: 4.519e-02, Loss_u: 2.598e-02, Loss_Scs: 1.914e-03, Loss_res: 1.729e-02, Time: 0.07
# It: 320, Loss: 4.458e-02, Loss_u: 2.151e-02, Loss_Scs: 1.927e-03, Loss_res: 2.114e-02, Time: 0.07
# It: 330, Loss: 3.720e-02, Loss_u: 2.055e-02, Loss_Scs: 1.769e-03, Loss_res: 1.488e-02, Time: 0.07
# It: 340, Loss: 3.262e-02, Loss_u: 1.541e-02, Loss_Scs: 1.540e-03, Loss_res: 1.567e-02, Time: 0.07
# It: 350, Loss: 2.725e-02, Loss_u: 1.725e-02, Loss_Scs: 1.207e-03, Loss_res: 8.794e-03, Time: 0.07
# It: 360, Loss: 2.531e-02, Loss_u: 1.449e-02, Loss_Scs: 1.671e-03, Loss_res: 9.152e-03, Time: 0.07
# It: 370, Loss: 2.674e-02, Loss_u: 1.644e-02, Loss_Scs: 1.223e-03, Loss_res: 9.082e-03, Time: 0.07
# It: 380, Loss: 2.549e-02, Loss_u: 1.374e-02, Loss_Scs: 9.804e-04, Loss_res: 1.077e-02, Time: 0.07
# It: 390, Loss: 1.908e-02, Loss_u: 1.141e-02, Loss_Scs: 9.773e-04, Loss_res: 6.692e-03, Time: 0.09
# It: 400, Loss: 1.879e-02, Loss_u: 1.070e-02, Loss_Scs: 1.036e-03, Loss_res: 7.060e-03, Time: 0.07
# It: 410, Loss: 1.988e-02, Loss_u: 1.247e-02, Loss_Scs: 9.446e-04, Loss_res: 6.461e-03, Time: 0.07
# It: 420, Loss: 1.571e-02, Loss_u: 8.824e-03, Loss_Scs: 1.089e-03, Loss_res: 5.795e-03, Time: 0.07
# It: 430, Loss: 1.497e-02, Loss_u: 9.612e-03, Loss_Scs: 9.163e-04, Loss_res: 4.440e-03, Time: 0.07
# It: 440, Loss: 1.366e-02, Loss_u: 9.333e-03, Loss_Scs: 8.479e-04, Loss_res: 3.481e-03, Time: 0.07
# It: 450, Loss: 1.409e-02, Loss_u: 7.930e-03, Loss_Scs: 8.761e-04, Loss_res: 5.289e-03, Time: 0.07
# It: 460, Loss: 1.332e-02, Loss_u: 9.237e-03, Loss_Scs: 8.123e-04, Loss_res: 3.272e-03, Time: 0.07
# It: 470, Loss: 1.170e-02, Loss_u: 7.182e-03, Loss_Scs: 7.181e-04, Loss_res: 3.799e-03, Time: 0.07
# It: 480, Loss: 1.258e-02, Loss_u: 9.085e-03, Loss_Scs: 6.955e-04, Loss_res: 2.797e-03, Time: 0.07
# It: 490, Loss: 1.036e-02, Loss_u: 5.862e-03, Loss_Scs: 6.650e-04, Loss_res: 3.828e-03, Time: 0.07
# It: 500, Loss: 9.087e-03, Loss_u: 6.443e-03, Loss_Scs: 6.660e-04, Loss_res: 1.978e-03, Time: 0.07
# It: 510, Loss: 1.025e-02, Loss_u: 6.963e-03, Loss_Scs: 5.178e-04, Loss_res: 2.773e-03, Time: 0.07
# It: 520, Loss: 1.109e-02, Loss_u: 7.195e-03, Loss_Scs: 5.077e-04, Loss_res: 3.387e-03, Time: 0.08
# It: 530, Loss: 8.899e-03, Loss_u: 6.654e-03, Loss_Scs: 4.697e-04, Loss_res: 1.775e-03, Time: 0.07
# It: 540, Loss: 8.416e-03, Loss_u: 6.154e-03, Loss_Scs: 5.843e-04, Loss_res: 1.678e-03, Time: 0.07
# It: 550, Loss: 8.110e-03, Loss_u: 6.023e-03, Loss_Scs: 5.966e-04, Loss_res: 1.490e-03, Time: 0.07
# It: 560, Loss: 7.048e-03, Loss_u: 4.415e-03, Loss_Scs: 3.771e-04, Loss_res: 2.256e-03, Time: 0.06
# It: 570, Loss: 6.270e-03, Loss_u: 4.238e-03, Loss_Scs: 4.154e-04, Loss_res: 1.617e-03, Time: 0.07
# It: 580, Loss: 6.723e-03, Loss_u: 4.304e-03, Loss_Scs: 4.579e-04, Loss_res: 1.961e-03, Time: 0.06
# It: 590, Loss: 7.205e-03, Loss_u: 4.755e-03, Loss_Scs: 5.420e-04, Loss_res: 1.908e-03, Time: 0.06
# It: 600, Loss: 6.689e-03, Loss_u: 4.168e-03, Loss_Scs: 4.318e-04, Loss_res: 2.090e-03, Time: 0.07
# It: 610, Loss: 6.439e-03, Loss_u: 4.460e-03, Loss_Scs: 3.711e-04, Loss_res: 1.608e-03, Time: 0.07
# It: 620, Loss: 5.774e-03, Loss_u: 4.338e-03, Loss_Scs: 3.064e-04, Loss_res: 1.130e-03, Time: 0.07
# It: 630, Loss: 4.738e-03, Loss_u: 3.425e-03, Loss_Scs: 3.005e-04, Loss_res: 1.013e-03, Time: 0.07
# It: 640, Loss: 6.442e-03, Loss_u: 3.676e-03, Loss_Scs: 3.204e-04, Loss_res: 2.445e-03, Time: 0.07
# It: 650, Loss: 4.937e-03, Loss_u: 3.437e-03, Loss_Scs: 3.619e-04, Loss_res: 1.137e-03, Time: 0.07
# It: 660, Loss: 5.413e-03, Loss_u: 3.719e-03, Loss_Scs: 3.003e-04, Loss_res: 1.394e-03, Time: 0.08
# It: 670, Loss: 5.434e-03, Loss_u: 3.404e-03, Loss_Scs: 3.042e-04, Loss_res: 1.726e-03, Time: 0.08
# It: 680, Loss: 5.441e-03, Loss_u: 3.847e-03, Loss_Scs: 3.122e-04, Loss_res: 1.281e-03, Time: 0.07
# It: 690, Loss: 4.510e-03, Loss_u: 2.999e-03, Loss_Scs: 2.602e-04, Loss_res: 1.250e-03, Time: 0.07
# It: 700, Loss: 5.013e-03, Loss_u: 3.598e-03, Loss_Scs: 2.494e-04, Loss_res: 1.166e-03, Time: 0.07
# It: 710, Loss: 4.418e-03, Loss_u: 3.086e-03, Loss_Scs: 2.730e-04, Loss_res: 1.060e-03, Time: 0.07
# It: 720, Loss: 3.845e-03, Loss_u: 2.636e-03, Loss_Scs: 2.315e-04, Loss_res: 9.778e-04, Time: 0.07
# It: 730, Loss: 5.076e-03, Loss_u: 3.468e-03, Loss_Scs: 2.053e-04, Loss_res: 1.403e-03, Time: 0.07
# It: 740, Loss: 4.178e-03, Loss_u: 2.869e-03, Loss_Scs: 2.906e-04, Loss_res: 1.018e-03, Time: 0.07
# It: 750, Loss: 3.810e-03, Loss_u: 2.603e-03, Loss_Scs: 2.305e-04, Loss_res: 9.773e-04, Time: 0.07
# It: 760, Loss: 4.333e-03, Loss_u: 2.013e-03, Loss_Scs: 2.199e-04, Loss_res: 2.101e-03, Time: 0.06
# It: 770, Loss: 3.461e-03, Loss_u: 2.163e-03, Loss_Scs: 1.675e-04, Loss_res: 1.131e-03, Time: 0.06
# It: 780, Loss: 3.588e-03, Loss_u: 2.494e-03, Loss_Scs: 2.719e-04, Loss_res: 8.220e-04, Time: 0.07
# It: 790, Loss: 4.017e-03, Loss_u: 2.577e-03, Loss_Scs: 2.639e-04, Loss_res: 1.177e-03, Time: 0.07
# It: 800, Loss: 3.647e-03, Loss_u: 2.498e-03, Loss_Scs: 2.670e-04, Loss_res: 8.819e-04, Time: 0.08
# It: 810, Loss: 4.981e-03, Loss_u: 2.667e-03, Loss_Scs: 2.441e-04, Loss_res: 2.070e-03, Time: 0.07
# It: 820, Loss: 3.286e-03, Loss_u: 2.416e-03, Loss_Scs: 1.818e-04, Loss_res: 6.878e-04, Time: 0.07
# It: 830, Loss: 3.002e-03, Loss_u: 1.875e-03, Loss_Scs: 1.698e-04, Loss_res: 9.576e-04, Time: 0.07
# It: 840, Loss: 3.451e-03, Loss_u: 2.052e-03, Loss_Scs: 2.481e-04, Loss_res: 1.151e-03, Time: 0.07
# It: 850, Loss: 3.089e-03, Loss_u: 2.267e-03, Loss_Scs: 1.970e-04, Loss_res: 6.257e-04, Time: 0.07
# It: 860, Loss: 2.852e-03, Loss_u: 2.154e-03, Loss_Scs: 1.830e-04, Loss_res: 5.154e-04, Time: 0.07
# It: 870, Loss: 3.519e-03, Loss_u: 1.711e-03, Loss_Scs: 1.956e-04, Loss_res: 1.612e-03, Time: 0.07
# It: 880, Loss: 2.845e-03, Loss_u: 2.057e-03, Loss_Scs: 1.604e-04, Loss_res: 6.275e-04, Time: 0.07
# It: 890, Loss: 2.580e-03, Loss_u: 1.783e-03, Loss_Scs: 1.821e-04, Loss_res: 6.149e-04, Time: 0.07
# It: 900, Loss: 2.737e-03, Loss_u: 1.935e-03, Loss_Scs: 2.167e-04, Loss_res: 5.861e-04, Time: 0.07
# It: 910, Loss: 2.950e-03, Loss_u: 2.100e-03, Loss_Scs: 1.764e-04, Loss_res: 6.728e-04, Time: 0.07
# It: 920, Loss: 2.270e-03, Loss_u: 1.453e-03, Loss_Scs: 2.184e-04, Loss_res: 5.991e-04, Time: 0.07
# It: 930, Loss: 2.648e-03, Loss_u: 1.659e-03, Loss_Scs: 1.779e-04, Loss_res: 8.110e-04, Time: 0.07
# It: 940, Loss: 3.324e-03, Loss_u: 1.741e-03, Loss_Scs: 1.257e-04, Loss_res: 1.458e-03, Time: 0.09
# It: 950, Loss: 2.456e-03, Loss_u: 1.320e-03, Loss_Scs: 1.477e-04, Loss_res: 9.876e-04, Time: 0.07
# It: 960, Loss: 2.338e-03, Loss_u: 1.564e-03, Loss_Scs: 1.627e-04, Loss_res: 6.114e-04, Time: 0.07
# It: 970, Loss: 2.504e-03, Loss_u: 1.810e-03, Loss_Scs: 1.519e-04, Loss_res: 5.417e-04, Time: 0.07
# It: 980, Loss: 2.592e-03, Loss_u: 1.801e-03, Loss_Scs: 1.977e-04, Loss_res: 5.936e-04, Time: 0.07
# It: 990, Loss: 2.523e-03, Loss_u: 1.696e-03, Loss_Scs: 1.980e-04, Loss_res: 6.298e-04, Time: 0.06
# It: 1000, Loss: 2.312e-03, Loss_u: 1.619e-03, Loss_Scs: 1.829e-04, Loss_res: 5.107e-04, Time: 0.06
# It: 1010, Loss: 2.398e-03, Loss_u: 1.667e-03, Loss_Scs: 2.100e-04, Loss_res: 5.210e-04, Time: 0.07
# It: 1020, Loss: 2.783e-03, Loss_u: 1.542e-03, Loss_Scs: 1.479e-04, Loss_res: 1.093e-03, Time: 0.07
# It: 1030, Loss: 1.783e-03, Loss_u: 1.168e-03, Loss_Scs: 1.317e-04, Loss_res: 4.830e-04, Time: 0.06
# It: 1040, Loss: 2.107e-03, Loss_u: 1.365e-03, Loss_Scs: 1.640e-04, Loss_res: 5.776e-04, Time: 0.06
# It: 1050, Loss: 2.145e-03, Loss_u: 1.617e-03, Loss_Scs: 1.036e-04, Loss_res: 4.241e-04, Time: 0.07
# It: 1060, Loss: 1.946e-03, Loss_u: 1.434e-03, Loss_Scs: 9.744e-05, Loss_res: 4.150e-04, Time: 0.07
# It: 1070, Loss: 1.863e-03, Loss_u: 1.291e-03, Loss_Scs: 1.301e-04, Loss_res: 4.419e-04, Time: 0.07
# It: 1080, Loss: 1.779e-03, Loss_u: 1.103e-03, Loss_Scs: 9.406e-05, Loss_res: 5.820e-04, Time: 0.07
# It: 1090, Loss: 1.831e-03, Loss_u: 1.294e-03, Loss_Scs: 9.412e-05, Loss_res: 4.438e-04, Time: 0.07
# It: 1100, Loss: 2.224e-03, Loss_u: 1.261e-03, Loss_Scs: 1.160e-04, Loss_res: 8.471e-04, Time: 0.07
# It: 1110, Loss: 2.067e-03, Loss_u: 1.402e-03, Loss_Scs: 9.055e-05, Loss_res: 5.741e-04, Time: 0.07
# It: 1120, Loss: 1.382e-03, Loss_u: 8.697e-04, Loss_Scs: 1.524e-04, Loss_res: 3.596e-04, Time: 0.07
# It: 1130, Loss: 1.788e-03, Loss_u: 1.280e-03, Loss_Scs: 1.295e-04, Loss_res: 3.789e-04, Time: 0.07
# It: 1140, Loss: 1.669e-03, Loss_u: 1.150e-03, Loss_Scs: 1.062e-04, Loss_res: 4.132e-04, Time: 0.07
# It: 1150, Loss: 2.075e-03, Loss_u: 1.196e-03, Loss_Scs: 1.132e-04, Loss_res: 7.658e-04, Time: 0.07
# It: 1160, Loss: 2.224e-03, Loss_u: 9.677e-04, Loss_Scs: 1.370e-04, Loss_res: 1.120e-03, Time: 0.07
# It: 1170, Loss: 1.673e-03, Loss_u: 1.029e-03, Loss_Scs: 1.368e-04, Loss_res: 5.078e-04, Time: 0.07
# It: 1180, Loss: 1.391e-03, Loss_u: 1.031e-03, Loss_Scs: 1.090e-04, Loss_res: 2.509e-04, Time: 0.07
# It: 1190, Loss: 1.645e-03, Loss_u: 9.731e-04, Loss_Scs: 1.158e-04, Loss_res: 5.565e-04, Time: 0.07
# It: 1200, Loss: 1.667e-03, Loss_u: 1.118e-03, Loss_Scs: 7.330e-05, Loss_res: 4.764e-04, Time: 0.07
# It: 1210, Loss: 1.463e-03, Loss_u: 9.930e-04, Loss_Scs: 1.561e-04, Loss_res: 3.144e-04, Time: 0.07
# It: 1220, Loss: 1.582e-03, Loss_u: 1.158e-03, Loss_Scs: 1.193e-04, Loss_res: 3.047e-04, Time: 0.08
# It: 1230, Loss: 1.397e-03, Loss_u: 9.616e-04, Loss_Scs: 1.131e-04, Loss_res: 3.227e-04, Time: 0.07
# It: 1240, Loss: 2.059e-03, Loss_u: 1.024e-03, Loss_Scs: 1.300e-04, Loss_res: 9.049e-04, Time: 0.07
# It: 1250, Loss: 1.379e-03, Loss_u: 9.559e-04, Loss_Scs: 1.165e-04, Loss_res: 3.071e-04, Time: 0.07
# It: 1260, Loss: 1.248e-03, Loss_u: 7.733e-04, Loss_Scs: 1.110e-04, Loss_res: 3.642e-04, Time: 0.07
# It: 1270, Loss: 1.440e-03, Loss_u: 1.012e-03, Loss_Scs: 1.068e-04, Loss_res: 3.209e-04, Time: 0.06
# It: 1280, Loss: 1.204e-03, Loss_u: 8.452e-04, Loss_Scs: 8.108e-05, Loss_res: 2.773e-04, Time: 0.07
# It: 1290, Loss: 1.795e-03, Loss_u: 1.176e-03, Loss_Scs: 1.339e-04, Loss_res: 4.857e-04, Time: 0.07
# It: 1300, Loss: 1.649e-03, Loss_u: 9.262e-04, Loss_Scs: 9.030e-05, Loss_res: 6.326e-04, Time: 0.06
# It: 1310, Loss: 1.155e-03, Loss_u: 8.853e-04, Loss_Scs: 7.116e-05, Loss_res: 1.987e-04, Time: 0.06
# It: 1320, Loss: 1.475e-03, Loss_u: 1.117e-03, Loss_Scs: 9.358e-05, Loss_res: 2.640e-04, Time: 0.07
# It: 1330, Loss: 1.448e-03, Loss_u: 7.592e-04, Loss_Scs: 1.600e-04, Loss_res: 5.291e-04, Time: 0.07
# It: 1340, Loss: 1.220e-03, Loss_u: 9.188e-04, Loss_Scs: 9.246e-05, Loss_res: 2.089e-04, Time: 0.07
# It: 1350, Loss: 1.324e-03, Loss_u: 8.968e-04, Loss_Scs: 6.890e-05, Loss_res: 3.583e-04, Time: 0.07
# It: 1360, Loss: 1.187e-03, Loss_u: 8.714e-04, Loss_Scs: 8.419e-05, Loss_res: 2.312e-04, Time: 0.07
# It: 1370, Loss: 1.439e-03, Loss_u: 6.746e-04, Loss_Scs: 1.272e-04, Loss_res: 6.375e-04, Time: 0.08
# It: 1380, Loss: 1.129e-03, Loss_u: 7.853e-04, Loss_Scs: 8.492e-05, Loss_res: 2.584e-04, Time: 0.07
# It: 1390, Loss: 1.429e-03, Loss_u: 8.878e-04, Loss_Scs: 1.192e-04, Loss_res: 4.216e-04, Time: 0.07
# It: 1400, Loss: 1.318e-03, Loss_u: 7.889e-04, Loss_Scs: 1.248e-04, Loss_res: 4.047e-04, Time: 0.06
# It: 1410, Loss: 1.061e-03, Loss_u: 6.972e-04, Loss_Scs: 9.772e-05, Loss_res: 2.660e-04, Time: 0.07
# It: 1420, Loss: 1.266e-03, Loss_u: 8.895e-04, Loss_Scs: 6.526e-05, Loss_res: 3.108e-04, Time: 0.07
# It: 1430, Loss: 1.261e-03, Loss_u: 7.291e-04, Loss_Scs: 7.920e-05, Loss_res: 4.527e-04, Time: 0.06
# It: 1440, Loss: 1.041e-03, Loss_u: 7.320e-04, Loss_Scs: 7.709e-05, Loss_res: 2.320e-04, Time: 0.07
# It: 1450, Loss: 9.909e-04, Loss_u: 6.677e-04, Loss_Scs: 5.795e-05, Loss_res: 2.653e-04, Time: 0.07
# It: 1460, Loss: 9.825e-04, Loss_u: 7.383e-04, Loss_Scs: 6.090e-05, Loss_res: 1.832e-04, Time: 0.07
# It: 1470, Loss: 9.140e-04, Loss_u: 5.948e-04, Loss_Scs: 6.109e-05, Loss_res: 2.580e-04, Time: 0.07
# It: 1480, Loss: 1.042e-03, Loss_u: 8.099e-04, Loss_Scs: 7.137e-05, Loss_res: 1.604e-04, Time: 0.07
# It: 1490, Loss: 1.209e-03, Loss_u: 8.182e-04, Loss_Scs: 1.107e-04, Loss_res: 2.799e-04, Time: 0.07
# It: 1500, Loss: 9.117e-04, Loss_u: 4.791e-04, Loss_Scs: 6.999e-05, Loss_res: 3.626e-04, Time: 0.07
# It: 1510, Loss: 8.297e-04, Loss_u: 5.719e-04, Loss_Scs: 8.544e-05, Loss_res: 1.723e-04, Time: 0.08
# It: 1520, Loss: 1.082e-03, Loss_u: 8.197e-04, Loss_Scs: 5.726e-05, Loss_res: 2.048e-04, Time: 0.07
# It: 1530, Loss: 9.765e-04, Loss_u: 6.669e-04, Loss_Scs: 4.612e-05, Loss_res: 2.635e-04, Time: 0.07
# It: 1540, Loss: 1.271e-03, Loss_u: 8.313e-04, Loss_Scs: 6.943e-05, Loss_res: 3.701e-04, Time: 0.06
# It: 1550, Loss: 1.184e-03, Loss_u: 6.226e-04, Loss_Scs: 6.315e-05, Loss_res: 4.984e-04, Time: 0.06
# It: 1560, Loss: 8.645e-04, Loss_u: 5.575e-04, Loss_Scs: 8.374e-05, Loss_res: 2.233e-04, Time: 0.07
# It: 1570, Loss: 1.521e-03, Loss_u: 5.444e-04, Loss_Scs: 6.006e-05, Loss_res: 9.169e-04, Time: 0.07
# It: 1580, Loss: 9.586e-04, Loss_u: 6.228e-04, Loss_Scs: 5.734e-05, Loss_res: 2.785e-04, Time: 0.07
# It: 1590, Loss: 7.673e-04, Loss_u: 5.629e-04, Loss_Scs: 5.464e-05, Loss_res: 1.497e-04, Time: 0.07
# It: 1600, Loss: 9.197e-04, Loss_u: 6.556e-04, Loss_Scs: 7.554e-05, Loss_res: 1.886e-04, Time: 0.12
# It: 1610, Loss: 1.311e-03, Loss_u: 5.988e-04, Loss_Scs: 8.765e-05, Loss_res: 6.247e-04, Time: 0.12
# It: 1620, Loss: 7.681e-04, Loss_u: 5.159e-04, Loss_Scs: 8.818e-05, Loss_res: 1.640e-04, Time: 0.12
# It: 1630, Loss: 8.617e-04, Loss_u: 6.191e-04, Loss_Scs: 9.797e-05, Loss_res: 1.447e-04, Time: 0.12
# It: 1640, Loss: 1.293e-03, Loss_u: 6.266e-04, Loss_Scs: 1.885e-04, Loss_res: 4.779e-04, Time: 0.12
# It: 1650, Loss: 8.870e-04, Loss_u: 6.704e-04, Loss_Scs: 8.317e-05, Loss_res: 1.334e-04, Time: 0.12
# It: 1660, Loss: 7.598e-04, Loss_u: 4.993e-04, Loss_Scs: 5.940e-05, Loss_res: 2.011e-04, Time: 0.12
# It: 1670, Loss: 1.336e-03, Loss_u: 5.097e-04, Loss_Scs: 1.013e-04, Loss_res: 7.255e-04, Time: 0.13
# It: 1680, Loss: 1.032e-03, Loss_u: 5.069e-04, Loss_Scs: 8.249e-05, Loss_res: 4.426e-04, Time: 0.12
# It: 1690, Loss: 7.700e-04, Loss_u: 5.305e-04, Loss_Scs: 7.889e-05, Loss_res: 1.606e-04, Time: 0.13
# It: 1700, Loss: 8.719e-04, Loss_u: 6.194e-04, Loss_Scs: 7.965e-05, Loss_res: 1.728e-04, Time: 0.12
# It: 1710, Loss: 8.367e-04, Loss_u: 5.879e-04, Loss_Scs: 4.789e-05, Loss_res: 2.009e-04, Time: 0.13
# It: 1720, Loss: 6.800e-04, Loss_u: 4.861e-04, Loss_Scs: 5.746e-05, Loss_res: 1.365e-04, Time: 0.12
# It: 1730, Loss: 8.673e-04, Loss_u: 5.848e-04, Loss_Scs: 1.117e-04, Loss_res: 1.708e-04, Time: 0.13
# It: 1740, Loss: 6.423e-04, Loss_u: 4.073e-04, Loss_Scs: 5.350e-05, Loss_res: 1.814e-04, Time: 0.12
# It: 1750, Loss: 7.512e-04, Loss_u: 5.478e-04, Loss_Scs: 5.586e-05, Loss_res: 1.475e-04, Time: 0.12
# It: 1760, Loss: 6.187e-04, Loss_u: 3.946e-04, Loss_Scs: 8.593e-05, Loss_res: 1.382e-04, Time: 0.12
# It: 1770, Loss: 7.468e-04, Loss_u: 5.502e-04, Loss_Scs: 5.519e-05, Loss_res: 1.414e-04, Time: 0.12
# It: 1780, Loss: 6.780e-04, Loss_u: 4.265e-04, Loss_Scs: 5.154e-05, Loss_res: 2.000e-04, Time: 0.12
# It: 1790, Loss: 5.970e-04, Loss_u: 4.481e-04, Loss_Scs: 5.507e-05, Loss_res: 9.387e-05, Time: 0.14
# It: 1800, Loss: 7.219e-04, Loss_u: 4.501e-04, Loss_Scs: 9.864e-05, Loss_res: 1.732e-04, Time: 0.08
# It: 1810, Loss: 7.407e-04, Loss_u: 4.400e-04, Loss_Scs: 9.955e-05, Loss_res: 2.011e-04, Time: 0.07
# It: 1820, Loss: 5.974e-04, Loss_u: 3.789e-04, Loss_Scs: 7.763e-05, Loss_res: 1.408e-04, Time: 0.07
# It: 1830, Loss: 7.343e-04, Loss_u: 4.772e-04, Loss_Scs: 7.461e-05, Loss_res: 1.824e-04, Time: 0.07
# It: 1840, Loss: 7.767e-04, Loss_u: 4.575e-04, Loss_Scs: 7.427e-05, Loss_res: 2.450e-04, Time: 0.07
# It: 1850, Loss: 4.825e-04, Loss_u: 2.957e-04, Loss_Scs: 6.444e-05, Loss_res: 1.223e-04, Time: 0.07
# It: 1860, Loss: 6.299e-04, Loss_u: 4.099e-04, Loss_Scs: 4.674e-05, Loss_res: 1.733e-04, Time: 0.07
# It: 1870, Loss: 7.185e-04, Loss_u: 4.337e-04, Loss_Scs: 8.772e-05, Loss_res: 1.971e-04, Time: 0.07
# It: 1880, Loss: 6.153e-04, Loss_u: 3.307e-04, Loss_Scs: 9.729e-05, Loss_res: 1.873e-04, Time: 0.07
# It: 1890, Loss: 5.868e-04, Loss_u: 3.898e-04, Loss_Scs: 4.885e-05, Loss_res: 1.481e-04, Time: 0.07
# It: 1900, Loss: 6.288e-04, Loss_u: 3.699e-04, Loss_Scs: 7.570e-05, Loss_res: 1.832e-04, Time: 0.07
# It: 1910, Loss: 7.201e-04, Loss_u: 3.982e-04, Loss_Scs: 5.026e-05, Loss_res: 2.716e-04, Time: 0.07
# It: 1920, Loss: 5.804e-04, Loss_u: 4.284e-04, Loss_Scs: 5.004e-05, Loss_res: 1.019e-04, Time: 0.07
# It: 1930, Loss: 4.982e-04, Loss_u: 3.210e-04, Loss_Scs: 4.032e-05, Loss_res: 1.369e-04, Time: 0.08
# It: 1940, Loss: 5.954e-04, Loss_u: 4.214e-04, Loss_Scs: 7.084e-05, Loss_res: 1.032e-04, Time: 0.07
# It: 1950, Loss: 5.176e-04, Loss_u: 3.557e-04, Loss_Scs: 5.970e-05, Loss_res: 1.022e-04, Time: 0.07
# It: 1960, Loss: 5.222e-04, Loss_u: 3.527e-04, Loss_Scs: 6.076e-05, Loss_res: 1.087e-04, Time: 0.07
# It: 1970, Loss: 5.138e-04, Loss_u: 3.524e-04, Loss_Scs: 5.270e-05, Loss_res: 1.086e-04, Time: 0.07
# It: 1980, Loss: 6.632e-04, Loss_u: 3.664e-04, Loss_Scs: 1.686e-04, Loss_res: 1.282e-04, Time: 0.07
# It: 1990, Loss: 1.018e-03, Loss_u: 3.548e-04, Loss_Scs: 7.139e-05, Loss_res: 5.918e-04, Time: 0.07
# It: 2000, Loss: 5.676e-04, Loss_u: 3.810e-04, Loss_Scs: 6.912e-05, Loss_res: 1.175e-04, Time: 0.07
# It: 2010, Loss: 5.819e-04, Loss_u: 3.378e-04, Loss_Scs: 1.625e-04, Loss_res: 8.149e-05, Time: 0.06
# It: 2020, Loss: 6.905e-04, Loss_u: 4.223e-04, Loss_Scs: 1.792e-04, Loss_res: 8.901e-05, Time: 0.06
# It: 2030, Loss: 6.509e-04, Loss_u: 3.979e-04, Loss_Scs: 1.194e-04, Loss_res: 1.336e-04, Time: 0.06
# It: 2040, Loss: 5.907e-04, Loss_u: 3.520e-04, Loss_Scs: 1.252e-04, Loss_res: 1.136e-04, Time: 0.06
# It: 2050, Loss: 6.835e-04, Loss_u: 4.429e-04, Loss_Scs: 1.356e-04, Loss_res: 1.050e-04, Time: 0.07
# It: 2060, Loss: 7.882e-04, Loss_u: 4.000e-04, Loss_Scs: 1.598e-04, Loss_res: 2.284e-04, Time: 0.07
# It: 2070, Loss: 5.111e-04, Loss_u: 3.709e-04, Loss_Scs: 4.977e-05, Loss_res: 9.043e-05, Time: 0.08
# It: 2080, Loss: 4.888e-04, Loss_u: 3.569e-04, Loss_Scs: 3.756e-05, Loss_res: 9.434e-05, Time: 0.07
# It: 2090, Loss: 4.498e-04, Loss_u: 3.160e-04, Loss_Scs: 4.040e-05, Loss_res: 9.341e-05, Time: 0.07
# It: 2100, Loss: 4.990e-04, Loss_u: 2.244e-04, Loss_Scs: 1.412e-04, Loss_res: 1.334e-04, Time: 0.07
# It: 2110, Loss: 5.122e-04, Loss_u: 3.309e-04, Loss_Scs: 8.687e-05, Loss_res: 9.437e-05, Time: 0.07
# It: 2120, Loss: 7.584e-04, Loss_u: 2.960e-04, Loss_Scs: 1.761e-04, Loss_res: 2.864e-04, Time: 0.07
# It: 2130, Loss: 4.900e-04, Loss_u: 2.450e-04, Loss_Scs: 1.362e-04, Loss_res: 1.088e-04, Time: 0.07
# It: 2140, Loss: 7.253e-04, Loss_u: 3.989e-04, Loss_Scs: 1.831e-04, Loss_res: 1.433e-04, Time: 0.07
# It: 2150, Loss: 5.684e-04, Loss_u: 3.319e-04, Loss_Scs: 1.081e-04, Loss_res: 1.284e-04, Time: 0.07
# It: 2160, Loss: 7.962e-04, Loss_u: 3.988e-04, Loss_Scs: 5.934e-05, Loss_res: 3.381e-04, Time: 0.07
# It: 2170, Loss: 5.702e-04, Loss_u: 3.890e-04, Loss_Scs: 6.181e-05, Loss_res: 1.193e-04, Time: 0.06
# It: 2180, Loss: 4.962e-04, Loss_u: 2.783e-04, Loss_Scs: 8.990e-05, Loss_res: 1.280e-04, Time: 0.07
# It: 2190, Loss: 4.598e-04, Loss_u: 2.626e-04, Loss_Scs: 8.498e-05, Loss_res: 1.122e-04, Time: 0.07
# It: 2200, Loss: 6.387e-04, Loss_u: 3.744e-04, Loss_Scs: 1.198e-04, Loss_res: 1.445e-04, Time: 0.07
# It: 2210, Loss: 4.859e-04, Loss_u: 2.986e-04, Loss_Scs: 7.210e-05, Loss_res: 1.152e-04, Time: 0.08
# It: 2220, Loss: 8.163e-04, Loss_u: 3.065e-04, Loss_Scs: 3.208e-04, Loss_res: 1.891e-04, Time: 0.08
# It: 2230, Loss: 6.357e-04, Loss_u: 2.693e-04, Loss_Scs: 2.435e-04, Loss_res: 1.229e-04, Time: 0.07
# It: 2240, Loss: 6.909e-04, Loss_u: 2.525e-04, Loss_Scs: 4.262e-05, Loss_res: 3.958e-04, Time: 0.07
# It: 2250, Loss: 4.836e-04, Loss_u: 2.457e-04, Loss_Scs: 5.350e-05, Loss_res: 1.844e-04, Time: 0.07
# It: 2260, Loss: 8.486e-04, Loss_u: 3.110e-04, Loss_Scs: 4.574e-04, Loss_res: 8.016e-05, Time: 0.07
# It: 2270, Loss: 4.323e-04, Loss_u: 2.161e-04, Loss_Scs: 3.436e-05, Loss_res: 1.818e-04, Time: 0.07
# It: 2280, Loss: 6.178e-04, Loss_u: 2.808e-04, Loss_Scs: 1.243e-04, Loss_res: 2.126e-04, Time: 0.07
# It: 2290, Loss: 4.709e-04, Loss_u: 2.544e-04, Loss_Scs: 3.203e-05, Loss_res: 1.845e-04, Time: 0.06
# It: 2300, Loss: 1.506e-03, Loss_u: 4.082e-04, Loss_Scs: 8.240e-04, Loss_res: 2.732e-04, Time: 0.07
# It: 2310, Loss: 4.017e-04, Loss_u: 2.500e-04, Loss_Scs: 6.242e-05, Loss_res: 8.929e-05, Time: 0.07
# It: 2320, Loss: 5.878e-04, Loss_u: 2.403e-04, Loss_Scs: 1.856e-04, Loss_res: 1.619e-04, Time: 0.06
# It: 2330, Loss: 1.374e-03, Loss_u: 2.519e-04, Loss_Scs: 6.607e-04, Loss_res: 4.611e-04, Time: 0.07
# It: 2340, Loss: 4.189e-04, Loss_u: 1.803e-04, Loss_Scs: 4.917e-05, Loss_res: 1.895e-04, Time: 0.07
# It: 2350, Loss: 1.154e-03, Loss_u: 2.838e-04, Loss_Scs: 7.691e-04, Loss_res: 1.009e-04, Time: 0.08
# It: 2360, Loss: 3.574e-04, Loss_u: 2.545e-04, Loss_Scs: 3.021e-05, Loss_res: 7.270e-05, Time: 0.07
# It: 2370, Loss: 5.138e-04, Loss_u: 2.503e-04, Loss_Scs: 8.646e-05, Loss_res: 1.770e-04, Time: 0.07
# It: 2380, Loss: 3.601e-04, Loss_u: 1.999e-04, Loss_Scs: 6.842e-05, Loss_res: 9.177e-05, Time: 0.06
# It: 2390, Loss: 1.224e-03, Loss_u: 2.325e-04, Loss_Scs: 9.069e-04, Loss_res: 8.470e-05, Time: 0.07
# It: 2400, Loss: 8.240e-04, Loss_u: 2.197e-04, Loss_Scs: 5.389e-04, Loss_res: 6.543e-05, Time: 0.07
# It: 2410, Loss: 3.537e-04, Loss_u: 1.798e-04, Loss_Scs: 8.245e-05, Loss_res: 9.142e-05, Time: 0.06
# It: 2420, Loss: 6.337e-04, Loss_u: 2.324e-04, Loss_Scs: 2.704e-04, Loss_res: 1.309e-04, Time: 0.07
# It: 2430, Loss: 8.377e-04, Loss_u: 2.276e-04, Loss_Scs: 5.181e-04, Loss_res: 9.202e-05, Time: 0.07
# It: 2440, Loss: 3.456e-04, Loss_u: 1.943e-04, Loss_Scs: 6.678e-05, Loss_res: 8.455e-05, Time: 0.07
# It: 2450, Loss: 3.445e-04, Loss_u: 2.367e-04, Loss_Scs: 3.232e-05, Loss_res: 7.547e-05, Time: 0.07
# It: 2460, Loss: 4.108e-04, Loss_u: 2.138e-04, Loss_Scs: 8.958e-05, Loss_res: 1.075e-04, Time: 0.08
# It: 2470, Loss: 9.228e-04, Loss_u: 2.535e-04, Loss_Scs: 2.080e-04, Loss_res: 4.613e-04, Time: 0.07
# It: 2480, Loss: 5.111e-03, Loss_u: 4.300e-04, Loss_Scs: 4.558e-03, Loss_res: 1.228e-04, Time: 0.07
# It: 2490, Loss: 2.025e-03, Loss_u: 2.501e-04, Loss_Scs: 1.608e-03, Loss_res: 1.666e-04, Time: 0.08
# It: 2500, Loss: 3.895e-04, Loss_u: 1.482e-04, Loss_Scs: 1.717e-04, Loss_res: 6.955e-05, Time: 0.07
# It: 2510, Loss: 3.109e-04, Loss_u: 2.100e-04, Loss_Scs: 3.798e-05, Loss_res: 6.297e-05, Time: 0.07
# It: 2520, Loss: 4.990e-04, Loss_u: 2.114e-04, Loss_Scs: 8.647e-05, Loss_res: 2.011e-04, Time: 0.07
# It: 2530, Loss: 3.985e-04, Loss_u: 2.877e-04, Loss_Scs: 2.149e-05, Loss_res: 8.934e-05, Time: 0.07
# It: 2540, Loss: 3.286e-04, Loss_u: 2.009e-04, Loss_Scs: 5.459e-05, Loss_res: 7.306e-05, Time: 0.07
# It: 2550, Loss: 5.402e-04, Loss_u: 2.009e-04, Loss_Scs: 7.793e-05, Loss_res: 2.613e-04, Time: 0.06
# It: 2560, Loss: 5.262e-04, Loss_u: 2.274e-04, Loss_Scs: 1.819e-04, Loss_res: 1.169e-04, Time: 0.06
# It: 2570, Loss: 6.899e-04, Loss_u: 2.113e-04, Loss_Scs: 3.590e-04, Loss_res: 1.196e-04, Time: 0.07
# It: 2580, Loss: 5.992e-04, Loss_u: 1.813e-04, Loss_Scs: 2.006e-04, Loss_res: 2.173e-04, Time: 0.07
# It: 2590, Loss: 6.710e-04, Loss_u: 1.389e-04, Loss_Scs: 4.191e-04, Loss_res: 1.130e-04, Time: 0.07
# It: 2600, Loss: 5.379e-04, Loss_u: 2.493e-04, Loss_Scs: 2.206e-04, Loss_res: 6.795e-05, Time: 0.07
# It: 2610, Loss: 4.395e-04, Loss_u: 1.675e-04, Loss_Scs: 1.905e-04, Loss_res: 8.150e-05, Time: 0.07
# It: 2620, Loss: 7.475e-04, Loss_u: 1.860e-04, Loss_Scs: 4.761e-04, Loss_res: 8.534e-05, Time: 0.07
# It: 2630, Loss: 3.910e-04, Loss_u: 1.731e-04, Loss_Scs: 1.733e-04, Loss_res: 4.467e-05, Time: 0.08
# It: 2640, Loss: 5.316e-04, Loss_u: 1.520e-04, Loss_Scs: 2.990e-04, Loss_res: 8.051e-05, Time: 0.07
# It: 2650, Loss: 2.850e-04, Loss_u: 1.347e-04, Loss_Scs: 3.446e-05, Loss_res: 1.158e-04, Time: 0.07
# It: 2660, Loss: 7.761e-04, Loss_u: 1.687e-04, Loss_Scs: 4.354e-04, Loss_res: 1.720e-04, Time: 0.07
# It: 2670, Loss: 3.209e-04, Loss_u: 1.627e-04, Loss_Scs: 6.171e-05, Loss_res: 9.651e-05, Time: 0.07
# It: 2680, Loss: 4.580e-04, Loss_u: 1.723e-04, Loss_Scs: 1.936e-04, Loss_res: 9.213e-05, Time: 0.07
# It: 2690, Loss: 3.525e-03, Loss_u: 2.538e-04, Loss_Scs: 3.191e-03, Loss_res: 7.989e-05, Time: 0.07
# It: 2700, Loss: 1.453e-03, Loss_u: 2.004e-04, Loss_Scs: 1.114e-03, Loss_res: 1.392e-04, Time: 0.06
# It: 2710, Loss: 3.259e-04, Loss_u: 2.040e-04, Loss_Scs: 2.337e-05, Loss_res: 9.847e-05, Time: 0.06
# It: 2720, Loss: 3.104e-04, Loss_u: 1.630e-04, Loss_Scs: 6.208e-05, Loss_res: 8.536e-05, Time: 0.06
# It: 2730, Loss: 3.731e-04, Loss_u: 1.797e-04, Loss_Scs: 7.092e-05, Loss_res: 1.224e-04, Time: 0.07
# It: 2740, Loss: 3.172e-04, Loss_u: 1.734e-04, Loss_Scs: 6.294e-05, Loss_res: 8.080e-05, Time: 0.07
# It: 2750, Loss: 1.897e-03, Loss_u: 1.129e-04, Loss_Scs: 1.400e-03, Loss_res: 3.835e-04, Time: 0.07
# It: 2760, Loss: 3.848e-04, Loss_u: 1.692e-04, Loss_Scs: 1.357e-04, Loss_res: 7.984e-05, Time: 0.07
# It: 2770, Loss: 6.177e-04, Loss_u: 1.215e-04, Loss_Scs: 2.134e-04, Loss_res: 2.828e-04, Time: 0.06
# It: 2780, Loss: 6.017e-04, Loss_u: 2.098e-04, Loss_Scs: 2.269e-04, Loss_res: 1.650e-04, Time: 0.09
# It: 2790, Loss: 3.922e-04, Loss_u: 1.320e-04, Loss_Scs: 1.778e-04, Loss_res: 8.242e-05, Time: 0.07
# It: 2800, Loss: 4.580e-04, Loss_u: 1.489e-04, Loss_Scs: 2.403e-04, Loss_res: 6.884e-05, Time: 0.07
# It: 2810, Loss: 3.617e-04, Loss_u: 1.294e-04, Loss_Scs: 1.631e-04, Loss_res: 6.910e-05, Time: 0.07
# It: 2820, Loss: 5.538e-04, Loss_u: 1.803e-04, Loss_Scs: 3.007e-04, Loss_res: 7.282e-05, Time: 0.06
# It: 2830, Loss: 6.038e-04, Loss_u: 1.507e-04, Loss_Scs: 1.624e-04, Loss_res: 2.906e-04, Time: 0.06
# It: 2840, Loss: 1.693e-03, Loss_u: 1.788e-04, Loss_Scs: 1.422e-03, Loss_res: 9.242e-05, Time: 0.07
# It: 2850, Loss: 2.514e-04, Loss_u: 9.396e-05, Loss_Scs: 3.491e-05, Loss_res: 1.226e-04, Time: 0.07
# It: 2860, Loss: 8.195e-04, Loss_u: 1.576e-04, Loss_Scs: 5.680e-04, Loss_res: 9.389e-05, Time: 0.07
# It: 2870, Loss: 1.236e-03, Loss_u: 1.919e-04, Loss_Scs: 9.878e-04, Loss_res: 5.661e-05, Time: 0.07
# It: 2880, Loss: 2.510e-04, Loss_u: 1.099e-04, Loss_Scs: 6.829e-05, Loss_res: 7.276e-05, Time: 0.07
# It: 2890, Loss: 3.886e-04, Loss_u: 1.458e-04, Loss_Scs: 1.636e-04, Loss_res: 7.928e-05, Time: 0.06
# It: 2900, Loss: 2.576e-04, Loss_u: 1.036e-04, Loss_Scs: 6.144e-05, Loss_res: 9.253e-05, Time: 0.07
# It: 2910, Loss: 4.663e-04, Loss_u: 1.219e-04, Loss_Scs: 2.493e-04, Loss_res: 9.509e-05, Time: 0.07
# It: 2920, Loss: 2.533e-04, Loss_u: 1.521e-04, Loss_Scs: 3.620e-05, Loss_res: 6.499e-05, Time: 0.09
# It: 2930, Loss: 1.668e-03, Loss_u: 2.016e-04, Loss_Scs: 1.375e-03, Loss_res: 9.184e-05, Time: 0.07
# It: 2940, Loss: 2.299e-04, Loss_u: 1.038e-04, Loss_Scs: 3.300e-05, Loss_res: 9.303e-05, Time: 0.07
# It: 2950, Loss: 2.378e-04, Loss_u: 1.251e-04, Loss_Scs: 5.038e-05, Loss_res: 6.237e-05, Time: 0.06
# It: 2960, Loss: 3.887e-04, Loss_u: 1.439e-04, Loss_Scs: 3.503e-05, Loss_res: 2.098e-04, Time: 0.07
# It: 2970, Loss: 1.305e-03, Loss_u: 2.014e-04, Loss_Scs: 7.363e-04, Loss_res: 3.669e-04, Time: 0.06
# It: 2980, Loss: 5.881e-04, Loss_u: 1.430e-04, Loss_Scs: 2.812e-04, Loss_res: 1.639e-04, Time: 0.07
# It: 2990, Loss: 4.298e-04, Loss_u: 1.466e-04, Loss_Scs: 2.144e-04, Loss_res: 6.887e-05, Time: 0.07
# It: 3000, Loss: 3.933e-04, Loss_u: 1.612e-04, Loss_Scs: 1.523e-04, Loss_res: 7.979e-05, Time: 0.06
# It: 3010, Loss: 2.342e-04, Loss_u: 1.361e-04, Loss_Scs: 2.525e-05, Loss_res: 7.285e-05, Time: 0.06
# It: 3020, Loss: 3.329e-04, Loss_u: 1.389e-04, Loss_Scs: 1.312e-04, Loss_res: 6.276e-05, Time: 0.07
# It: 3030, Loss: 1.195e-03, Loss_u: 1.499e-04, Loss_Scs: 9.585e-04, Loss_res: 8.700e-05, Time: 0.07
# It: 3040, Loss: 2.037e-04, Loss_u: 1.008e-04, Loss_Scs: 4.111e-05, Loss_res: 6.181e-05, Time: 0.06
# It: 3050, Loss: 1.910e-04, Loss_u: 6.702e-05, Loss_Scs: 4.730e-05, Loss_res: 7.663e-05, Time: 0.07
# It: 3060, Loss: 6.814e-04, Loss_u: 1.192e-04, Loss_Scs: 2.663e-04, Loss_res: 2.959e-04, Time: 0.09
# It: 3070, Loss: 6.848e-04, Loss_u: 1.204e-04, Loss_Scs: 4.451e-04, Loss_res: 1.192e-04, Time: 0.07
# It: 3080, Loss: 3.852e-04, Loss_u: 1.003e-04, Loss_Scs: 2.184e-04, Loss_res: 6.653e-05, Time: 0.07
# It: 3090, Loss: 5.095e-04, Loss_u: 1.173e-04, Loss_Scs: 3.308e-04, Loss_res: 6.147e-05, Time: 0.07
# It: 3100, Loss: 2.426e-03, Loss_u: 2.361e-04, Loss_Scs: 1.934e-03, Loss_res: 2.561e-04, Time: 0.07
# It: 3110, Loss: 2.023e-04, Loss_u: 1.037e-04, Loss_Scs: 3.362e-05, Loss_res: 6.498e-05, Time: 0.07
# It: 3120, Loss: 2.110e-04, Loss_u: 9.589e-05, Loss_Scs: 2.289e-05, Loss_res: 9.223e-05, Time: 0.07
# It: 3130, Loss: 1.635e-04, Loss_u: 8.379e-05, Loss_Scs: 3.043e-05, Loss_res: 4.927e-05, Time: 0.07
# It: 3140, Loss: 1.719e-04, Loss_u: 7.421e-05, Loss_Scs: 2.709e-05, Loss_res: 7.058e-05, Time: 0.07
# It: 3150, Loss: 2.208e-04, Loss_u: 8.245e-05, Loss_Scs: 9.412e-05, Loss_res: 4.426e-05, Time: 0.07
# It: 3160, Loss: 2.951e-04, Loss_u: 8.642e-05, Loss_Scs: 1.091e-04, Loss_res: 9.958e-05, Time: 0.11
# It: 3170, Loss: 1.636e-04, Loss_u: 9.924e-05, Loss_Scs: 2.278e-05, Loss_res: 4.157e-05, Time: 0.13
# It: 3180, Loss: 5.251e-04, Loss_u: 8.787e-05, Loss_Scs: 3.207e-04, Loss_res: 1.165e-04, Time: 0.14
# It: 3190, Loss: 6.475e-04, Loss_u: 1.075e-04, Loss_Scs: 3.895e-04, Loss_res: 1.506e-04, Time: 0.13
# It: 3200, Loss: 5.449e-04, Loss_u: 9.587e-05, Loss_Scs: 3.503e-04, Loss_res: 9.873e-05, Time: 0.12
# It: 3210, Loss: 2.309e-04, Loss_u: 1.140e-04, Loss_Scs: 4.953e-05, Loss_res: 6.736e-05, Time: 0.13
# It: 3220, Loss: 3.618e-04, Loss_u: 6.385e-05, Loss_Scs: 1.800e-04, Loss_res: 1.180e-04, Time: 0.12
# It: 3230, Loss: 2.356e-04, Loss_u: 1.003e-04, Loss_Scs: 6.579e-05, Loss_res: 6.951e-05, Time: 0.12
# It: 3240, Loss: 3.062e-04, Loss_u: 8.134e-05, Loss_Scs: 1.444e-04, Loss_res: 8.044e-05, Time: 0.11
# It: 3250, Loss: 1.123e-03, Loss_u: 1.569e-04, Loss_Scs: 7.775e-04, Loss_res: 1.891e-04, Time: 0.12
# It: 3260, Loss: 3.141e-04, Loss_u: 1.034e-04, Loss_Scs: 1.549e-04, Loss_res: 5.580e-05, Time: 0.12
# It: 3270, Loss: 1.023e-03, Loss_u: 1.081e-04, Loss_Scs: 8.349e-04, Loss_res: 8.041e-05, Time: 0.12
# It: 3280, Loss: 2.503e-04, Loss_u: 7.106e-05, Loss_Scs: 9.889e-05, Loss_res: 8.039e-05, Time: 0.12
# It: 3290, Loss: 3.294e-04, Loss_u: 7.480e-05, Loss_Scs: 9.853e-05, Loss_res: 1.561e-04, Time: 0.12
# It: 3300, Loss: 7.806e-04, Loss_u: 1.409e-04, Loss_Scs: 4.787e-04, Loss_res: 1.610e-04, Time: 0.12
# It: 3310, Loss: 4.373e-04, Loss_u: 7.675e-05, Loss_Scs: 2.460e-04, Loss_res: 1.145e-04, Time: 0.12
# It: 3320, Loss: 1.506e-04, Loss_u: 7.381e-05, Loss_Scs: 2.274e-05, Loss_res: 5.410e-05, Time: 0.12
# It: 3330, Loss: 3.439e-04, Loss_u: 1.152e-04, Loss_Scs: 1.492e-04, Loss_res: 7.951e-05, Time: 0.13
# It: 3340, Loss: 3.295e-04, Loss_u: 1.101e-04, Loss_Scs: 1.720e-04, Loss_res: 4.735e-05, Time: 0.12
# It: 3350, Loss: 1.151e-03, Loss_u: 9.167e-05, Loss_Scs: 9.146e-04, Loss_res: 1.446e-04, Time: 0.13
# It: 3360, Loss: 1.960e-04, Loss_u: 7.010e-05, Loss_Scs: 2.364e-05, Loss_res: 1.023e-04, Time: 0.10
# It: 3370, Loss: 3.633e-04, Loss_u: 7.769e-05, Loss_Scs: 1.559e-04, Loss_res: 1.296e-04, Time: 0.07
# It: 3380, Loss: 2.308e-04, Loss_u: 6.030e-05, Loss_Scs: 1.084e-04, Loss_res: 6.212e-05, Time: 0.07
# It: 3390, Loss: 2.532e-04, Loss_u: 5.800e-05, Loss_Scs: 1.032e-04, Loss_res: 9.199e-05, Time: 0.07
# It: 3400, Loss: 1.688e-04, Loss_u: 6.666e-05, Loss_Scs: 2.438e-05, Loss_res: 7.774e-05, Time: 0.07
# It: 3410, Loss: 3.039e-04, Loss_u: 8.748e-05, Loss_Scs: 2.377e-05, Loss_res: 1.926e-04, Time: 0.07
# It: 3420, Loss: 2.653e-04, Loss_u: 1.312e-04, Loss_Scs: 2.504e-05, Loss_res: 1.091e-04, Time: 0.07
# It: 3430, Loss: 5.021e-04, Loss_u: 7.196e-05, Loss_Scs: 1.369e-04, Loss_res: 2.933e-04, Time: 0.07
# It: 3440, Loss: 3.984e-03, Loss_u: 2.396e-04, Loss_Scs: 3.444e-03, Loss_res: 3.007e-04, Time: 0.07
# It: 3450, Loss: 7.175e-04, Loss_u: 1.238e-04, Loss_Scs: 5.216e-04, Loss_res: 7.203e-05, Time: 0.07
# It: 3460, Loss: 6.343e-04, Loss_u: 1.347e-04, Loss_Scs: 3.599e-04, Loss_res: 1.398e-04, Time: 0.07
# It: 3470, Loss: 1.296e-04, Loss_u: 5.182e-05, Loss_Scs: 2.991e-05, Loss_res: 4.788e-05, Time: 0.07
# It: 3480, Loss: 2.459e-04, Loss_u: 7.220e-05, Loss_Scs: 1.043e-04, Loss_res: 6.945e-05, Time: 0.08
# It: 3490, Loss: 1.270e-04, Loss_u: 6.547e-05, Loss_Scs: 2.015e-05, Loss_res: 4.139e-05, Time: 0.06
# It: 3500, Loss: 1.364e-04, Loss_u: 4.448e-05, Loss_Scs: 1.373e-05, Loss_res: 7.820e-05, Time: 0.07
# It: 3510, Loss: 5.550e-04, Loss_u: 7.364e-05, Loss_Scs: 2.777e-04, Loss_res: 2.037e-04, Time: 0.07
# It: 3520, Loss: 2.185e-04, Loss_u: 8.689e-05, Loss_Scs: 6.822e-05, Loss_res: 6.342e-05, Time: 0.06
# It: 3530, Loss: 1.216e-04, Loss_u: 5.575e-05, Loss_Scs: 1.686e-05, Loss_res: 4.903e-05, Time: 0.07
# It: 3540, Loss: 3.705e-04, Loss_u: 6.800e-05, Loss_Scs: 2.625e-04, Loss_res: 3.994e-05, Time: 0.07
# It: 3550, Loss: 1.852e-03, Loss_u: 1.272e-04, Loss_Scs: 1.582e-03, Loss_res: 1.426e-04, Time: 0.07
# It: 3560, Loss: 1.969e-04, Loss_u: 7.580e-05, Loss_Scs: 3.345e-05, Loss_res: 8.764e-05, Time: 0.07
# It: 3570, Loss: 2.958e-04, Loss_u: 5.310e-05, Loss_Scs: 2.020e-04, Loss_res: 4.067e-05, Time: 0.07
# It: 3580, Loss: 2.254e-04, Loss_u: 6.915e-05, Loss_Scs: 2.106e-05, Loss_res: 1.352e-04, Time: 0.07
# It: 3590, Loss: 2.004e-04, Loss_u: 5.197e-05, Loss_Scs: 9.508e-05, Loss_res: 5.337e-05, Time: 0.07
# It: 3600, Loss: 2.708e-04, Loss_u: 6.230e-05, Loss_Scs: 1.226e-04, Loss_res: 8.590e-05, Time: 0.07
# It: 3610, Loss: 1.264e-04, Loss_u: 5.800e-05, Loss_Scs: 1.703e-05, Loss_res: 5.139e-05, Time: 0.07
# It: 3620, Loss: 1.384e-04, Loss_u: 3.765e-05, Loss_Scs: 1.467e-05, Loss_res: 8.607e-05, Time: 0.09
# It: 3630, Loss: 7.085e-04, Loss_u: 9.838e-05, Loss_Scs: 3.986e-04, Loss_res: 2.116e-04, Time: 0.07
# It: 3640, Loss: 1.883e-04, Loss_u: 6.284e-05, Loss_Scs: 8.349e-05, Loss_res: 4.194e-05, Time: 0.07
# It: 3650, Loss: 5.744e-04, Loss_u: 8.720e-05, Loss_Scs: 4.228e-04, Loss_res: 6.449e-05, Time: 0.07
# It: 3660, Loss: 1.104e-03, Loss_u: 6.705e-05, Loss_Scs: 9.859e-04, Loss_res: 5.074e-05, Time: 0.07
# It: 3670, Loss: 3.721e-04, Loss_u: 1.318e-04, Loss_Scs: 2.633e-05, Loss_res: 2.139e-04, Time: 0.07
# It: 3680, Loss: 4.245e-04, Loss_u: 6.199e-05, Loss_Scs: 2.665e-04, Loss_res: 9.595e-05, Time: 0.07
# It: 3690, Loss: 4.922e-04, Loss_u: 6.972e-05, Loss_Scs: 3.097e-04, Loss_res: 1.128e-04, Time: 0.07
# It: 3700, Loss: 6.272e-04, Loss_u: 1.080e-04, Loss_Scs: 4.549e-04, Loss_res: 6.436e-05, Time: 0.07
# It: 3710, Loss: 7.531e-04, Loss_u: 1.048e-04, Loss_Scs: 5.817e-04, Loss_res: 6.655e-05, Time: 0.07
# It: 3720, Loss: 1.320e-04, Loss_u: 5.711e-05, Loss_Scs: 3.069e-05, Loss_res: 4.422e-05, Time: 0.07
# It: 3730, Loss: 9.750e-05, Loss_u: 4.550e-05, Loss_Scs: 1.620e-05, Loss_res: 3.581e-05, Time: 0.07
# It: 3740, Loss: 1.409e-04, Loss_u: 5.476e-05, Loss_Scs: 4.366e-05, Loss_res: 4.249e-05, Time: 0.07
# It: 3750, Loss: 1.943e-04, Loss_u: 7.144e-05, Loss_Scs: 3.356e-05, Loss_res: 8.930e-05, Time: 0.07
# It: 3760, Loss: 3.806e-04, Loss_u: 6.263e-05, Loss_Scs: 2.525e-04, Loss_res: 6.551e-05, Time: 0.08
# It: 3770, Loss: 3.707e-04, Loss_u: 5.654e-05, Loss_Scs: 2.692e-04, Loss_res: 4.497e-05, Time: 0.07
# It: 3780, Loss: 9.294e-04, Loss_u: 8.379e-05, Loss_Scs: 7.995e-04, Loss_res: 4.609e-05, Time: 0.07
# It: 3790, Loss: 1.134e-04, Loss_u: 4.607e-05, Loss_Scs: 2.814e-05, Loss_res: 3.915e-05, Time: 0.07
# It: 3800, Loss: 3.355e-04, Loss_u: 6.312e-05, Loss_Scs: 1.875e-04, Loss_res: 8.486e-05, Time: 0.07
# It: 3810, Loss: 4.274e-04, Loss_u: 4.147e-05, Loss_Scs: 1.504e-04, Loss_res: 2.355e-04, Time: 0.07
# It: 3820, Loss: 3.029e-03, Loss_u: 1.351e-04, Loss_Scs: 2.805e-03, Loss_res: 8.906e-05, Time: 0.10
# It: 3830, Loss: 5.676e-04, Loss_u: 6.966e-05, Loss_Scs: 4.574e-04, Loss_res: 4.057e-05, Time: 0.07
# It: 3840, Loss: 7.096e-04, Loss_u: 1.039e-04, Loss_Scs: 5.511e-04, Loss_res: 5.462e-05, Time: 0.07
# It: 3850, Loss: 6.079e-04, Loss_u: 9.161e-05, Loss_Scs: 3.972e-04, Loss_res: 1.191e-04, Time: 0.07
# It: 3860, Loss: 2.116e-04, Loss_u: 5.782e-05, Loss_Scs: 1.199e-04, Loss_res: 3.391e-05, Time: 0.07
# It: 3870, Loss: 2.486e-04, Loss_u: 2.848e-05, Loss_Scs: 1.707e-04, Loss_res: 4.942e-05, Time: 0.07
# It: 3880, Loss: 1.651e-04, Loss_u: 4.428e-05, Loss_Scs: 8.734e-05, Loss_res: 3.347e-05, Time: 0.07
# It: 3890, Loss: 1.274e-04, Loss_u: 3.914e-05, Loss_Scs: 9.965e-06, Loss_res: 7.828e-05, Time: 0.07
# It: 3900, Loss: 2.286e-04, Loss_u: 7.287e-05, Loss_Scs: 7.391e-05, Loss_res: 8.187e-05, Time: 0.08
# It: 3910, Loss: 2.313e-04, Loss_u: 8.403e-05, Loss_Scs: 6.041e-05, Loss_res: 8.687e-05, Time: 0.07
# It: 3920, Loss: 2.706e-04, Loss_u: 8.073e-05, Loss_Scs: 1.987e-05, Loss_res: 1.700e-04, Time: 0.07
# It: 3930, Loss: 4.155e-04, Loss_u: 1.205e-04, Loss_Scs: 2.042e-04, Loss_res: 9.083e-05, Time: 0.07
# It: 3940, Loss: 1.055e-03, Loss_u: 8.746e-05, Loss_Scs: 9.178e-04, Loss_res: 4.971e-05, Time: 0.07
# It: 3950, Loss: 6.709e-04, Loss_u: 7.212e-05, Loss_Scs: 5.331e-04, Loss_res: 6.570e-05, Time: 0.07
# It: 3960, Loss: 3.370e-04, Loss_u: 6.455e-05, Loss_Scs: 2.267e-04, Loss_res: 4.569e-05, Time: 0.07
# It: 3970, Loss: 1.599e-04, Loss_u: 7.276e-05, Loss_Scs: 5.080e-05, Loss_res: 3.629e-05, Time: 0.07
# It: 3980, Loss: 9.242e-04, Loss_u: 1.133e-04, Loss_Scs: 7.839e-04, Loss_res: 2.698e-05, Time: 0.07
# It: 3990, Loss: 4.707e-04, Loss_u: 7.210e-05, Loss_Scs: 3.243e-04, Loss_res: 7.425e-05, Time: 0.07
# It: 4000, Loss: 1.087e-04, Loss_u: 4.258e-05, Loss_Scs: 2.678e-05, Loss_res: 3.938e-05, Time: 0.07
# It: 4010, Loss: 1.722e-04, Loss_u: 4.690e-05, Loss_Scs: 6.268e-05, Loss_res: 6.265e-05, Time: 0.07
# It: 4020, Loss: 1.545e-04, Loss_u: 3.719e-05, Loss_Scs: 6.404e-05, Loss_res: 5.325e-05, Time: 0.07
# It: 4030, Loss: 2.930e-04, Loss_u: 4.994e-05, Loss_Scs: 1.197e-04, Loss_res: 1.233e-04, Time: 0.07
# It: 4040, Loss: 4.975e-04, Loss_u: 8.823e-05, Loss_Scs: 2.503e-04, Loss_res: 1.590e-04, Time: 0.08
# It: 4050, Loss: 2.011e-04, Loss_u: 2.528e-05, Loss_Scs: 1.188e-04, Loss_res: 5.705e-05, Time: 0.06
# It: 4060, Loss: 1.067e-04, Loss_u: 4.494e-05, Loss_Scs: 1.475e-05, Loss_res: 4.700e-05, Time: 0.06
# It: 4070, Loss: 1.477e-03, Loss_u: 8.451e-05, Loss_Scs: 1.350e-03, Loss_res: 4.191e-05, Time: 0.07
# It: 4080, Loss: 2.439e-04, Loss_u: 6.775e-05, Loss_Scs: 1.188e-04, Loss_res: 5.736e-05, Time: 0.07
# It: 4090, Loss: 2.775e-04, Loss_u: 5.443e-05, Loss_Scs: 1.677e-04, Loss_res: 5.537e-05, Time: 0.07
# It: 4100, Loss: 3.393e-04, Loss_u: 5.282e-05, Loss_Scs: 2.290e-04, Loss_res: 5.739e-05, Time: 0.07
# It: 4110, Loss: 1.300e-04, Loss_u: 5.531e-05, Loss_Scs: 2.140e-05, Loss_res: 5.333e-05, Time: 0.07
# It: 4120, Loss: 7.621e-04, Loss_u: 4.198e-05, Loss_Scs: 6.774e-04, Loss_res: 4.271e-05, Time: 0.07
# It: 4130, Loss: 9.637e-05, Loss_u: 3.092e-05, Loss_Scs: 3.243e-05, Loss_res: 3.302e-05, Time: 0.07
# It: 4140, Loss: 2.056e-04, Loss_u: 3.642e-05, Loss_Scs: 1.368e-04, Loss_res: 3.233e-05, Time: 0.07
# It: 4150, Loss: 2.573e-04, Loss_u: 2.776e-05, Loss_Scs: 2.057e-04, Loss_res: 2.391e-05, Time: 0.07
# It: 4160, Loss: 2.606e-04, Loss_u: 4.368e-05, Loss_Scs: 1.884e-04, Loss_res: 2.845e-05, Time: 0.07
# It: 4170, Loss: 2.517e-04, Loss_u: 3.530e-05, Loss_Scs: 7.698e-05, Loss_res: 1.394e-04, Time: 0.06
# It: 4180, Loss: 1.421e-03, Loss_u: 1.132e-04, Loss_Scs: 1.165e-03, Loss_res: 1.429e-04, Time: 0.08
# It: 4190, Loss: 1.398e-04, Loss_u: 5.860e-05, Loss_Scs: 2.595e-05, Loss_res: 5.522e-05, Time: 0.07
# It: 4200, Loss: 2.835e-04, Loss_u: 1.048e-04, Loss_Scs: 4.759e-05, Loss_res: 1.311e-04, Time: 0.07
# It: 4210, Loss: 2.876e-04, Loss_u: 8.334e-05, Loss_Scs: 1.412e-04, Loss_res: 6.304e-05, Time: 0.07
# It: 4220, Loss: 1.540e-03, Loss_u: 1.884e-04, Loss_Scs: 1.293e-03, Loss_res: 5.813e-05, Time: 0.07
# It: 4230, Loss: 2.678e-04, Loss_u: 5.728e-05, Loss_Scs: 1.329e-04, Loss_res: 7.766e-05, Time: 0.06
# It: 4240, Loss: 1.503e-04, Loss_u: 3.644e-05, Loss_Scs: 7.271e-05, Loss_res: 4.116e-05, Time: 0.06
# It: 4250, Loss: 1.219e-04, Loss_u: 5.506e-05, Loss_Scs: 4.085e-05, Loss_res: 2.600e-05, Time: 0.07
# It: 4260, Loss: 9.809e-05, Loss_u: 3.777e-05, Loss_Scs: 2.630e-05, Loss_res: 3.402e-05, Time: 0.07
# It: 4270, Loss: 1.953e-04, Loss_u: 3.724e-05, Loss_Scs: 1.142e-04, Loss_res: 4.385e-05, Time: 0.07
# It: 4280, Loss: 1.186e-04, Loss_u: 2.680e-05, Loss_Scs: 6.622e-05, Loss_res: 2.560e-05, Time: 0.07
# It: 4290, Loss: 3.993e-04, Loss_u: 3.590e-05, Loss_Scs: 3.363e-04, Loss_res: 2.711e-05, Time: 0.07
# It: 4300, Loss: 7.533e-04, Loss_u: 5.873e-05, Loss_Scs: 6.562e-04, Loss_res: 3.833e-05, Time: 0.06
# It: 4310, Loss: 6.736e-04, Loss_u: 1.519e-04, Loss_Scs: 3.943e-04, Loss_res: 1.274e-04, Time: 0.07
# It: 4320, Loss: 1.772e-04, Loss_u: 7.860e-05, Loss_Scs: 3.534e-05, Loss_res: 6.323e-05, Time: 0.08
# It: 4330, Loss: 8.824e-05, Loss_u: 2.526e-05, Loss_Scs: 1.357e-05, Loss_res: 4.941e-05, Time: 0.06
# It: 4340, Loss: 4.766e-04, Loss_u: 4.779e-05, Loss_Scs: 3.863e-04, Loss_res: 4.249e-05, Time: 0.07
# It: 4350, Loss: 2.103e-04, Loss_u: 3.813e-05, Loss_Scs: 1.139e-04, Loss_res: 5.832e-05, Time: 0.07
# It: 4360, Loss: 2.477e-04, Loss_u: 3.442e-05, Loss_Scs: 1.835e-04, Loss_res: 2.975e-05, Time: 0.07
# It: 4370, Loss: 9.245e-05, Loss_u: 4.070e-05, Loss_Scs: 2.409e-05, Loss_res: 2.766e-05, Time: 0.07
# It: 4380, Loss: 1.102e-03, Loss_u: 9.336e-05, Loss_Scs: 8.375e-04, Loss_res: 1.714e-04, Time: 0.07
# It: 4390, Loss: 7.628e-04, Loss_u: 6.430e-05, Loss_Scs: 6.387e-04, Loss_res: 5.982e-05, Time: 0.07
# It: 4400, Loss: 3.339e-04, Loss_u: 3.974e-05, Loss_Scs: 2.653e-04, Loss_res: 2.887e-05, Time: 0.07
# It: 4410, Loss: 1.049e-04, Loss_u: 2.541e-05, Loss_Scs: 4.792e-05, Loss_res: 3.152e-05, Time: 0.07
# It: 4420, Loss: 7.362e-05, Loss_u: 2.428e-05, Loss_Scs: 2.765e-05, Loss_res: 2.170e-05, Time: 0.07
# It: 4430, Loss: 6.968e-05, Loss_u: 2.733e-05, Loss_Scs: 9.651e-06, Loss_res: 3.270e-05, Time: 0.07
# It: 4440, Loss: 4.669e-04, Loss_u: 4.663e-05, Loss_Scs: 3.893e-04, Loss_res: 3.102e-05, Time: 0.07
# It: 4450, Loss: 3.944e-04, Loss_u: 7.922e-05, Loss_Scs: 2.013e-04, Loss_res: 1.139e-04, Time: 0.07
# It: 4460, Loss: 1.042e-03, Loss_u: 1.985e-04, Loss_Scs: 6.499e-04, Loss_res: 1.937e-04, Time: 0.08
# It: 4470, Loss: 5.485e-04, Loss_u: 1.075e-04, Loss_Scs: 3.086e-04, Loss_res: 1.325e-04, Time: 0.06
# It: 4480, Loss: 1.987e-04, Loss_u: 6.060e-05, Loss_Scs: 6.097e-05, Loss_res: 7.715e-05, Time: 0.06
# It: 4490, Loss: 5.820e-04, Loss_u: 4.125e-05, Loss_Scs: 4.847e-04, Loss_res: 5.611e-05, Time: 0.07
# It: 4500, Loss: 3.846e-04, Loss_u: 3.826e-05, Loss_Scs: 3.102e-04, Loss_res: 3.616e-05, Time: 0.07
# It: 4510, Loss: 2.144e-04, Loss_u: 5.505e-05, Loss_Scs: 1.979e-05, Loss_res: 1.396e-04, Time: 0.07
# It: 4520, Loss: 3.862e-04, Loss_u: 6.304e-05, Loss_Scs: 2.303e-04, Loss_res: 9.288e-05, Time: 0.07
# It: 4530, Loss: 1.166e-04, Loss_u: 4.715e-05, Loss_Scs: 2.414e-05, Loss_res: 4.527e-05, Time: 0.07
# It: 4540, Loss: 5.963e-04, Loss_u: 4.809e-05, Loss_Scs: 4.971e-04, Loss_res: 5.101e-05, Time: 0.07
# It: 4550, Loss: 2.438e-04, Loss_u: 4.309e-05, Loss_Scs: 1.679e-04, Loss_res: 3.279e-05, Time: 0.07
# It: 4560, Loss: 2.249e-04, Loss_u: 4.056e-05, Loss_Scs: 1.491e-04, Loss_res: 3.528e-05, Time: 0.07
# It: 4570, Loss: 1.190e-04, Loss_u: 3.823e-05, Loss_Scs: 4.934e-05, Loss_res: 3.145e-05, Time: 0.07
# It: 4580, Loss: 9.545e-04, Loss_u: 1.190e-04, Loss_Scs: 6.192e-04, Loss_res: 2.162e-04, Time: 0.07
# It: 4590, Loss: 1.430e-04, Loss_u: 3.605e-05, Loss_Scs: 8.531e-05, Loss_res: 2.165e-05, Time: 0.07
# It: 4600, Loss: 9.850e-04, Loss_u: 6.361e-05, Loss_Scs: 8.605e-04, Loss_res: 6.084e-05, Time: 0.09
# It: 4610, Loss: 1.377e-04, Loss_u: 5.071e-05, Loss_Scs: 3.567e-05, Loss_res: 5.135e-05, Time: 0.07
# It: 4620, Loss: 1.818e-04, Loss_u: 2.334e-05, Loss_Scs: 1.355e-04, Loss_res: 2.290e-05, Time: 0.07
# It: 4630, Loss: 9.082e-05, Loss_u: 2.998e-05, Loss_Scs: 3.898e-05, Loss_res: 2.186e-05, Time: 0.07
# It: 4640, Loss: 1.011e-04, Loss_u: 2.829e-05, Loss_Scs: 4.663e-05, Loss_res: 2.620e-05, Time: 0.07
# It: 4650, Loss: 1.423e-04, Loss_u: 2.932e-05, Loss_Scs: 8.477e-05, Loss_res: 2.820e-05, Time: 0.06
# It: 4660, Loss: 1.118e-03, Loss_u: 6.934e-05, Loss_Scs: 1.019e-03, Loss_res: 2.985e-05, Time: 0.07
# It: 4670, Loss: 1.021e-04, Loss_u: 1.779e-05, Loss_Scs: 6.071e-05, Loss_res: 2.356e-05, Time: 0.07
# It: 4680, Loss: 3.401e-04, Loss_u: 4.518e-05, Loss_Scs: 2.436e-04, Loss_res: 5.129e-05, Time: 0.07
# It: 4690, Loss: 2.181e-04, Loss_u: 2.067e-05, Loss_Scs: 1.584e-04, Loss_res: 3.911e-05, Time: 0.07
# It: 4700, Loss: 2.539e-04, Loss_u: 3.431e-05, Loss_Scs: 8.627e-05, Loss_res: 1.333e-04, Time: 0.07
# It: 4710, Loss: 2.113e-04, Loss_u: 2.710e-05, Loss_Scs: 1.587e-04, Loss_res: 2.555e-05, Time: 0.09
# It: 4720, Loss: 1.278e-03, Loss_u: 4.310e-05, Loss_Scs: 1.152e-03, Loss_res: 8.271e-05, Time: 0.12
# It: 4730, Loss: 1.698e-04, Loss_u: 4.050e-05, Loss_Scs: 8.043e-05, Loss_res: 4.891e-05, Time: 0.13
# It: 4740, Loss: 2.267e-04, Loss_u: 2.442e-05, Loss_Scs: 1.564e-04, Loss_res: 4.590e-05, Time: 0.13
# It: 4750, Loss: 1.380e-04, Loss_u: 2.321e-05, Loss_Scs: 8.266e-05, Loss_res: 3.209e-05, Time: 0.12
# It: 4760, Loss: 6.543e-05, Loss_u: 1.979e-05, Loss_Scs: 1.502e-05, Loss_res: 3.062e-05, Time: 0.13
# It: 4770, Loss: 9.338e-05, Loss_u: 2.462e-05, Loss_Scs: 5.056e-05, Loss_res: 1.820e-05, Time: 0.12
# It: 4780, Loss: 6.824e-05, Loss_u: 2.955e-05, Loss_Scs: 1.244e-05, Loss_res: 2.625e-05, Time: 0.12
# It: 4790, Loss: 7.177e-04, Loss_u: 5.062e-05, Loss_Scs: 5.950e-04, Loss_res: 7.203e-05, Time: 0.12
# It: 4800, Loss: 6.793e-04, Loss_u: 3.697e-05, Loss_Scs: 6.114e-04, Loss_res: 3.097e-05, Time: 0.12
# It: 4810, Loss: 1.271e-04, Loss_u: 4.031e-05, Loss_Scs: 1.857e-05, Loss_res: 6.824e-05, Time: 0.13
# It: 4820, Loss: 3.854e-04, Loss_u: 4.886e-05, Loss_Scs: 1.440e-04, Loss_res: 1.926e-04, Time: 0.13
# It: 4830, Loss: 3.566e-04, Loss_u: 4.472e-05, Loss_Scs: 2.932e-04, Loss_res: 1.870e-05, Time: 0.12
# It: 4840, Loss: 1.880e-04, Loss_u: 4.113e-05, Loss_Scs: 3.838e-05, Loss_res: 1.085e-04, Time: 0.12
# ...
# It: 38410, Loss: 1.466e-06, Loss_u: 5.377e-07, Loss_Scs: 8.063e-08, Loss_res: 8.481e-07, Time: 0.07
# It: 38420, Loss: 1.488e-06, Loss_u: 5.332e-07, Loss_Scs: 1.022e-07, Loss_res: 8.524e-07, Time: 0.07
# It: 38430, Loss: 1.453e-06, Loss_u: 5.359e-07, Loss_Scs: 9.900e-08, Loss_res: 8.180e-07, Time: 0.07
# It: 38440, Loss: 2.037e-06, Loss_u: 5.168e-07, Loss_Scs: 1.259e-07, Loss_res: 1.394e-06, Time: 0.08
# It: 38450, Loss: 1.974e-06, Loss_u: 4.735e-07, Loss_Scs: 1.876e-07, Loss_res: 1.313e-06, Time: 0.07
# It: 38460, Loss: 1.654e-06, Loss_u: 5.243e-07, Loss_Scs: 1.233e-07, Loss_res: 1.007e-06, Time: 0.07
# It: 38470, Loss: 1.694e-06, Loss_u: 5.950e-07, Loss_Scs: 1.166e-07, Loss_res: 9.827e-07, Time: 0.07
# It: 38480, Loss: 1.620e-06, Loss_u: 5.305e-07, Loss_Scs: 3.068e-07, Loss_res: 7.830e-07, Time: 0.07
# It: 38490, Loss: 1.759e-06, Loss_u: 5.857e-07, Loss_Scs: 8.124e-08, Loss_res: 1.092e-06, Time: 0.07
# It: 38500, Loss: 1.581e-06, Loss_u: 4.811e-07, Loss_Scs: 2.083e-07, Loss_res: 8.919e-07, Time: 0.07
# It: 38510, Loss: 1.289e-06, Loss_u: 4.685e-07, Loss_Scs: 1.467e-07, Loss_res: 6.735e-07, Time: 0.07
# It: 38520, Loss: 2.084e-06, Loss_u: 5.116e-07, Loss_Scs: 3.299e-07, Loss_res: 1.243e-06, Time: 0.07
# It: 38530, Loss: 4.527e-06, Loss_u: 6.002e-07, Loss_Scs: 1.689e-07, Loss_res: 3.758e-06, Time: 0.07
# It: 38540, Loss: 2.193e-06, Loss_u: 4.159e-07, Loss_Scs: 1.745e-07, Loss_res: 1.603e-06, Time: 0.08
# It: 38550, Loss: 2.036e-06, Loss_u: 6.555e-07, Loss_Scs: 3.798e-07, Loss_res: 1.001e-06, Time: 0.07
# It: 38560, Loss: 1.640e-06, Loss_u: 4.549e-07, Loss_Scs: 4.100e-08, Loss_res: 1.144e-06, Time: 0.07
# It: 38570, Loss: 1.468e-06, Loss_u: 4.401e-07, Loss_Scs: 1.541e-07, Loss_res: 8.735e-07, Time: 0.07
# It: 38580, Loss: 2.060e-06, Loss_u: 6.158e-07, Loss_Scs: 2.708e-07, Loss_res: 1.173e-06, Time: 0.08
# It: 38590, Loss: 6.088e-06, Loss_u: 6.734e-07, Loss_Scs: 6.541e-07, Loss_res: 4.760e-06, Time: 0.07
# It: 38600, Loss: 1.592e-06, Loss_u: 5.766e-07, Loss_Scs: 4.502e-08, Loss_res: 9.703e-07, Time: 0.07
# It: 38610, Loss: 2.277e-06, Loss_u: 7.724e-07, Loss_Scs: 8.307e-08, Loss_res: 1.422e-06, Time: 0.07
# It: 38620, Loss: 1.971e-06, Loss_u: 5.708e-07, Loss_Scs: 4.435e-07, Loss_res: 9.562e-07, Time: 0.06
# It: 38630, Loss: 1.313e-06, Loss_u: 4.492e-07, Loss_Scs: 4.957e-08, Loss_res: 8.142e-07, Time: 0.07
# It: 38640, Loss: 1.628e-06, Loss_u: 4.071e-07, Loss_Scs: 1.996e-07, Loss_res: 1.022e-06, Time: 0.07
# It: 38650, Loss: 1.268e-06, Loss_u: 4.621e-07, Loss_Scs: 7.715e-08, Loss_res: 7.289e-07, Time: 0.07
# It: 38660, Loss: 1.500e-06, Loss_u: 5.445e-07, Loss_Scs: 7.408e-08, Loss_res: 8.809e-07, Time: 0.07
# It: 38670, Loss: 2.067e-06, Loss_u: 6.561e-07, Loss_Scs: 3.540e-07, Loss_res: 1.057e-06, Time: 0.07
# It: 38680, Loss: 1.482e-06, Loss_u: 4.392e-07, Loss_Scs: 1.296e-07, Loss_res: 9.135e-07, Time: 0.07
# It: 38690, Loss: 3.209e-06, Loss_u: 5.905e-07, Loss_Scs: 5.802e-07, Loss_res: 2.038e-06, Time: 0.07
# It: 38700, Loss: 1.617e-06, Loss_u: 4.365e-07, Loss_Scs: 1.963e-07, Loss_res: 9.846e-07, Time: 0.07
# It: 38710, Loss: 1.276e-06, Loss_u: 4.673e-07, Loss_Scs: 6.400e-08, Loss_res: 7.448e-07, Time: 0.07
# It: 38720, Loss: 1.690e-06, Loss_u: 4.690e-07, Loss_Scs: 4.770e-08, Loss_res: 1.173e-06, Time: 0.08
# It: 38730, Loss: 3.360e-06, Loss_u: 4.502e-07, Loss_Scs: 7.901e-08, Loss_res: 2.831e-06, Time: 0.07
# It: 38740, Loss: 2.443e-06, Loss_u: 4.926e-07, Loss_Scs: 1.097e-06, Loss_res: 8.533e-07, Time: 0.06
# It: 38750, Loss: 1.763e-06, Loss_u: 4.910e-07, Loss_Scs: 3.838e-07, Loss_res: 8.884e-07, Time: 0.07
# It: 38760, Loss: 1.764e-06, Loss_u: 4.458e-07, Loss_Scs: 1.813e-07, Loss_res: 1.137e-06, Time: 0.07
# It: 38770, Loss: 1.565e-06, Loss_u: 4.248e-07, Loss_Scs: 5.781e-08, Loss_res: 1.083e-06, Time: 0.07
# It: 38780, Loss: 1.175e-06, Loss_u: 4.217e-07, Loss_Scs: 4.068e-08, Loss_res: 7.125e-07, Time: 0.07
# It: 38790, Loss: 1.570e-06, Loss_u: 5.079e-07, Loss_Scs: 2.483e-07, Loss_res: 8.134e-07, Time: 0.07
# It: 38800, Loss: 5.264e-06, Loss_u: 6.107e-07, Loss_Scs: 5.457e-08, Loss_res: 4.599e-06, Time: 0.07
# It: 38810, Loss: 2.271e-06, Loss_u: 4.706e-07, Loss_Scs: 1.867e-07, Loss_res: 1.613e-06, Time: 0.07
# It: 38820, Loss: 2.162e-06, Loss_u: 4.401e-07, Loss_Scs: 1.017e-07, Loss_res: 1.621e-06, Time: 0.07
# It: 38830, Loss: 2.265e-06, Loss_u: 6.901e-07, Loss_Scs: 5.999e-07, Loss_res: 9.748e-07, Time: 0.07
# It: 38840, Loss: 1.537e-06, Loss_u: 5.216e-07, Loss_Scs: 5.680e-08, Loss_res: 9.581e-07, Time: 0.07
# It: 38850, Loss: 1.705e-06, Loss_u: 5.645e-07, Loss_Scs: 1.945e-07, Loss_res: 9.461e-07, Time: 0.09
# It: 38860, Loss: 1.532e-06, Loss_u: 5.113e-07, Loss_Scs: 2.701e-07, Loss_res: 7.502e-07, Time: 0.07
# It: 38870, Loss: 1.693e-06, Loss_u: 5.770e-07, Loss_Scs: 3.724e-07, Loss_res: 7.432e-07, Time: 0.07
# It: 38880, Loss: 1.735e-06, Loss_u: 4.765e-07, Loss_Scs: 4.136e-07, Loss_res: 8.448e-07, Time: 0.07
# It: 38890, Loss: 1.385e-06, Loss_u: 4.116e-07, Loss_Scs: 4.406e-08, Loss_res: 9.289e-07, Time: 0.07
# It: 38900, Loss: 1.205e-06, Loss_u: 4.447e-07, Loss_Scs: 2.928e-08, Loss_res: 7.309e-07, Time: 0.08
# It: 38910, Loss: 1.795e-06, Loss_u: 5.565e-07, Loss_Scs: 7.649e-08, Loss_res: 1.162e-06, Time: 0.07
# It: 38920, Loss: 1.660e-06, Loss_u: 5.135e-07, Loss_Scs: 1.034e-07, Loss_res: 1.043e-06, Time: 0.07
# It: 38930, Loss: 1.485e-06, Loss_u: 5.015e-07, Loss_Scs: 2.079e-07, Loss_res: 7.753e-07, Time: 0.07
# It: 38940, Loss: 2.207e-06, Loss_u: 5.357e-07, Loss_Scs: 6.152e-07, Loss_res: 1.056e-06, Time: 0.07
# It: 38950, Loss: 1.416e-06, Loss_u: 5.088e-07, Loss_Scs: 6.445e-08, Loss_res: 8.426e-07, Time: 0.07
# It: 38960, Loss: 1.402e-06, Loss_u: 6.040e-07, Loss_Scs: 4.752e-08, Loss_res: 7.503e-07, Time: 0.07
# It: 38970, Loss: 2.017e-06, Loss_u: 5.236e-07, Loss_Scs: 3.308e-07, Loss_res: 1.163e-06, Time: 0.06
# It: 38980, Loss: 1.875e-06, Loss_u: 5.620e-07, Loss_Scs: 1.236e-07, Loss_res: 1.189e-06, Time: 0.07
# It: 38990, Loss: 3.080e-06, Loss_u: 8.801e-07, Loss_Scs: 3.155e-07, Loss_res: 1.884e-06, Time: 0.09
# It: 39000, Loss: 1.960e-06, Loss_u: 6.281e-07, Loss_Scs: 1.651e-07, Loss_res: 1.167e-06, Time: 0.07
# It: 39010, Loss: 2.482e-06, Loss_u: 4.342e-07, Loss_Scs: 1.097e-07, Loss_res: 1.938e-06, Time: 0.07
# It: 39020, Loss: 3.538e-06, Loss_u: 6.529e-07, Loss_Scs: 9.070e-08, Loss_res: 2.795e-06, Time: 0.07
# It: 39030, Loss: 1.528e-06, Loss_u: 5.061e-07, Loss_Scs: 1.321e-07, Loss_res: 8.894e-07, Time: 0.07
# It: 39040, Loss: 1.810e-06, Loss_u: 5.202e-07, Loss_Scs: 3.553e-07, Loss_res: 9.349e-07, Time: 0.07
# It: 39050, Loss: 1.972e-06, Loss_u: 6.519e-07, Loss_Scs: 2.866e-07, Loss_res: 1.034e-06, Time: 0.08
# It: 39060, Loss: 1.676e-06, Loss_u: 4.400e-07, Loss_Scs: 1.269e-07, Loss_res: 1.109e-06, Time: 0.07
# It: 39070, Loss: 1.993e-06, Loss_u: 5.782e-07, Loss_Scs: 2.320e-07, Loss_res: 1.183e-06, Time: 0.07
# It: 39080, Loss: 1.603e-06, Loss_u: 5.595e-07, Loss_Scs: 2.347e-07, Loss_res: 8.088e-07, Time: 0.07
# It: 39090, Loss: 1.607e-06, Loss_u: 5.664e-07, Loss_Scs: 1.443e-07, Loss_res: 8.964e-07, Time: 0.07
# It: 39100, Loss: 1.339e-06, Loss_u: 4.821e-07, Loss_Scs: 8.724e-08, Loss_res: 7.695e-07, Time: 0.07
# It: 39110, Loss: 1.774e-06, Loss_u: 5.102e-07, Loss_Scs: 6.011e-08, Loss_res: 1.204e-06, Time: 0.07
# It: 39120, Loss: 1.700e-06, Loss_u: 5.274e-07, Loss_Scs: 1.691e-07, Loss_res: 1.003e-06, Time: 0.08
# It: 39130, Loss: 2.405e-06, Loss_u: 5.347e-07, Loss_Scs: 3.146e-07, Loss_res: 1.556e-06, Time: 0.07
# It: 39140, Loss: 2.102e-06, Loss_u: 4.949e-07, Loss_Scs: 2.190e-07, Loss_res: 1.389e-06, Time: 0.08
# It: 39150, Loss: 1.848e-06, Loss_u: 6.559e-07, Loss_Scs: 7.812e-08, Loss_res: 1.114e-06, Time: 0.07
# It: 39160, Loss: 1.778e-06, Loss_u: 6.580e-07, Loss_Scs: 1.413e-07, Loss_res: 9.784e-07, Time: 0.07
# It: 39170, Loss: 1.434e-06, Loss_u: 5.406e-07, Loss_Scs: 8.514e-08, Loss_res: 8.082e-07, Time: 0.07
# It: 39180, Loss: 1.618e-06, Loss_u: 4.139e-07, Loss_Scs: 8.596e-08, Loss_res: 1.118e-06, Time: 0.07
# It: 39190, Loss: 2.296e-06, Loss_u: 5.758e-07, Loss_Scs: 6.731e-07, Loss_res: 1.047e-06, Time: 0.06
# It: 39200, Loss: 1.467e-06, Loss_u: 5.149e-07, Loss_Scs: 2.845e-07, Loss_res: 6.672e-07, Time: 0.08
# It: 39210, Loss: 1.599e-06, Loss_u: 5.688e-07, Loss_Scs: 2.386e-07, Loss_res: 7.917e-07, Time: 0.07
# It: 39220, Loss: 1.318e-06, Loss_u: 4.548e-07, Loss_Scs: 6.899e-08, Loss_res: 7.939e-07, Time: 0.07
# It: 39230, Loss: 1.519e-06, Loss_u: 4.884e-07, Loss_Scs: 2.414e-07, Loss_res: 7.890e-07, Time: 0.07
# It: 39240, Loss: 1.600e-06, Loss_u: 4.997e-07, Loss_Scs: 2.929e-07, Loss_res: 8.079e-07, Time: 0.07
# It: 39250, Loss: 1.740e-06, Loss_u: 5.752e-07, Loss_Scs: 8.146e-08, Loss_res: 1.083e-06, Time: 0.07
# It: 39260, Loss: 1.490e-06, Loss_u: 4.397e-07, Loss_Scs: 1.526e-07, Loss_res: 8.979e-07, Time: 0.09
# It: 39270, Loss: 1.447e-06, Loss_u: 5.260e-07, Loss_Scs: 2.286e-07, Loss_res: 6.919e-07, Time: 0.07
# It: 39280, Loss: 1.275e-06, Loss_u: 4.285e-07, Loss_Scs: 4.721e-08, Loss_res: 7.990e-07, Time: 0.07
# It: 39290, Loss: 1.545e-06, Loss_u: 4.886e-07, Loss_Scs: 6.762e-08, Loss_res: 9.887e-07, Time: 0.08
# It: 39300, Loss: 1.539e-06, Loss_u: 4.664e-07, Loss_Scs: 9.546e-08, Loss_res: 9.771e-07, Time: 0.07
# It: 39310, Loss: 1.456e-06, Loss_u: 4.196e-07, Loss_Scs: 3.644e-08, Loss_res: 9.998e-07, Time: 0.07
# It: 39320, Loss: 1.546e-06, Loss_u: 4.853e-07, Loss_Scs: 2.692e-07, Loss_res: 7.912e-07, Time: 0.08
# It: 39330, Loss: 1.423e-06, Loss_u: 6.144e-07, Loss_Scs: 9.931e-08, Loss_res: 7.094e-07, Time: 0.07
# It: 39340, Loss: 1.661e-06, Loss_u: 4.311e-07, Loss_Scs: 9.382e-08, Loss_res: 1.136e-06, Time: 0.07
# It: 39350, Loss: 1.591e-06, Loss_u: 5.324e-07, Loss_Scs: 1.264e-07, Loss_res: 9.322e-07, Time: 0.07
# It: 39360, Loss: 1.707e-06, Loss_u: 5.754e-07, Loss_Scs: 1.951e-07, Loss_res: 9.366e-07, Time: 0.07
# It: 39370, Loss: 1.559e-06, Loss_u: 5.728e-07, Loss_Scs: 2.046e-07, Loss_res: 7.816e-07, Time: 0.07
# It: 39380, Loss: 1.488e-06, Loss_u: 5.248e-07, Loss_Scs: 1.368e-07, Loss_res: 8.265e-07, Time: 0.07
# It: 39390, Loss: 1.406e-06, Loss_u: 5.241e-07, Loss_Scs: 9.390e-08, Loss_res: 7.885e-07, Time: 0.07
# It: 39400, Loss: 1.459e-06, Loss_u: 4.066e-07, Loss_Scs: 6.571e-08, Loss_res: 9.867e-07, Time: 0.08
# It: 39410, Loss: 1.918e-06, Loss_u: 4.808e-07, Loss_Scs: 8.552e-08, Loss_res: 1.352e-06, Time: 0.08
# It: 39420, Loss: 1.462e-06, Loss_u: 4.916e-07, Loss_Scs: 1.419e-07, Loss_res: 8.288e-07, Time: 0.07
# It: 39430, Loss: 1.507e-06, Loss_u: 4.705e-07, Loss_Scs: 6.182e-08, Loss_res: 9.744e-07, Time: 0.07
# It: 39440, Loss: 1.456e-06, Loss_u: 4.341e-07, Loss_Scs: 1.352e-07, Loss_res: 8.869e-07, Time: 0.08
# It: 39450, Loss: 1.431e-06, Loss_u: 5.306e-07, Loss_Scs: 9.490e-08, Loss_res: 8.055e-07, Time: 0.07
# It: 39460, Loss: 1.356e-06, Loss_u: 4.110e-07, Loss_Scs: 6.961e-08, Loss_res: 8.759e-07, Time: 0.07
# It: 39470, Loss: 1.939e-06, Loss_u: 6.054e-07, Loss_Scs: 9.489e-08, Loss_res: 1.239e-06, Time: 0.08
# It: 39480, Loss: 1.457e-06, Loss_u: 5.762e-07, Loss_Scs: 9.298e-08, Loss_res: 7.881e-07, Time: 0.07
# It: 39490, Loss: 1.333e-06, Loss_u: 3.995e-07, Loss_Scs: 8.192e-08, Loss_res: 8.519e-07, Time: 0.07
# It: 39500, Loss: 1.382e-06, Loss_u: 5.749e-07, Loss_Scs: 1.088e-07, Loss_res: 6.983e-07, Time: 0.07
# It: 39510, Loss: 3.543e-06, Loss_u: 4.590e-07, Loss_Scs: 1.628e-07, Loss_res: 2.921e-06, Time: 0.07
# It: 39520, Loss: 1.341e-06, Loss_u: 3.751e-07, Loss_Scs: 1.062e-07, Loss_res: 8.601e-07, Time: 0.07
# It: 39530, Loss: 1.765e-06, Loss_u: 3.894e-07, Loss_Scs: 5.919e-08, Loss_res: 1.317e-06, Time: 0.09
# It: 39540, Loss: 1.502e-06, Loss_u: 4.788e-07, Loss_Scs: 1.055e-07, Loss_res: 9.180e-07, Time: 0.07
# It: 39550, Loss: 1.471e-06, Loss_u: 4.219e-07, Loss_Scs: 1.221e-07, Loss_res: 9.265e-07, Time: 0.07
# It: 39560, Loss: 1.614e-06, Loss_u: 4.129e-07, Loss_Scs: 3.544e-07, Loss_res: 8.465e-07, Time: 0.08
# It: 39570, Loss: 1.773e-06, Loss_u: 4.445e-07, Loss_Scs: 1.102e-07, Loss_res: 1.219e-06, Time: 0.07
# It: 39580, Loss: 2.070e-06, Loss_u: 5.695e-07, Loss_Scs: 1.235e-07, Loss_res: 1.377e-06, Time: 0.07
# It: 39590, Loss: 1.534e-06, Loss_u: 4.715e-07, Loss_Scs: 2.154e-07, Loss_res: 8.473e-07, Time: 0.08
# It: 39600, Loss: 1.916e-06, Loss_u: 5.199e-07, Loss_Scs: 3.528e-07, Loss_res: 1.043e-06, Time: 0.07
# It: 39610, Loss: 2.028e-06, Loss_u: 4.957e-07, Loss_Scs: 6.096e-07, Loss_res: 9.226e-07, Time: 0.07
# It: 39620, Loss: 1.626e-06, Loss_u: 5.685e-07, Loss_Scs: 2.266e-07, Loss_res: 8.314e-07, Time: 0.07
# It: 39630, Loss: 1.440e-06, Loss_u: 4.893e-07, Loss_Scs: 1.088e-07, Loss_res: 8.419e-07, Time: 0.07
# It: 39640, Loss: 1.644e-06, Loss_u: 6.923e-07, Loss_Scs: 1.342e-07, Loss_res: 8.172e-07, Time: 0.08
# It: 39650, Loss: 1.636e-06, Loss_u: 5.280e-07, Loss_Scs: 3.423e-07, Loss_res: 7.660e-07, Time: 0.12
# It: 39660, Loss: 2.073e-06, Loss_u: 4.746e-07, Loss_Scs: 9.538e-08, Loss_res: 1.503e-06, Time: 0.14
# It: 39670, Loss: 1.752e-06, Loss_u: 5.069e-07, Loss_Scs: 7.651e-08, Loss_res: 1.169e-06, Time: 0.13
# It: 39680, Loss: 1.521e-06, Loss_u: 5.835e-07, Loss_Scs: 2.629e-08, Loss_res: 9.111e-07, Time: 0.12
# It: 39690, Loss: 2.289e-06, Loss_u: 5.659e-07, Loss_Scs: 1.879e-07, Loss_res: 1.536e-06, Time: 0.13
# It: 39700, Loss: 2.802e-06, Loss_u: 4.673e-07, Loss_Scs: 1.360e-07, Loss_res: 2.199e-06, Time: 0.13
# It: 39710, Loss: 2.568e-06, Loss_u: 4.894e-07, Loss_Scs: 4.822e-07, Loss_res: 1.597e-06, Time: 0.14
# It: 39720, Loss: 1.868e-06, Loss_u: 4.150e-07, Loss_Scs: 1.084e-07, Loss_res: 1.345e-06, Time: 0.12
# It: 39730, Loss: 1.516e-06, Loss_u: 5.107e-07, Loss_Scs: 7.838e-08, Loss_res: 9.265e-07, Time: 0.14
# It: 39740, Loss: 1.149e-06, Loss_u: 3.780e-07, Loss_Scs: 1.564e-07, Loss_res: 6.149e-07, Time: 0.12
# It: 39750, Loss: 1.479e-06, Loss_u: 5.153e-07, Loss_Scs: 3.286e-07, Loss_res: 6.348e-07, Time: 0.12
# It: 39760, Loss: 1.788e-06, Loss_u: 5.116e-07, Loss_Scs: 1.982e-07, Loss_res: 1.078e-06, Time: 0.12
# It: 39770, Loss: 1.344e-06, Loss_u: 5.549e-07, Loss_Scs: 6.580e-08, Loss_res: 7.235e-07, Time: 0.12
# It: 39780, Loss: 1.622e-06, Loss_u: 4.977e-07, Loss_Scs: 7.088e-08, Loss_res: 1.053e-06, Time: 0.12
# It: 39790, Loss: 1.338e-06, Loss_u: 4.984e-07, Loss_Scs: 9.436e-08, Loss_res: 7.452e-07, Time: 0.13
# It: 39800, Loss: 1.640e-06, Loss_u: 5.268e-07, Loss_Scs: 1.568e-07, Loss_res: 9.560e-07, Time: 0.12
# It: 39810, Loss: 1.739e-06, Loss_u: 4.616e-07, Loss_Scs: 5.125e-08, Loss_res: 1.226e-06, Time: 0.14
# It: 39820, Loss: 1.797e-06, Loss_u: 4.595e-07, Loss_Scs: 5.686e-07, Loss_res: 7.691e-07, Time: 0.12
# It: 39830, Loss: 1.761e-06, Loss_u: 4.685e-07, Loss_Scs: 4.434e-07, Loss_res: 8.493e-07, Time: 0.13
# It: 39840, Loss: 1.139e-06, Loss_u: 3.984e-07, Loss_Scs: 5.650e-08, Loss_res: 6.838e-07, Time: 0.12
# It: 39850, Loss: 1.344e-06, Loss_u: 4.925e-07, Loss_Scs: 5.945e-08, Loss_res: 7.917e-07, Time: 0.13
# It: 39860, Loss: 1.433e-06, Loss_u: 4.606e-07, Loss_Scs: 7.699e-08, Loss_res: 8.954e-07, Time: 0.07
# It: 39870, Loss: 1.597e-06, Loss_u: 4.869e-07, Loss_Scs: 2.751e-07, Loss_res: 8.353e-07, Time: 0.07
# It: 39880, Loss: 1.344e-06, Loss_u: 4.246e-07, Loss_Scs: 3.961e-08, Loss_res: 8.797e-07, Time: 0.07
# It: 39890, Loss: 1.442e-06, Loss_u: 5.628e-07, Loss_Scs: 3.859e-08, Loss_res: 8.408e-07, Time: 0.07
# It: 39900, Loss: 2.862e-06, Loss_u: 7.108e-07, Loss_Scs: 1.026e-07, Loss_res: 2.048e-06, Time: 0.07
# It: 39910, Loss: 1.964e-06, Loss_u: 5.554e-07, Loss_Scs: 1.388e-07, Loss_res: 1.270e-06, Time: 0.08
# It: 39920, Loss: 1.534e-06, Loss_u: 5.806e-07, Loss_Scs: 6.986e-08, Loss_res: 8.834e-07, Time: 0.09
# It: 39930, Loss: 2.270e-06, Loss_u: 5.319e-07, Loss_Scs: 9.686e-07, Loss_res: 7.696e-07, Time: 0.07
# It: 39940, Loss: 1.654e-06, Loss_u: 4.781e-07, Loss_Scs: 2.262e-07, Loss_res: 9.501e-07, Time: 0.07
# It: 39950, Loss: 2.067e-06, Loss_u: 4.587e-07, Loss_Scs: 3.900e-07, Loss_res: 1.219e-06, Time: 0.07
# It: 39960, Loss: 2.046e-06, Loss_u: 7.941e-07, Loss_Scs: 2.729e-07, Loss_res: 9.791e-07, Time: 0.07
# It: 39970, Loss: 1.307e-06, Loss_u: 4.715e-07, Loss_Scs: 8.197e-08, Loss_res: 7.534e-07, Time: 0.07
# It: 39980, Loss: 1.217e-06, Loss_u: 3.919e-07, Loss_Scs: 8.370e-08, Loss_res: 7.412e-07, Time: 0.07
# It: 39990, Loss: 1.332e-06, Loss_u: 4.939e-07, Loss_Scs: 1.138e-07, Loss_res: 7.242e-07, Time: 0.07
# Relative L2 error_u: 1.68e-03
# Relative L2 error_s: 8.43e-04

# %%
model.loss_total_log[-1]
# Out:
# np.float32(1.3318283e-06)

# %%
fig = plt.figure(figsize=(12, 8))
iterations = np.arange(0, len(model.loss_total_log)) * 10  # Every 10 iterations

# Subplot 1
plt.subplot(2, 2, 1)
plt.semilogy(iterations, model.loss_total_log)
plt.xlabel('Iterations')
plt.ylabel('Total Loss')
plt.title('a) Total Loss History')
plt.grid(True)

# Subplot 2
plt.subplot(2, 2, 2)
plt.semilogy(iterations, model.loss_u_log)
plt.xlabel('Iterations')
plt.ylabel('u Loss')
plt.title('b) Boundary & Initial Condition Loss')
plt.grid(True)

# Subplot 3
plt.subplot(2, 2, 3)
plt.semilogy(iterations, model.loss_Scs_log)
plt.xlabel('Iterations')
plt.ylabel('Stefan Condition Loss')
plt.title('c) Stefan Condition Loss')
plt.grid(True)

# Subplot 4
plt.subplot(2, 2, 4)
plt.semilogy(iterations, model.loss_res_log)
plt.xlabel('Iterations')
plt.ylabel('Residual Loss')
plt.title('d) PDE Residual Loss')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
    U_star = griddata(X_star, u_star.flatten(), (X, T), method='cubic')
    U_pred = griddata(X_star, u_pred.flatten(), (X, T), method='cubic')

    t = np.linspace(0, 1, 100)[:, None]
    x = np.zeros_like(t)
    x_star = np.concatenate((x, t), axis=1)
    s_star = s(x_star)
    s_pred = model.predict_s(x_star)
    error_s = np.abs(s_star - s_pred)

    # Plot for solution u
    fig_1 = plt.figure(1, figsize=(18, 5))
    plt.subplot(1, 3, 1)
    plt.plot(s_star, t, color='black', linewidth=2)
    plt.pcolor(X, T, U_star, cmap='jet')
    plt.colorbar()
    plt.xlabel(r'$x$')
    plt.ylabel(r'$t$')
    plt.title('a) Exact $u(x,t)$')

    plt.subplot(1, 3, 2)
    plt.pcolor(X, T, U_pred, cmap='jet')
    plt.plot(s_pred, t, color='black', linewidth=2)
    plt.colorbar()
    plt.xlabel(r'$x$')
    plt.ylabel(r'$t$')
    plt.title('b) Predicted $u(x,t)$')

    plt.subplot(1, 3, 3)
    plt.pcolor(X, T, np.abs(U_star - U_pred), cmap='jet')
    plt.colorbar(format='%.0e')
    plt.xlabel(r'$x$')
    plt.ylabel(r'$t$')
    plt.title('c) Absolute Error')

    plt.tight_layout()
    plt.show()

    # Plot for solution s
    fig_2 = plt.figure(2, figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(t, s_star, label='Exact')
    plt.plot(t, s_pred, '--', label='Predicted')
    plt.xlabel(r'$t$')
    plt.ylabel(r'$s(t)$')
    plt.title('a) Moving Boundary')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(t, error_s)
    plt.xlabel(r'$t$')
    plt.ylabel(r'Point-wise Error')
    plt.title('b) Absolute Error')
    plt.yscale('log')

    plt.tight_layout()
    plt.show()
