# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import numpy as np
import timeit
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.11/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
class Sampler:
    # Initialize the class
    def __init__(self, dim, coords, func, name=None):
        self.dim = dim
        self.coords = coords
        self.func = func
        self.name = name

    def sample(self, N):
        x = self.coords[0:1, :] + (self.coords[1:2, :] - self.coords[0:1, :]) * np.random.uniform(0, 1, size=(N, self.dim))
        y = self.func(x)
        return x, y

class DataSampler:
    # Initialize the class
    def __init__(self, X, Y, name = None):
        self.X = X
        self.Y = Y
        self.N = self.X.shape[0]

    def sample(self, batch_size):
        idx = np.random.choice(self.N, batch_size, replace=True)
        X_batch = self.X[idx, :]
        Y_batch = self.Y[idx, :]
        return X_batch, Y_batch

# %%
class Stefan1D_2P_inverse_I:
    def __init__(self, layers_u, layers_s, ics_sampler, ft2_sampler, res_sampler):
        # Normalization constants
        X, _ = res_sampler.sample(np.int32(1e5))
        self.mu_X, self.sigma_X = X.mean(0), X.std(0)
        self.mu_x, self.sigma_x = self.mu_X[0], self.sigma_X[0]
        self.mu_t, self.sigma_t = self.mu_X[1], self.sigma_X[1]

        # Samplers
        self.ics_sampler = ics_sampler
        # Store the single final time sampler (for phase 2)
        self.ft2_sampler = ft2_sampler
        self.res_sampler = res_sampler

        # Initialize network weights and biases
        self.layers_u = layers_u
        self.weights_u, self.biases_u = self.initialize_NN(layers_u)
        self.layers_s = layers_s
        self.weights_s, self.biases_s = self.initialize_NN(layers_s)

        # Define Tensorflow session
        self.sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))

        # --- Define placeholders ---
        self.x_u_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.t_u_tf = tf.placeholder(tf.float32, shape=(None, 1))

        # Initial conditions
        self.x1_ic_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.t1_ic_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u1_ic_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.x2_ic_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.t2_ic_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u2_ic_tf = tf.placeholder(tf.float32, shape=(None, 1))

        # Final Time condition (ONLY for phase 2)
        self.x2_T_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.t2_T_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.u2_T_tf = tf.placeholder(tf.float32, shape=(None, 1))

        # Residual points
        self.x_r_tf = tf.placeholder(tf.float32, shape=(None, 1))
        self.t_r_tf = tf.placeholder(tf.float32, shape=(None, 1))

        # --- Evaluate predictions ---
        self.s_pred = self.net_s(self.t_u_tf)
        self.u1_pred, self.u2_pred = self.net_u1u2(self.x_r_tf, self.t_r_tf)
        self.u_pred = self.net_u(self.x_u_tf, self.t_u_tf)

        # Initial condition predictions
        self.u1_0_pred, _ = self.net_u1u2(self.x1_ic_tf, self.t1_ic_tf)
        _, self.u2_0_pred = self.net_u1u2(self.x2_ic_tf, self.t2_ic_tf)

        # Final time predictions (ONLY for phase 2)
        _, self.u2_T_pred = self.net_u1u2(self.x2_T_tf, self.t2_T_tf) # Keep phase 2 prediction

        # Interface predictions
        self.s_bc1_pred, self.s_bc2_pred = self.net_u1u2((self.net_s(self.t_r_tf) - self.mu_x) / self.sigma_x, self.t_r_tf)
        self.r_u1_pred, self.r_u2_pred = self.net_r_u1u2(self.x_r_tf, self.t_r_tf)
        self.r_Nc_pred = self.net_r_Nc(self.t_r_tf)

        # --- Loss Functions ---
        # Final Time Loss - ONLY for phase 2
        self.loss_u2_T = tf.reduce_mean(tf.square(self.u2_T_pred - self.u2_T_tf)) # Keep phase 2 loss
        self.loss_u_T = self.loss_u2_T

        # Initial Loss
        self.loss_u1_ic = tf.reduce_mean(tf.square(self.u1_0_pred - self.u1_ic_tf))
        self.loss_u2_ic = tf.reduce_mean(tf.square(self.u2_0_pred - self.u2_ic_tf))
        self.loss_u_ics = self.loss_u1_ic + self.loss_u2_ic

        # Stefan loss
        self.loss_Sbc1 = tf.reduce_mean(tf.square(self.s_bc1_pred))
        self.loss_Sbc2 = tf.reduce_mean(tf.square(self.s_bc2_pred))
        self.loss_s_0 = tf.reduce_mean(tf.square(self.net_s(self.t1_ic_tf) - 0.5))
        self.loss_SNc = tf.reduce_mean(tf.square(self.r_Nc_pred))
        self.loss_Scs = self.loss_Sbc1 + self.loss_Sbc2 + self.loss_s_0 + self.loss_SNc

        # Residual loss
        self.loss_res_u1 = tf.reduce_mean(tf.square(self.r_u1_pred))
        self.loss_res_u2 = tf.reduce_mean(tf.square(self.r_u2_pred))
        self.loss_res = self.loss_res_u1 + self.loss_res_u2

        # Total loss
        self.loss_u = self.loss_u_ics + self.loss_u_T
        self.loss = self.loss_res + self.loss_u + self.loss_Scs

        # Define optimizer
        self.global_step = tf.Variable(0, trainable=False)
        starter_learning_rate = 1e-3
        self.learning_rate = tf.train.exponential_decay(starter_learning_rate, self.global_step,
                                                        1000, 0.9, staircase=False)
        self.train_op = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss, global_step=self.global_step)

        # Logging and Saving
        self.loss_total_log = []
        self.loss_u_log = []
        self.loss_Scs_log = []
        self.loss_res_log = []
        self.saver = tf.train.Saver()

        # Initialize Tensorflow variables
        init = tf.global_variables_initializer()
        self.sess.run(init)

    # --- Modify the train method ---
    def train(self, nIter=10000, batch_size=128):
        start_time = timeit.default_timer()

        for it in range(nIter):
            # Fetch initial condition and residual batches
            X1_ic_batch, u1_ic_batch = self.fetch_minibatch(self.ics_sampler[0], batch_size)
            X2_ic_batch, u2_ic_batch = self.fetch_minibatch(self.ics_sampler[1], batch_size)
            X_res_batch, _ = self.fetch_minibatch(self.res_sampler, batch_size)

            # Fetch final time condition batch (ONLY for phase 2)
            # Use the stored self.ft2_sampler
            X2_T_batch, u2_T_batch = self.fetch_minibatch(self.ft2_sampler, batch_size)

            # Define a dictionary for associating placeholders with data
            tf_dict = {self.x_u_tf: X_res_batch[:, 0:1], self.t_u_tf: X_res_batch[:, 1:2],
                       # Initial conditions
                       self.x1_ic_tf: X1_ic_batch[:, 0:1], self.t1_ic_tf: X1_ic_batch[:, 1:2],
                       self.u1_ic_tf: u1_ic_batch,
                       self.x2_ic_tf: X2_ic_batch[:, 0:1], self.t2_ic_tf: X2_ic_batch[:, 1:2],
                       self.u2_ic_tf: u2_ic_batch,
                       # Final time conditions (ONLY phase 2)
                       self.x2_T_tf: X2_T_batch[:, 0:1], self.t2_T_tf: X2_T_batch[:, 1:2], # Keep phase 2
                       self.u2_T_tf: u2_T_batch,                                        # Keep phase 2
                       # Residual points
                       self.x_r_tf: X_res_batch[:, 0:1], self.t_r_tf: X_res_batch[:, 1:2]}

            self.sess.run(self.train_op, tf_dict)

            # Print/Log
            if it % 10 == 0:
                elapsed = timeit.default_timer() - start_time
                loss_value = self.sess.run(self.loss, tf_dict)
                loss_u_value, loss_Scs_value, loss_res_value = self.sess.run(
                    [self.loss_u, self.loss_Scs, self.loss_res], tf_dict)

                self.loss_total_log.append(loss_value)  # Store total loss
                self.loss_u_log.append(loss_u_value)
                self.loss_Scs_log.append(loss_Scs_value)
                self.loss_res_log.append(loss_res_value)
                print('It: %d, Loss: %.3e, Loss_u: %.3e, Loss_Scs: %.3e, Loss_res: %.3e, Time: %.2f' %
                      (it, loss_value, loss_u_value, loss_Scs_value, loss_res_value, elapsed))
                start_time = timeit.default_timer()

    def predict_u(self, X_star):
         X_star = (X_star - self.mu_X) / self.sigma_X
         tf_dict = {self.x_u_tf: X_star[:, 0:1], self.t_u_tf: X_star[:, 1:2]}
         u_star = self.sess.run(self.u_pred, tf_dict)
         return u_star

    def predict_s(self, X_star):
         X_star = (X_star - self.mu_X) / self.sigma_X
         tf_dict = {self.t_u_tf: X_star[:, 1:2]}
         s_star = self.sess.run(self.s_pred, tf_dict)
         return s_star

    # Xavier initialization
    def xavier_init(self, size):
        in_dim = size[0]
        out_dim = size[1]
        xavier_stddev = 1. / np.sqrt((in_dim + out_dim) / 2.)
        return tf.Variable(tf.random_normal([in_dim, out_dim], dtype=tf.float32) * xavier_stddev,
                           dtype=tf.float32)

    # Initialize network weights and biases using Xavier initialization
    def initialize_NN(self, layers):
        weights = []
        biases = []
        num_layers = len(layers)
        for l in range(0, num_layers - 1):
            W = self.xavier_init(size=[layers[l], layers[l + 1]])
            b = tf.Variable(tf.zeros([1, layers[l + 1]], dtype=tf.float32), dtype=tf.float32)
            weights.append(W)
            biases.append(b)
        return weights, biases

    # Evaluates the forward pass
    def forward_pass(self, H, weights, biases):
        num_layers = len(weights)
        for l in range(0, num_layers - 2):
            W = weights[l]
            b = biases[l]
            H = tf.tanh(tf.add(tf.matmul(H, W), b))
        W = weights[-1]
        b = biases[-1]
        H = tf.add(tf.matmul(H, W), b)
        return H

     # Forward pass for u1, u2
    def net_u1u2(self, x, t):
        u = self.forward_pass(tf.concat([x, t], 1), self.weights_u, self.biases_u)
        u1 = u[:,0:1]
        u2 = u[:,1:2]
        return u1, u2

    def net_u1u2_x(self, x, t):
        u1, u2 = self.net_u1u2(x, t)
        u1_x = tf.gradients(u1, x)[0] / self.sigma_x
        u2_x = tf.gradients(u2, x)[0] / self.sigma_x
        return u1_x, u2_x

    # Forward pass for s
    def net_s(self, t):
        s = self.forward_pass(t, self.weights_s, self.biases_s)
        return s

    # Forward pass for u
    def net_u(self, x, t):
        u1, u2 = self.net_u1u2(x, t)
        s = self.net_s(t)
        x_hat = x * self.sigma_x + self.mu_x # Denormalize x
        u = tf.multiply(u1, 0.5 * (tf.sign(s - x_hat) + 1)) + \
            tf.multiply(u2, 0.5 * (tf.sign(x_hat - s) + 1))
        return u

    # Forward pass for residual
    def net_r_u1u2(self, x, t):
        u1, u2 = self.net_u1u2(x, t)
        u1_t = tf.gradients(u1, t)[0] / self.sigma_t
        u1_x = tf.gradients(u1, x)[0] / self.sigma_x
        u1_xx = tf.gradients(u1_x, x)[0] / self.sigma_x
        r_u1 = u1_t - 2 * u1_xx

        u2_t = tf.gradients(u2, t)[0] / self.sigma_t
        u2_x = tf.gradients(u2, x)[0] / self.sigma_x
        u2_xx = tf.gradients(u2_x, x)[0] / self.sigma_x
        r_u2 = u2_t - u2_xx
        return r_u1, r_u2

    def net_r_Nc(self, t):
        s = self.net_s(t)
        s_t = tf.gradients(s, t)[0] / self.sigma_t
        s_norm = (s - self.mu_x) / self.sigma_x # Normalize s for gradient evaluation
        u1_x, u2_x = self.net_u1u2_x(s_norm, t)
        residual = s_t - u2_x + 2 * u1_x
        return residual

    def fetch_minibatch(self, sampler, N):
        X, Y = sampler.sample(N)
        X = (X - self.mu_X) / self.sigma_X
        return X, Y

# %%
if __name__ == '__main__':

    # Exact u1
    def u1(x):
        t = x[:, 1:2]; x = x[:, 0:1]
        u1 = 2 * (np.exp((t + 0.5 - x) / 2) - 1)
        return u1

    # Exact u2
    def u2(x):
        t = x[:, 1:2]; x = x[:, 0:1]
        u2 = np.exp(t + 0.5 - x) - 1
        return u2

    # Exact s
    def s(x):
        t = x[:, 1:2]
        s = t + 0.5
        return s

    # Exact u
    def u(x):
        return np.where(x[:, 0:1] <= s(x), u1(x), u2(x))

    # Condition at the final time (ONLY for phase 2)
    def u2_T(x): # Keep phase 2
        x = x[:, 0:1]
        u2_T = np.exp(1 + 0.5 - x) - 1 # Assumes T=1
        return u2_T

    # Initial condition for s
    def s_0(x):
        z = 0.5; N = x.shape[0]
        return z * np.ones((N, 1))

    # Initial condition for u1
    def u1_0(x):
        x = x[:, 0:1]
        u1_0 = 2 * (np.exp((0.5 - x) / 2) - 1)
        return u1_0

    # Initial condition for u2
    def u2_0(x):
        x = x[:, 0:1]
        u2_0 = np.exp(0.5 - x) - 1 # Renamed variable inside from u2 to u2_0
        return u2_0

    # Domain boundaries
    ics_coords = np.array([[0.0, 0.0], [2.0, 0.0]])
    ft_coords = np.array([[0.0, 1.0], [2.0, 1.0]])
    dom_coords = np.array([[0.0, 0.0], [2.0, 1.0]])

    # Initial Condition Samplers
    ic1_sampler = Sampler(2, ics_coords, lambda x: u1_0(x), name='Initial Condition 1')
    ic2_sampler = Sampler(2, ics_coords, lambda x: u2_0(x), name='Initial Condition 2')
    ics_sampler = [ic1_sampler, ic2_sampler]

    # Final Time Condition Sampler (ONLY for phase 2)
    ft2_sampler = Sampler(2, ft_coords, lambda x: u2_T(x), name='Final Time Condition 2') # Keep phase 2

    # Create residual sampler
    res_sampler = Sampler(2, dom_coords, lambda x: u(x), name='Forcing')

    # Define model layers
    layers_u = [2, 100, 100, 100, 2]
    layers_s = [1, 100, 100, 100, 1]

    # Instantiate the model - Pass only ft2_sampler
    model = Stefan1D_2P_inverse_I(layers_u,
                                  layers_s,
                                  ics_sampler,
                                  ft2_sampler,
                                  res_sampler)

    # Train the model
    model.train(nIter=40000, batch_size=128)

    # Test data
    nn = 100
    x = np.linspace(dom_coords[0, 0], dom_coords[1, 0], nn)[:, None]
    t = np.linspace(dom_coords[0, 1], dom_coords[1, 1], nn)[:, None]
    X, T = np.meshgrid(x, t)
    X_star = np.hstack((X.flatten()[:, None], T.flatten()[:, None]))

    u_star = u(X_star)
    s_star = s(X_star)

    # Predictions
    u_pred = model.predict_u(X_star)
    s_pred = model.predict_s(X_star)

    # Errors
    error_u = np.linalg.norm(u_star - u_pred, 2) / np.linalg.norm(u_star, 2)
    error_s = np.linalg.norm(s_star - s_pred, 2) / np.linalg.norm(s_star, 2)

    print('Relative L2 error_u: {:.2e}'.format(error_u))
    print('Relative L2 error_s: {:.2e}'.format(error_s))
# Out:
# Device mapping: no known devices.
# It: 0, Loss: 2.551e+00, Loss_u: 2.044e+00, Loss_Scs: 3.200e-01, Loss_res: 1.869e-01, Time: 1.03
# It: 10, Loss: 1.578e+00, Loss_u: 1.141e+00, Loss_Scs: 2.615e-01, Loss_res: 1.762e-01, Time: 0.14
# It: 20, Loss: 1.514e+00, Loss_u: 1.084e+00, Loss_Scs: 2.163e-01, Loss_res: 2.136e-01, Time: 0.13
# It: 30, Loss: 1.088e+00, Loss_u: 7.535e-01, Loss_Scs: 1.406e-01, Loss_res: 1.941e-01, Time: 0.13
# It: 40, Loss: 1.109e+00, Loss_u: 7.188e-01, Loss_Scs: 1.600e-01, Loss_res: 2.300e-01, Time: 0.12
# It: 50, Loss: 1.052e+00, Loss_u: 7.529e-01, Loss_Scs: 1.413e-01, Loss_res: 1.576e-01, Time: 0.14
# It: 60, Loss: 9.402e-01, Loss_u: 6.445e-01, Loss_Scs: 1.041e-01, Loss_res: 1.915e-01, Time: 0.14
# It: 70, Loss: 1.014e+00, Loss_u: 7.261e-01, Loss_Scs: 1.103e-01, Loss_res: 1.774e-01, Time: 0.07
# It: 80, Loss: 9.189e-01, Loss_u: 5.815e-01, Loss_Scs: 1.125e-01, Loss_res: 2.249e-01, Time: 0.07
# It: 90, Loss: 7.849e-01, Loss_u: 5.123e-01, Loss_Scs: 1.071e-01, Loss_res: 1.655e-01, Time: 0.08
# It: 100, Loss: 8.649e-01, Loss_u: 6.037e-01, Loss_Scs: 9.222e-02, Loss_res: 1.690e-01, Time: 0.07
# It: 110, Loss: 7.975e-01, Loss_u: 5.519e-01, Loss_Scs: 8.434e-02, Loss_res: 1.613e-01, Time: 0.07
# It: 120, Loss: 7.750e-01, Loss_u: 5.518e-01, Loss_Scs: 8.188e-02, Loss_res: 1.413e-01, Time: 0.07
# It: 130, Loss: 7.261e-01, Loss_u: 5.182e-01, Loss_Scs: 5.965e-02, Loss_res: 1.482e-01, Time: 0.08
# It: 140, Loss: 6.464e-01, Loss_u: 4.071e-01, Loss_Scs: 5.658e-02, Loss_res: 1.827e-01, Time: 0.08
# It: 150, Loss: 5.188e-01, Loss_u: 2.309e-01, Loss_Scs: 4.026e-02, Loss_res: 2.477e-01, Time: 0.07
# It: 160, Loss: 4.879e-01, Loss_u: 2.580e-01, Loss_Scs: 3.720e-02, Loss_res: 1.927e-01, Time: 0.08
# It: 170, Loss: 4.439e-01, Loss_u: 2.527e-01, Loss_Scs: 3.544e-02, Loss_res: 1.558e-01, Time: 0.08
# It: 180, Loss: 3.992e-01, Loss_u: 2.363e-01, Loss_Scs: 3.032e-02, Loss_res: 1.325e-01, Time: 0.08
# It: 190, Loss: 3.801e-01, Loss_u: 1.785e-01, Loss_Scs: 2.746e-02, Loss_res: 1.742e-01, Time: 0.07
# It: 200, Loss: 3.532e-01, Loss_u: 1.299e-01, Loss_Scs: 2.861e-02, Loss_res: 1.947e-01, Time: 0.07
# It: 210, Loss: 2.755e-01, Loss_u: 1.027e-01, Loss_Scs: 2.489e-02, Loss_res: 1.479e-01, Time: 0.07
# It: 220, Loss: 2.804e-01, Loss_u: 1.301e-01, Loss_Scs: 1.950e-02, Loss_res: 1.309e-01, Time: 0.07
# It: 230, Loss: 1.927e-01, Loss_u: 1.005e-01, Loss_Scs: 1.451e-02, Loss_res: 7.768e-02, Time: 0.07
# It: 240, Loss: 1.812e-01, Loss_u: 9.176e-02, Loss_Scs: 1.244e-02, Loss_res: 7.700e-02, Time: 0.07
# It: 250, Loss: 1.954e-01, Loss_u: 7.456e-02, Loss_Scs: 1.265e-02, Loss_res: 1.082e-01, Time: 0.07
# It: 260, Loss: 1.584e-01, Loss_u: 7.817e-02, Loss_Scs: 9.285e-03, Loss_res: 7.090e-02, Time: 0.08
# It: 270, Loss: 1.371e-01, Loss_u: 7.134e-02, Loss_Scs: 9.711e-03, Loss_res: 5.602e-02, Time: 0.08
# It: 280, Loss: 1.012e-01, Loss_u: 4.394e-02, Loss_Scs: 6.863e-03, Loss_res: 5.035e-02, Time: 0.07
# It: 290, Loss: 9.711e-02, Loss_u: 4.228e-02, Loss_Scs: 6.908e-03, Loss_res: 4.792e-02, Time: 0.11
# It: 300, Loss: 5.834e-02, Loss_u: 3.150e-02, Loss_Scs: 5.527e-03, Loss_res: 2.131e-02, Time: 0.08
# It: 310, Loss: 6.397e-02, Loss_u: 2.717e-02, Loss_Scs: 5.455e-03, Loss_res: 3.135e-02, Time: 0.07
# It: 320, Loss: 5.576e-02, Loss_u: 2.530e-02, Loss_Scs: 4.412e-03, Loss_res: 2.605e-02, Time: 0.08
# It: 330, Loss: 5.024e-02, Loss_u: 2.242e-02, Loss_Scs: 3.951e-03, Loss_res: 2.387e-02, Time: 0.08
# It: 340, Loss: 3.830e-02, Loss_u: 1.954e-02, Loss_Scs: 3.395e-03, Loss_res: 1.536e-02, Time: 0.07
# It: 350, Loss: 4.270e-02, Loss_u: 1.907e-02, Loss_Scs: 2.796e-03, Loss_res: 2.083e-02, Time: 0.07
# It: 360, Loss: 3.021e-02, Loss_u: 1.379e-02, Loss_Scs: 2.433e-03, Loss_res: 1.399e-02, Time: 0.07
# It: 370, Loss: 2.377e-02, Loss_u: 1.092e-02, Loss_Scs: 2.204e-03, Loss_res: 1.064e-02, Time: 0.07
# It: 380, Loss: 2.419e-02, Loss_u: 1.233e-02, Loss_Scs: 1.998e-03, Loss_res: 9.859e-03, Time: 0.08
# It: 390, Loss: 2.391e-02, Loss_u: 1.218e-02, Loss_Scs: 2.319e-03, Loss_res: 9.405e-03, Time: 0.07
# It: 400, Loss: 2.130e-02, Loss_u: 1.210e-02, Loss_Scs: 1.578e-03, Loss_res: 7.624e-03, Time: 0.07
# It: 410, Loss: 2.062e-02, Loss_u: 1.080e-02, Loss_Scs: 1.157e-03, Loss_res: 8.660e-03, Time: 0.07
# It: 420, Loss: 1.712e-02, Loss_u: 9.572e-03, Loss_Scs: 1.420e-03, Loss_res: 6.131e-03, Time: 0.10
# It: 430, Loss: 1.757e-02, Loss_u: 1.080e-02, Loss_Scs: 1.084e-03, Loss_res: 5.692e-03, Time: 0.07
# It: 440, Loss: 1.371e-02, Loss_u: 7.952e-03, Loss_Scs: 1.064e-03, Loss_res: 4.697e-03, Time: 0.07
# It: 450, Loss: 1.633e-02, Loss_u: 7.681e-03, Loss_Scs: 1.010e-03, Loss_res: 7.644e-03, Time: 0.08
# It: 460, Loss: 1.557e-02, Loss_u: 8.280e-03, Loss_Scs: 6.955e-04, Loss_res: 6.590e-03, Time: 0.07
# It: 470, Loss: 1.076e-02, Loss_u: 6.340e-03, Loss_Scs: 7.568e-04, Loss_res: 3.661e-03, Time: 0.09
# It: 480, Loss: 1.064e-02, Loss_u: 5.604e-03, Loss_Scs: 7.703e-04, Loss_res: 4.267e-03, Time: 0.09
# It: 490, Loss: 1.036e-02, Loss_u: 6.746e-03, Loss_Scs: 6.945e-04, Loss_res: 2.921e-03, Time: 0.07
# It: 500, Loss: 9.855e-03, Loss_u: 6.109e-03, Loss_Scs: 6.859e-04, Loss_res: 3.060e-03, Time: 0.08
# It: 510, Loss: 1.021e-02, Loss_u: 6.251e-03, Loss_Scs: 7.943e-04, Loss_res: 3.169e-03, Time: 0.08
# It: 520, Loss: 1.017e-02, Loss_u: 4.955e-03, Loss_Scs: 5.337e-04, Loss_res: 4.684e-03, Time: 0.07
# It: 530, Loss: 1.013e-02, Loss_u: 5.613e-03, Loss_Scs: 7.059e-04, Loss_res: 3.808e-03, Time: 0.07
# It: 540, Loss: 8.553e-03, Loss_u: 5.111e-03, Loss_Scs: 6.307e-04, Loss_res: 2.811e-03, Time: 0.09
# It: 550, Loss: 7.968e-03, Loss_u: 4.481e-03, Loss_Scs: 5.572e-04, Loss_res: 2.930e-03, Time: 0.07
# It: 560, Loss: 8.043e-03, Loss_u: 4.870e-03, Loss_Scs: 6.288e-04, Loss_res: 2.544e-03, Time: 0.07
# It: 570, Loss: 7.130e-03, Loss_u: 4.920e-03, Loss_Scs: 5.541e-04, Loss_res: 1.656e-03, Time: 0.08
# It: 580, Loss: 7.001e-03, Loss_u: 4.017e-03, Loss_Scs: 5.374e-04, Loss_res: 2.447e-03, Time: 0.07
# It: 590, Loss: 6.141e-03, Loss_u: 3.518e-03, Loss_Scs: 3.743e-04, Loss_res: 2.249e-03, Time: 0.07
# It: 600, Loss: 6.506e-03, Loss_u: 3.848e-03, Loss_Scs: 4.375e-04, Loss_res: 2.221e-03, Time: 0.08
# It: 610, Loss: 6.458e-03, Loss_u: 3.434e-03, Loss_Scs: 4.136e-04, Loss_res: 2.610e-03, Time: 0.07
# It: 620, Loss: 7.116e-03, Loss_u: 3.506e-03, Loss_Scs: 3.614e-04, Loss_res: 3.249e-03, Time: 0.07
# It: 630, Loss: 5.999e-03, Loss_u: 3.668e-03, Loss_Scs: 4.472e-04, Loss_res: 1.883e-03, Time: 0.08
# It: 640, Loss: 5.716e-03, Loss_u: 3.714e-03, Loss_Scs: 4.972e-04, Loss_res: 1.505e-03, Time: 0.07
# It: 650, Loss: 7.411e-03, Loss_u: 3.725e-03, Loss_Scs: 3.931e-04, Loss_res: 3.293e-03, Time: 0.07
# It: 660, Loss: 5.231e-03, Loss_u: 3.174e-03, Loss_Scs: 3.106e-04, Loss_res: 1.747e-03, Time: 0.07
# It: 670, Loss: 5.166e-03, Loss_u: 2.950e-03, Loss_Scs: 4.707e-04, Loss_res: 1.746e-03, Time: 0.09
# It: 680, Loss: 4.961e-03, Loss_u: 2.794e-03, Loss_Scs: 4.183e-04, Loss_res: 1.748e-03, Time: 0.07
# It: 690, Loss: 4.772e-03, Loss_u: 2.466e-03, Loss_Scs: 3.358e-04, Loss_res: 1.971e-03, Time: 0.08
# It: 700, Loss: 4.668e-03, Loss_u: 2.400e-03, Loss_Scs: 3.299e-04, Loss_res: 1.939e-03, Time: 0.08
# It: 710, Loss: 5.177e-03, Loss_u: 3.585e-03, Loss_Scs: 2.684e-04, Loss_res: 1.324e-03, Time: 0.07
# It: 720, Loss: 5.026e-03, Loss_u: 3.027e-03, Loss_Scs: 2.370e-04, Loss_res: 1.762e-03, Time: 0.07
# It: 730, Loss: 4.896e-03, Loss_u: 2.343e-03, Loss_Scs: 2.871e-04, Loss_res: 2.266e-03, Time: 0.07
# It: 740, Loss: 3.955e-03, Loss_u: 2.473e-03, Loss_Scs: 2.843e-04, Loss_res: 1.197e-03, Time: 0.07
# It: 750, Loss: 4.588e-03, Loss_u: 2.571e-03, Loss_Scs: 3.946e-04, Loss_res: 1.622e-03, Time: 0.08
# It: 760, Loss: 3.799e-03, Loss_u: 2.322e-03, Loss_Scs: 2.459e-04, Loss_res: 1.231e-03, Time: 0.07
# It: 770, Loss: 3.564e-03, Loss_u: 2.053e-03, Loss_Scs: 3.207e-04, Loss_res: 1.191e-03, Time: 0.07
# It: 780, Loss: 4.179e-03, Loss_u: 1.788e-03, Loss_Scs: 2.356e-04, Loss_res: 2.155e-03, Time: 0.07
# It: 790, Loss: 4.679e-03, Loss_u: 2.587e-03, Loss_Scs: 2.894e-04, Loss_res: 1.802e-03, Time: 0.07
# It: 800, Loss: 3.535e-03, Loss_u: 1.899e-03, Loss_Scs: 2.305e-04, Loss_res: 1.405e-03, Time: 0.09
# It: 810, Loss: 4.155e-03, Loss_u: 2.252e-03, Loss_Scs: 2.052e-04, Loss_res: 1.698e-03, Time: 0.08
# It: 820, Loss: 3.271e-03, Loss_u: 1.907e-03, Loss_Scs: 1.894e-04, Loss_res: 1.175e-03, Time: 0.07
# It: 830, Loss: 3.509e-03, Loss_u: 2.269e-03, Loss_Scs: 1.782e-04, Loss_res: 1.061e-03, Time: 0.07
# It: 840, Loss: 3.370e-03, Loss_u: 2.390e-03, Loss_Scs: 1.834e-04, Loss_res: 7.960e-04, Time: 0.07
# It: 850, Loss: 3.569e-03, Loss_u: 2.042e-03, Loss_Scs: 2.574e-04, Loss_res: 1.269e-03, Time: 0.07
# It: 860, Loss: 2.896e-03, Loss_u: 1.492e-03, Loss_Scs: 1.745e-04, Loss_res: 1.230e-03, Time: 0.07
# It: 870, Loss: 3.143e-03, Loss_u: 1.913e-03, Loss_Scs: 2.518e-04, Loss_res: 9.787e-04, Time: 0.08
# It: 880, Loss: 2.677e-03, Loss_u: 1.690e-03, Loss_Scs: 1.978e-04, Loss_res: 7.896e-04, Time: 0.07
# It: 890, Loss: 3.404e-03, Loss_u: 1.879e-03, Loss_Scs: 2.188e-04, Loss_res: 1.307e-03, Time: 0.07
# It: 900, Loss: 3.183e-03, Loss_u: 2.161e-03, Loss_Scs: 1.444e-04, Loss_res: 8.776e-04, Time: 0.07
# It: 910, Loss: 3.720e-03, Loss_u: 2.134e-03, Loss_Scs: 1.846e-04, Loss_res: 1.402e-03, Time: 0.07
# It: 920, Loss: 2.501e-03, Loss_u: 1.529e-03, Loss_Scs: 1.612e-04, Loss_res: 8.101e-04, Time: 0.07
# It: 930, Loss: 2.771e-03, Loss_u: 1.596e-03, Loss_Scs: 2.000e-04, Loss_res: 9.745e-04, Time: 0.09
# It: 940, Loss: 3.235e-03, Loss_u: 1.940e-03, Loss_Scs: 1.728e-04, Loss_res: 1.121e-03, Time: 0.07
# It: 950, Loss: 2.623e-03, Loss_u: 1.286e-03, Loss_Scs: 2.001e-04, Loss_res: 1.137e-03, Time: 0.07
# It: 960, Loss: 2.939e-03, Loss_u: 1.775e-03, Loss_Scs: 1.766e-04, Loss_res: 9.875e-04, Time: 0.08
# It: 970, Loss: 2.247e-03, Loss_u: 1.178e-03, Loss_Scs: 1.438e-04, Loss_res: 9.248e-04, Time: 0.07
# It: 980, Loss: 1.891e-03, Loss_u: 1.187e-03, Loss_Scs: 1.190e-04, Loss_res: 5.852e-04, Time: 0.07
# It: 990, Loss: 2.021e-03, Loss_u: 1.211e-03, Loss_Scs: 1.401e-04, Loss_res: 6.697e-04, Time: 0.08
# It: 1000, Loss: 2.391e-03, Loss_u: 1.574e-03, Loss_Scs: 1.720e-04, Loss_res: 6.456e-04, Time: 0.08
# It: 1010, Loss: 2.773e-03, Loss_u: 1.548e-03, Loss_Scs: 3.264e-04, Loss_res: 8.985e-04, Time: 0.07
# It: 1020, Loss: 2.661e-03, Loss_u: 1.617e-03, Loss_Scs: 1.059e-04, Loss_res: 9.375e-04, Time: 0.07
# It: 1030, Loss: 2.608e-03, Loss_u: 1.631e-03, Loss_Scs: 2.015e-04, Loss_res: 7.759e-04, Time: 0.07
# It: 1040, Loss: 2.138e-03, Loss_u: 1.131e-03, Loss_Scs: 2.061e-04, Loss_res: 8.006e-04, Time: 0.07
# It: 1050, Loss: 2.121e-03, Loss_u: 1.220e-03, Loss_Scs: 1.583e-04, Loss_res: 7.424e-04, Time: 0.07
# It: 1060, Loss: 2.177e-03, Loss_u: 1.489e-03, Loss_Scs: 1.069e-04, Loss_res: 5.808e-04, Time: 0.10
# It: 1070, Loss: 1.962e-03, Loss_u: 1.252e-03, Loss_Scs: 1.663e-04, Loss_res: 5.435e-04, Time: 0.07
# It: 1080, Loss: 1.990e-03, Loss_u: 1.385e-03, Loss_Scs: 1.127e-04, Loss_res: 4.914e-04, Time: 0.07
# It: 1090, Loss: 1.956e-03, Loss_u: 1.235e-03, Loss_Scs: 1.232e-04, Loss_res: 5.978e-04, Time: 0.07
# It: 1100, Loss: 1.863e-03, Loss_u: 1.083e-03, Loss_Scs: 2.041e-04, Loss_res: 5.759e-04, Time: 0.08
# It: 1110, Loss: 1.775e-03, Loss_u: 1.118e-03, Loss_Scs: 8.930e-05, Loss_res: 5.681e-04, Time: 0.08
# It: 1120, Loss: 2.494e-03, Loss_u: 1.257e-03, Loss_Scs: 5.938e-04, Loss_res: 6.432e-04, Time: 0.08
# It: 1130, Loss: 2.649e-03, Loss_u: 1.065e-03, Loss_Scs: 5.906e-04, Loss_res: 9.934e-04, Time: 0.07
# It: 1140, Loss: 1.548e-03, Loss_u: 9.689e-04, Loss_Scs: 1.580e-04, Loss_res: 4.209e-04, Time: 0.07
# It: 1150, Loss: 2.337e-03, Loss_u: 1.303e-03, Loss_Scs: 3.141e-04, Loss_res: 7.198e-04, Time: 0.12
# It: 1160, Loss: 2.062e-03, Loss_u: 1.335e-03, Loss_Scs: 4.671e-04, Loss_res: 2.596e-04, Time: 0.12
# It: 1170, Loss: 1.493e-03, Loss_u: 8.875e-04, Loss_Scs: 9.297e-05, Loss_res: 5.130e-04, Time: 0.14
# It: 1180, Loss: 1.537e-03, Loss_u: 1.050e-03, Loss_Scs: 1.821e-04, Loss_res: 3.051e-04, Time: 0.13
# It: 1190, Loss: 1.826e-03, Loss_u: 1.306e-03, Loss_Scs: 1.104e-04, Loss_res: 4.097e-04, Time: 0.13
# It: 1200, Loss: 1.796e-03, Loss_u: 1.295e-03, Loss_Scs: 6.929e-05, Loss_res: 4.322e-04, Time: 0.14
# It: 1210, Loss: 1.522e-03, Loss_u: 9.689e-04, Loss_Scs: 1.444e-04, Loss_res: 4.087e-04, Time: 0.13
# It: 1220, Loss: 1.450e-03, Loss_u: 9.570e-04, Loss_Scs: 8.567e-05, Loss_res: 4.073e-04, Time: 0.14
# It: 1230, Loss: 1.521e-03, Loss_u: 1.134e-03, Loss_Scs: 1.112e-04, Loss_res: 2.757e-04, Time: 0.13
# It: 1240, Loss: 1.631e-03, Loss_u: 9.328e-04, Loss_Scs: 1.429e-04, Loss_res: 5.557e-04, Time: 0.13
# It: 1250, Loss: 1.484e-03, Loss_u: 9.546e-04, Loss_Scs: 2.475e-04, Loss_res: 2.818e-04, Time: 0.14
# It: 1260, Loss: 2.064e-03, Loss_u: 1.356e-03, Loss_Scs: 2.363e-04, Loss_res: 4.718e-04, Time: 0.13
# It: 1270, Loss: 1.956e-03, Loss_u: 9.264e-04, Loss_Scs: 5.037e-04, Loss_res: 5.263e-04, Time: 0.13
# It: 1280, Loss: 1.284e-03, Loss_u: 8.350e-04, Loss_Scs: 5.896e-05, Loss_res: 3.902e-04, Time: 0.14
# It: 1290, Loss: 1.856e-03, Loss_u: 1.016e-03, Loss_Scs: 5.559e-04, Loss_res: 2.839e-04, Time: 0.13
# It: 1300, Loss: 2.008e-03, Loss_u: 1.108e-03, Loss_Scs: 2.642e-04, Loss_res: 6.356e-04, Time: 0.14
# It: 1310, Loss: 1.775e-03, Loss_u: 9.614e-04, Loss_Scs: 1.346e-04, Loss_res: 6.791e-04, Time: 0.13
# It: 1320, Loss: 2.968e-03, Loss_u: 9.322e-04, Loss_Scs: 1.484e-03, Loss_res: 5.519e-04, Time: 0.14
# It: 1330, Loss: 1.285e-03, Loss_u: 8.980e-04, Loss_Scs: 1.459e-04, Loss_res: 2.411e-04, Time: 0.13
# It: 1340, Loss: 1.807e-03, Loss_u: 1.076e-03, Loss_Scs: 1.480e-04, Loss_res: 5.836e-04, Time: 0.15
# It: 1350, Loss: 1.834e-03, Loss_u: 1.022e-03, Loss_Scs: 4.247e-04, Loss_res: 3.877e-04, Time: 0.13
# It: 1360, Loss: 1.455e-03, Loss_u: 8.155e-04, Loss_Scs: 3.420e-04, Loss_res: 2.974e-04, Time: 0.08
# It: 1370, Loss: 1.778e-03, Loss_u: 9.971e-04, Loss_Scs: 5.039e-04, Loss_res: 2.769e-04, Time: 0.07
# It: 1380, Loss: 1.556e-03, Loss_u: 9.375e-04, Loss_Scs: 3.419e-04, Loss_res: 2.765e-04, Time: 0.07
# It: 1390, Loss: 1.410e-03, Loss_u: 9.100e-04, Loss_Scs: 1.033e-04, Loss_res: 3.971e-04, Time: 0.07
# It: 1400, Loss: 2.310e-03, Loss_u: 7.638e-04, Loss_Scs: 1.267e-03, Loss_res: 2.798e-04, Time: 0.08
# It: 1410, Loss: 1.516e-03, Loss_u: 7.355e-04, Loss_Scs: 5.799e-04, Loss_res: 2.004e-04, Time: 0.07
# It: 1420, Loss: 1.498e-03, Loss_u: 6.357e-04, Loss_Scs: 6.150e-04, Loss_res: 2.477e-04, Time: 0.07
# It: 1430, Loss: 1.345e-03, Loss_u: 9.134e-04, Loss_Scs: 1.799e-04, Loss_res: 2.516e-04, Time: 0.09
# It: 1440, Loss: 1.301e-03, Loss_u: 9.069e-04, Loss_Scs: 7.634e-05, Loss_res: 3.179e-04, Time: 0.07
# It: 1450, Loss: 8.389e-04, Loss_u: 6.653e-04, Loss_Scs: 5.710e-05, Loss_res: 1.165e-04, Time: 0.08
# It: 1460, Loss: 9.273e-04, Loss_u: 6.252e-04, Loss_Scs: 7.585e-05, Loss_res: 2.262e-04, Time: 0.08
# It: 1470, Loss: 9.562e-04, Loss_u: 6.203e-04, Loss_Scs: 1.268e-04, Loss_res: 2.091e-04, Time: 0.07
# It: 1480, Loss: 1.260e-03, Loss_u: 7.276e-04, Loss_Scs: 9.040e-05, Loss_res: 4.421e-04, Time: 0.07
# It: 1490, Loss: 1.023e-03, Loss_u: 7.384e-04, Loss_Scs: 6.969e-05, Loss_res: 2.152e-04, Time: 0.07
# It: 1500, Loss: 1.224e-03, Loss_u: 6.354e-04, Loss_Scs: 4.478e-04, Loss_res: 1.409e-04, Time: 0.07
# It: 1510, Loss: 1.225e-03, Loss_u: 7.605e-04, Loss_Scs: 2.660e-04, Loss_res: 1.986e-04, Time: 0.07
# It: 1520, Loss: 7.752e-04, Loss_u: 4.302e-04, Loss_Scs: 4.328e-05, Loss_res: 3.018e-04, Time: 0.07
# It: 1530, Loss: 1.457e-03, Loss_u: 4.305e-04, Loss_Scs: 5.676e-04, Loss_res: 4.589e-04, Time: 0.07
# It: 1540, Loss: 1.045e-03, Loss_u: 7.415e-04, Loss_Scs: 1.787e-04, Loss_res: 1.244e-04, Time: 0.07
# It: 1550, Loss: 1.023e-03, Loss_u: 6.447e-04, Loss_Scs: 1.336e-04, Loss_res: 2.446e-04, Time: 0.07
# It: 1560, Loss: 9.079e-04, Loss_u: 6.276e-04, Loss_Scs: 9.284e-05, Loss_res: 1.875e-04, Time: 0.09
# It: 1570, Loss: 1.106e-03, Loss_u: 5.592e-04, Loss_Scs: 3.095e-04, Loss_res: 2.375e-04, Time: 0.07
# It: 1580, Loss: 3.437e-03, Loss_u: 6.179e-04, Loss_Scs: 2.686e-03, Loss_res: 1.324e-04, Time: 0.08
# It: 1590, Loss: 1.882e-03, Loss_u: 5.833e-04, Loss_Scs: 1.142e-03, Loss_res: 1.559e-04, Time: 0.07
# It: 1600, Loss: 1.472e-03, Loss_u: 6.400e-04, Loss_Scs: 5.891e-04, Loss_res: 2.431e-04, Time: 0.08
# It: 1610, Loss: 1.269e-03, Loss_u: 4.946e-04, Loss_Scs: 1.888e-04, Loss_res: 5.853e-04, Time: 0.07
# It: 1620, Loss: 1.168e-03, Loss_u: 5.826e-04, Loss_Scs: 5.212e-05, Loss_res: 5.333e-04, Time: 0.07
# It: 1630, Loss: 8.292e-04, Loss_u: 5.368e-04, Loss_Scs: 8.282e-05, Loss_res: 2.096e-04, Time: 0.07
# It: 1640, Loss: 1.296e-03, Loss_u: 5.562e-04, Loss_Scs: 1.896e-04, Loss_res: 5.503e-04, Time: 0.07
# It: 1650, Loss: 8.300e-04, Loss_u: 4.170e-04, Loss_Scs: 4.260e-05, Loss_res: 3.704e-04, Time: 0.08
# It: 1660, Loss: 7.394e-04, Loss_u: 5.305e-04, Loss_Scs: 3.666e-05, Loss_res: 1.722e-04, Time: 0.07
# It: 1670, Loss: 6.350e-04, Loss_u: 4.100e-04, Loss_Scs: 4.895e-05, Loss_res: 1.760e-04, Time: 0.07
# It: 1680, Loss: 1.113e-03, Loss_u: 4.405e-04, Loss_Scs: 9.746e-05, Loss_res: 5.750e-04, Time: 0.07
# It: 1690, Loss: 6.526e-04, Loss_u: 4.479e-04, Loss_Scs: 4.518e-05, Loss_res: 1.596e-04, Time: 0.09
# It: 1700, Loss: 1.002e-03, Loss_u: 5.033e-04, Loss_Scs: 1.629e-04, Loss_res: 3.361e-04, Time: 0.12
# It: 1710, Loss: 7.099e-04, Loss_u: 4.985e-04, Loss_Scs: 6.010e-05, Loss_res: 1.512e-04, Time: 0.13
# It: 1720, Loss: 8.193e-04, Loss_u: 6.405e-04, Loss_Scs: 4.596e-05, Loss_res: 1.329e-04, Time: 0.14
# It: 1730, Loss: 1.090e-03, Loss_u: 5.389e-04, Loss_Scs: 4.188e-04, Loss_res: 1.324e-04, Time: 0.13
# It: 1740, Loss: 5.293e-03, Loss_u: 7.246e-04, Loss_Scs: 4.136e-03, Loss_res: 4.321e-04, Time: 0.08
# It: 1750, Loss: 1.107e-03, Loss_u: 4.533e-04, Loss_Scs: 5.533e-04, Loss_res: 1.001e-04, Time: 0.07
# It: 1760, Loss: 7.296e-04, Loss_u: 5.020e-04, Loss_Scs: 8.091e-05, Loss_res: 1.467e-04, Time: 0.08
# It: 1770, Loss: 1.211e-03, Loss_u: 4.696e-04, Loss_Scs: 5.957e-04, Loss_res: 1.456e-04, Time: 0.07
# It: 1780, Loss: 1.142e-03, Loss_u: 4.399e-04, Loss_Scs: 2.570e-04, Loss_res: 4.451e-04, Time: 0.07
# It: 1790, Loss: 5.890e-04, Loss_u: 4.000e-04, Loss_Scs: 5.649e-05, Loss_res: 1.325e-04, Time: 0.09
# It: 1800, Loss: 6.640e-04, Loss_u: 4.767e-04, Loss_Scs: 4.867e-05, Loss_res: 1.386e-04, Time: 0.08
# It: 1810, Loss: 7.146e-04, Loss_u: 5.008e-04, Loss_Scs: 6.996e-05, Loss_res: 1.439e-04, Time: 0.07
# It: 1820, Loss: 8.375e-04, Loss_u: 4.457e-04, Loss_Scs: 1.348e-04, Loss_res: 2.571e-04, Time: 0.07
# It: 1830, Loss: 9.147e-04, Loss_u: 4.820e-04, Loss_Scs: 2.016e-04, Loss_res: 2.311e-04, Time: 0.07
# It: 1840, Loss: 6.932e-04, Loss_u: 3.963e-04, Loss_Scs: 5.293e-05, Loss_res: 2.440e-04, Time: 0.07
# It: 1850, Loss: 5.752e-04, Loss_u: 3.601e-04, Loss_Scs: 6.560e-05, Loss_res: 1.496e-04, Time: 0.07
# It: 1860, Loss: 8.657e-04, Loss_u: 4.994e-04, Loss_Scs: 5.685e-05, Loss_res: 3.095e-04, Time: 0.07
# It: 1870, Loss: 1.308e-03, Loss_u: 5.605e-04, Loss_Scs: 5.756e-04, Loss_res: 1.719e-04, Time: 0.07
# It: 1880, Loss: 2.050e-03, Loss_u: 3.628e-04, Loss_Scs: 1.232e-03, Loss_res: 4.559e-04, Time: 0.07
# It: 1890, Loss: 1.051e-03, Loss_u: 4.202e-04, Loss_Scs: 5.070e-04, Loss_res: 1.242e-04, Time: 0.07
# It: 1900, Loss: 6.993e-04, Loss_u: 3.401e-04, Loss_Scs: 2.495e-04, Loss_res: 1.097e-04, Time: 0.07
# It: 1910, Loss: 5.324e-04, Loss_u: 3.274e-04, Loss_Scs: 9.046e-05, Loss_res: 1.145e-04, Time: 0.07
# It: 1920, Loss: 6.919e-04, Loss_u: 3.038e-04, Loss_Scs: 1.424e-04, Loss_res: 2.457e-04, Time: 0.10
# It: 1930, Loss: 5.916e-04, Loss_u: 3.108e-04, Loss_Scs: 1.306e-04, Loss_res: 1.502e-04, Time: 0.07
# It: 1940, Loss: 8.429e-04, Loss_u: 4.166e-04, Loss_Scs: 2.361e-04, Loss_res: 1.902e-04, Time: 0.08
# It: 1950, Loss: 6.847e-04, Loss_u: 3.239e-04, Loss_Scs: 1.704e-04, Loss_res: 1.904e-04, Time: 0.07
# It: 1960, Loss: 6.119e-04, Loss_u: 3.470e-04, Loss_Scs: 5.955e-05, Loss_res: 2.053e-04, Time: 0.07
# It: 1970, Loss: 5.745e-04, Loss_u: 3.098e-04, Loss_Scs: 1.173e-04, Loss_res: 1.475e-04, Time: 0.08
# It: 1980, Loss: 7.002e-04, Loss_u: 4.497e-04, Loss_Scs: 6.577e-05, Loss_res: 1.847e-04, Time: 0.07
# It: 1990, Loss: 9.836e-04, Loss_u: 4.019e-04, Loss_Scs: 4.748e-04, Loss_res: 1.070e-04, Time: 0.07
# It: 2000, Loss: 5.176e-04, Loss_u: 2.760e-04, Loss_Scs: 4.148e-05, Loss_res: 2.002e-04, Time: 0.08
# It: 2010, Loss: 2.055e-03, Loss_u: 4.356e-04, Loss_Scs: 1.474e-03, Loss_res: 1.448e-04, Time: 0.07
# It: 2020, Loss: 6.714e-04, Loss_u: 2.787e-04, Loss_Scs: 1.147e-04, Loss_res: 2.780e-04, Time: 0.07
# It: 2030, Loss: 5.966e-04, Loss_u: 3.611e-04, Loss_Scs: 1.292e-04, Loss_res: 1.063e-04, Time: 0.07
# It: 2040, Loss: 7.329e-04, Loss_u: 3.746e-04, Loss_Scs: 2.167e-04, Loss_res: 1.416e-04, Time: 0.07
# It: 2050, Loss: 6.519e-04, Loss_u: 2.883e-04, Loss_Scs: 2.075e-04, Loss_res: 1.561e-04, Time: 0.10
# It: 2060, Loss: 5.094e-04, Loss_u: 2.893e-04, Loss_Scs: 1.317e-04, Loss_res: 8.834e-05, Time: 0.07
# It: 2070, Loss: 1.133e-03, Loss_u: 2.930e-04, Loss_Scs: 5.506e-04, Loss_res: 2.899e-04, Time: 0.08
# It: 2080, Loss: 8.098e-04, Loss_u: 2.984e-04, Loss_Scs: 2.726e-04, Loss_res: 2.388e-04, Time: 0.07
# It: 2090, Loss: 5.506e-04, Loss_u: 3.507e-04, Loss_Scs: 4.735e-05, Loss_res: 1.525e-04, Time: 0.07
# It: 2100, Loss: 6.194e-04, Loss_u: 2.653e-04, Loss_Scs: 2.446e-04, Loss_res: 1.096e-04, Time: 0.07
# It: 2110, Loss: 1.421e-03, Loss_u: 3.451e-04, Loss_Scs: 8.595e-04, Loss_res: 2.164e-04, Time: 0.08
# It: 2120, Loss: 5.670e-04, Loss_u: 2.264e-04, Loss_Scs: 1.264e-04, Loss_res: 2.143e-04, Time: 0.07
# It: 2130, Loss: 7.378e-04, Loss_u: 2.448e-04, Loss_Scs: 3.385e-04, Loss_res: 1.544e-04, Time: 0.07
# It: 2140, Loss: 5.026e-04, Loss_u: 2.807e-04, Loss_Scs: 7.503e-05, Loss_res: 1.469e-04, Time: 0.07
# It: 2150, Loss: 9.464e-04, Loss_u: 2.367e-04, Loss_Scs: 4.835e-04, Loss_res: 2.262e-04, Time: 0.07
# It: 2160, Loss: 5.514e-04, Loss_u: 2.050e-04, Loss_Scs: 8.260e-05, Loss_res: 2.638e-04, Time: 0.07
# It: 2170, Loss: 7.026e-04, Loss_u: 3.225e-04, Loss_Scs: 2.263e-04, Loss_res: 1.537e-04, Time: 0.08
# It: 2180, Loss: 7.640e-04, Loss_u: 2.607e-04, Loss_Scs: 3.469e-04, Loss_res: 1.565e-04, Time: 0.10
# It: 2190, Loss: 8.911e-04, Loss_u: 3.440e-04, Loss_Scs: 4.170e-04, Loss_res: 1.300e-04, Time: 0.07
# It: 2200, Loss: 1.594e-03, Loss_u: 3.471e-04, Loss_Scs: 8.777e-04, Loss_res: 3.697e-04, Time: 0.08
# It: 2210, Loss: 2.708e-03, Loss_u: 4.649e-04, Loss_Scs: 1.924e-03, Loss_res: 3.197e-04, Time: 0.07
# It: 2220, Loss: 2.582e-03, Loss_u: 3.319e-04, Loss_Scs: 2.121e-03, Loss_res: 1.298e-04, Time: 0.07
# It: 2230, Loss: 7.409e-04, Loss_u: 2.468e-04, Loss_Scs: 3.919e-04, Loss_res: 1.022e-04, Time: 0.07
# It: 2240, Loss: 4.822e-04, Loss_u: 3.254e-04, Loss_Scs: 4.546e-05, Loss_res: 1.113e-04, Time: 0.08
# It: 2250, Loss: 4.764e-04, Loss_u: 2.906e-04, Loss_Scs: 5.797e-05, Loss_res: 1.279e-04, Time: 0.07
# It: 2260, Loss: 4.673e-04, Loss_u: 2.197e-04, Loss_Scs: 4.601e-05, Loss_res: 2.016e-04, Time: 0.07
# It: 2270, Loss: 4.026e-04, Loss_u: 2.014e-04, Loss_Scs: 9.970e-05, Loss_res: 1.015e-04, Time: 0.07
# It: 2280, Loss: 3.515e-04, Loss_u: 1.531e-04, Loss_Scs: 7.219e-05, Loss_res: 1.263e-04, Time: 0.07
# It: 2290, Loss: 7.561e-04, Loss_u: 2.227e-04, Loss_Scs: 1.776e-04, Loss_res: 3.558e-04, Time: 0.08
# It: 2300, Loss: 3.479e-04, Loss_u: 1.777e-04, Loss_Scs: 6.050e-05, Loss_res: 1.098e-04, Time: 0.09
# It: 2310, Loss: 6.026e-04, Loss_u: 2.284e-04, Loss_Scs: 2.696e-04, Loss_res: 1.045e-04, Time: 0.08
# It: 2320, Loss: 5.922e-04, Loss_u: 2.108e-04, Loss_Scs: 2.801e-04, Loss_res: 1.013e-04, Time: 0.07
# It: 2330, Loss: 3.436e-04, Loss_u: 1.894e-04, Loss_Scs: 3.819e-05, Loss_res: 1.160e-04, Time: 0.07
# It: 2340, Loss: 3.441e-04, Loss_u: 1.861e-04, Loss_Scs: 6.289e-05, Loss_res: 9.513e-05, Time: 0.07
# It: 2350, Loss: 6.179e-04, Loss_u: 2.306e-04, Loss_Scs: 2.546e-04, Loss_res: 1.327e-04, Time: 0.07
# It: 2360, Loss: 4.882e-04, Loss_u: 2.014e-04, Loss_Scs: 1.886e-04, Loss_res: 9.818e-05, Time: 0.08
# It: 2370, Loss: 1.117e-03, Loss_u: 1.662e-04, Loss_Scs: 7.276e-04, Loss_res: 2.237e-04, Time: 0.08
# It: 2380, Loss: 3.301e-04, Loss_u: 2.175e-04, Loss_Scs: 4.034e-05, Loss_res: 7.233e-05, Time: 0.08
# It: 2390, Loss: 3.034e-04, Loss_u: 1.545e-04, Loss_Scs: 4.467e-05, Loss_res: 1.042e-04, Time: 0.08
# It: 2400, Loss: 5.379e-04, Loss_u: 1.788e-04, Loss_Scs: 3.724e-05, Loss_res: 3.218e-04, Time: 0.07
# It: 2410, Loss: 1.020e-03, Loss_u: 3.742e-04, Loss_Scs: 3.471e-04, Loss_res: 2.990e-04, Time: 0.08
# It: 2420, Loss: 1.601e-03, Loss_u: 2.845e-04, Loss_Scs: 1.144e-03, Loss_res: 1.725e-04, Time: 0.08
# It: 2430, Loss: 8.625e-04, Loss_u: 2.803e-04, Loss_Scs: 3.511e-04, Loss_res: 2.311e-04, Time: 0.09
# It: 2440, Loss: 7.299e-04, Loss_u: 2.175e-04, Loss_Scs: 2.413e-04, Loss_res: 2.711e-04, Time: 0.07
# It: 2450, Loss: 1.387e-03, Loss_u: 3.029e-04, Loss_Scs: 6.044e-04, Loss_res: 4.796e-04, Time: 0.08
# It: 2460, Loss: 6.019e-04, Loss_u: 1.745e-04, Loss_Scs: 3.277e-05, Loss_res: 3.946e-04, Time: 0.07
# It: 2470, Loss: 5.930e-04, Loss_u: 2.553e-04, Loss_Scs: 7.984e-05, Loss_res: 2.579e-04, Time: 0.07
# It: 2480, Loss: 9.711e-04, Loss_u: 1.741e-04, Loss_Scs: 3.267e-04, Loss_res: 4.703e-04, Time: 0.08
# It: 2490, Loss: 3.613e-04, Loss_u: 1.616e-04, Loss_Scs: 6.610e-05, Loss_res: 1.337e-04, Time: 0.07
# It: 2500, Loss: 7.955e-04, Loss_u: 1.416e-04, Loss_Scs: 3.446e-04, Loss_res: 3.093e-04, Time: 0.07
# It: 2510, Loss: 3.634e-04, Loss_u: 1.289e-04, Loss_Scs: 1.016e-04, Loss_res: 1.330e-04, Time: 0.07
# It: 2520, Loss: 5.697e-04, Loss_u: 2.390e-04, Loss_Scs: 8.872e-05, Loss_res: 2.420e-04, Time: 0.07
# It: 2530, Loss: 2.681e-04, Loss_u: 1.565e-04, Loss_Scs: 4.212e-05, Loss_res: 6.946e-05, Time: 0.07
# It: 2540, Loss: 5.481e-04, Loss_u: 1.549e-04, Loss_Scs: 7.602e-05, Loss_res: 3.172e-04, Time: 0.08
# It: 2550, Loss: 3.680e-03, Loss_u: 1.958e-04, Loss_Scs: 3.241e-03, Loss_res: 2.432e-04, Time: 0.07
# It: 2560, Loss: 7.852e-04, Loss_u: 1.536e-04, Loss_Scs: 4.332e-04, Loss_res: 1.983e-04, Time: 0.11
# It: 2570, Loss: 4.824e-04, Loss_u: 1.528e-04, Loss_Scs: 2.649e-04, Loss_res: 6.468e-05, Time: 0.12
# It: 2580, Loss: 2.659e-04, Loss_u: 1.703e-04, Loss_Scs: 2.217e-05, Loss_res: 7.348e-05, Time: 0.13
# It: 2590, Loss: 4.604e-04, Loss_u: 1.635e-04, Loss_Scs: 1.729e-04, Loss_res: 1.240e-04, Time: 0.13
# It: 2600, Loss: 3.104e-04, Loss_u: 1.412e-04, Loss_Scs: 9.524e-05, Loss_res: 7.394e-05, Time: 0.12
# It: 2610, Loss: 2.390e-04, Loss_u: 1.173e-04, Loss_Scs: 3.549e-05, Loss_res: 8.617e-05, Time: 0.13
# It: 2620, Loss: 2.611e-04, Loss_u: 1.247e-04, Loss_Scs: 5.525e-05, Loss_res: 8.117e-05, Time: 0.13
# It: 2630, Loss: 2.897e-04, Loss_u: 1.618e-04, Loss_Scs: 5.860e-05, Loss_res: 6.936e-05, Time: 0.13
# It: 2640, Loss: 7.964e-04, Loss_u: 1.395e-04, Loss_Scs: 4.821e-04, Loss_res: 1.747e-04, Time: 0.14
# It: 2650, Loss: 5.295e-04, Loss_u: 1.272e-04, Loss_Scs: 3.198e-04, Loss_res: 8.245e-05, Time: 0.13
# It: 2660, Loss: 6.326e-04, Loss_u: 1.373e-04, Loss_Scs: 1.746e-04, Loss_res: 3.207e-04, Time: 0.13
# It: 2670, Loss: 1.294e-03, Loss_u: 2.638e-04, Loss_Scs: 6.390e-04, Loss_res: 3.915e-04, Time: 0.13
# It: 2680, Loss: 1.059e-03, Loss_u: 1.577e-04, Loss_Scs: 8.073e-04, Loss_res: 9.357e-05, Time: 0.13
# It: 2690, Loss: 3.198e-04, Loss_u: 1.426e-04, Loss_Scs: 1.140e-04, Loss_res: 6.322e-05, Time: 0.13
# It: 2700, Loss: 4.931e-04, Loss_u: 1.276e-04, Loss_Scs: 2.711e-04, Loss_res: 9.442e-05, Time: 0.14
# It: 2710, Loss: 3.044e-04, Loss_u: 1.200e-04, Loss_Scs: 8.557e-05, Loss_res: 9.883e-05, Time: 0.13
# It: 2720, Loss: 5.016e-04, Loss_u: 1.890e-04, Loss_Scs: 1.931e-04, Loss_res: 1.194e-04, Time: 0.14
# It: 2730, Loss: 7.142e-04, Loss_u: 1.344e-04, Loss_Scs: 5.161e-04, Loss_res: 6.369e-05, Time: 0.12
# It: 2740, Loss: 3.609e-04, Loss_u: 1.363e-04, Loss_Scs: 3.988e-05, Loss_res: 1.847e-04, Time: 0.13
# It: 2750, Loss: 4.115e-04, Loss_u: 1.371e-04, Loss_Scs: 1.898e-04, Loss_res: 8.460e-05, Time: 0.14
# It: 2760, Loss: 2.240e-04, Loss_u: 9.313e-05, Loss_Scs: 4.810e-05, Loss_res: 8.276e-05, Time: 0.14
# It: 2770, Loss: 4.034e-04, Loss_u: 9.361e-05, Loss_Scs: 2.367e-04, Loss_res: 7.306e-05, Time: 0.13
# It: 2780, Loss: 1.793e-03, Loss_u: 3.375e-04, Loss_Scs: 9.401e-04, Loss_res: 5.152e-04, Time: 0.07
# It: 2790, Loss: 6.150e-04, Loss_u: 1.317e-04, Loss_Scs: 4.148e-04, Loss_res: 6.843e-05, Time: 0.07
# It: 2800, Loss: 2.259e-04, Loss_u: 8.324e-05, Loss_Scs: 4.200e-05, Loss_res: 1.006e-04, Time: 0.09
# It: 2810, Loss: 5.421e-04, Loss_u: 1.152e-04, Loss_Scs: 2.836e-04, Loss_res: 1.432e-04, Time: 0.07
# It: 2820, Loss: 2.292e-04, Loss_u: 9.903e-05, Loss_Scs: 5.790e-05, Loss_res: 7.229e-05, Time: 0.08
# It: 2830, Loss: 2.325e-04, Loss_u: 7.822e-05, Loss_Scs: 3.655e-05, Loss_res: 1.178e-04, Time: 0.08
# It: 2840, Loss: 2.770e-04, Loss_u: 5.986e-05, Loss_Scs: 9.147e-05, Loss_res: 1.257e-04, Time: 0.07
# It: 2850, Loss: 4.355e-04, Loss_u: 1.257e-04, Loss_Scs: 8.476e-05, Loss_res: 2.251e-04, Time: 0.07
# It: 2860, Loss: 6.048e-04, Loss_u: 1.488e-04, Loss_Scs: 2.085e-04, Loss_res: 2.476e-04, Time: 0.07
# It: 2870, Loss: 5.429e-04, Loss_u: 1.607e-04, Loss_Scs: 1.740e-04, Loss_res: 2.082e-04, Time: 0.08
# It: 2880, Loss: 4.522e-04, Loss_u: 1.211e-04, Loss_Scs: 2.688e-04, Loss_res: 6.236e-05, Time: 0.07
# It: 2890, Loss: 4.473e-04, Loss_u: 8.712e-05, Loss_Scs: 4.707e-05, Loss_res: 3.131e-04, Time: 0.07
# It: 2900, Loss: 1.932e-04, Loss_u: 9.070e-05, Loss_Scs: 4.222e-05, Loss_res: 6.024e-05, Time: 0.07
# It: 2910, Loss: 3.858e-04, Loss_u: 8.235e-05, Loss_Scs: 1.836e-04, Loss_res: 1.198e-04, Time: 0.07
# It: 2920, Loss: 5.260e-03, Loss_u: 2.171e-04, Loss_Scs: 4.901e-03, Loss_res: 1.417e-04, Time: 0.07
# It: 2930, Loss: 1.708e-03, Loss_u: 1.057e-04, Loss_Scs: 1.439e-03, Loss_res: 1.632e-04, Time: 0.10
# It: 2940, Loss: 7.787e-04, Loss_u: 2.456e-04, Loss_Scs: 3.039e-04, Loss_res: 2.292e-04, Time: 0.07
# It: 2950, Loss: 2.689e-04, Loss_u: 9.609e-05, Loss_Scs: 3.316e-05, Loss_res: 1.397e-04, Time: 0.07
# It: 2960, Loss: 1.795e-04, Loss_u: 7.693e-05, Loss_Scs: 2.019e-05, Loss_res: 8.240e-05, Time: 0.07
# It: 2970, Loss: 1.633e-04, Loss_u: 7.521e-05, Loss_Scs: 3.953e-05, Loss_res: 4.855e-05, Time: 0.07
# It: 2980, Loss: 2.578e-04, Loss_u: 8.763e-05, Loss_Scs: 8.225e-05, Loss_res: 8.790e-05, Time: 0.08
# It: 2990, Loss: 1.989e-04, Loss_u: 8.539e-05, Loss_Scs: 2.540e-05, Loss_res: 8.808e-05, Time: 0.07
# It: 3000, Loss: 1.746e-04, Loss_u: 6.937e-05, Loss_Scs: 2.834e-05, Loss_res: 7.689e-05, Time: 0.08
# It: 3010, Loss: 2.251e-04, Loss_u: 8.126e-05, Loss_Scs: 2.667e-05, Loss_res: 1.172e-04, Time: 0.08
# It: 3020, Loss: 3.950e-04, Loss_u: 9.890e-05, Loss_Scs: 2.132e-04, Loss_res: 8.295e-05, Time: 0.07
# It: 3030, Loss: 2.044e-04, Loss_u: 6.652e-05, Loss_Scs: 5.504e-05, Loss_res: 8.289e-05, Time: 0.07
# It: 3040, Loss: 6.167e-04, Loss_u: 1.390e-04, Loss_Scs: 1.783e-04, Loss_res: 2.994e-04, Time: 0.07
# It: 3050, Loss: 7.608e-04, Loss_u: 1.084e-04, Loss_Scs: 5.781e-04, Loss_res: 7.426e-05, Time: 0.07
# It: 3060, Loss: 7.253e-04, Loss_u: 2.636e-04, Loss_Scs: 1.359e-04, Loss_res: 3.257e-04, Time: 0.09
# It: 3070, Loss: 4.981e-04, Loss_u: 1.527e-04, Loss_Scs: 9.513e-05, Loss_res: 2.502e-04, Time: 0.08
# It: 3080, Loss: 2.736e-04, Loss_u: 8.957e-05, Loss_Scs: 1.197e-04, Loss_res: 6.434e-05, Time: 0.07
# It: 3090, Loss: 5.677e-04, Loss_u: 1.105e-04, Loss_Scs: 2.079e-04, Loss_res: 2.493e-04, Time: 0.07
# It: 3100, Loss: 3.627e-04, Loss_u: 1.143e-04, Loss_Scs: 3.010e-05, Loss_res: 2.183e-04, Time: 0.07
# It: 3110, Loss: 1.636e-04, Loss_u: 4.529e-05, Loss_Scs: 4.801e-05, Loss_res: 7.033e-05, Time: 0.07
# It: 3120, Loss: 5.163e-04, Loss_u: 2.136e-04, Loss_Scs: 5.755e-05, Loss_res: 2.451e-04, Time: 0.08
# It: 3130, Loss: 2.748e-04, Loss_u: 9.913e-05, Loss_Scs: 9.035e-05, Loss_res: 8.535e-05, Time: 0.08
# It: 3140, Loss: 1.544e-04, Loss_u: 6.925e-05, Loss_Scs: 3.233e-05, Loss_res: 5.279e-05, Time: 0.07
# It: 3150, Loss: 2.937e-04, Loss_u: 6.541e-05, Loss_Scs: 1.697e-04, Loss_res: 5.862e-05, Time: 0.07
# It: 3160, Loss: 2.385e-04, Loss_u: 7.890e-05, Loss_Scs: 2.635e-05, Loss_res: 1.332e-04, Time: 0.08
# It: 3170, Loss: 1.029e-03, Loss_u: 1.417e-04, Loss_Scs: 8.073e-04, Loss_res: 8.049e-05, Time: 0.07
# It: 3180, Loss: 5.541e-04, Loss_u: 1.194e-04, Loss_Scs: 5.012e-05, Loss_res: 3.846e-04, Time: 0.07
# It: 3190, Loss: 2.905e-04, Loss_u: 7.857e-05, Loss_Scs: 1.361e-04, Loss_res: 7.583e-05, Time: 0.10
# It: 3200, Loss: 2.238e-04, Loss_u: 7.394e-05, Loss_Scs: 2.042e-05, Loss_res: 1.295e-04, Time: 0.07
# It: 3210, Loss: 2.233e-04, Loss_u: 7.463e-05, Loss_Scs: 6.349e-05, Loss_res: 8.521e-05, Time: 0.07
# It: 3220, Loss: 2.680e-04, Loss_u: 8.899e-05, Loss_Scs: 1.020e-04, Loss_res: 7.700e-05, Time: 0.08
# It: 3230, Loss: 2.121e-04, Loss_u: 8.214e-05, Loss_Scs: 5.984e-05, Loss_res: 7.010e-05, Time: 0.07
# It: 3240, Loss: 1.076e-03, Loss_u: 1.473e-04, Loss_Scs: 5.981e-04, Loss_res: 3.311e-04, Time: 0.07
# It: 3250, Loss: 7.688e-04, Loss_u: 1.062e-04, Loss_Scs: 5.331e-04, Loss_res: 1.295e-04, Time: 0.07
# It: 3260, Loss: 1.539e-04, Loss_u: 6.914e-05, Loss_Scs: 3.675e-05, Loss_res: 4.803e-05, Time: 0.07
# It: 3270, Loss: 2.167e-04, Loss_u: 6.375e-05, Loss_Scs: 3.553e-05, Loss_res: 1.174e-04, Time: 0.07
# It: 3280, Loss: 4.019e-04, Loss_u: 7.322e-05, Loss_Scs: 2.067e-04, Loss_res: 1.219e-04, Time: 0.07
# It: 3290, Loss: 3.868e-04, Loss_u: 5.540e-05, Loss_Scs: 1.773e-04, Loss_res: 1.541e-04, Time: 0.07
# It: 3300, Loss: 2.371e-04, Loss_u: 6.026e-05, Loss_Scs: 1.120e-04, Loss_res: 6.484e-05, Time: 0.07
# It: 3310, Loss: 3.429e-04, Loss_u: 1.150e-04, Loss_Scs: 8.305e-05, Loss_res: 1.449e-04, Time: 0.07
# It: 3320, Loss: 3.756e-04, Loss_u: 5.853e-05, Loss_Scs: 2.627e-04, Loss_res: 5.434e-05, Time: 0.09
# It: 3330, Loss: 2.153e-04, Loss_u: 7.353e-05, Loss_Scs: 5.499e-05, Loss_res: 8.679e-05, Time: 0.07
# It: 3340, Loss: 1.613e-04, Loss_u: 4.075e-05, Loss_Scs: 8.265e-05, Loss_res: 3.792e-05, Time: 0.07
# It: 3350, Loss: 4.491e-04, Loss_u: 4.478e-05, Loss_Scs: 3.661e-04, Loss_res: 3.824e-05, Time: 0.07
# It: 3360, Loss: 1.514e-03, Loss_u: 6.860e-05, Loss_Scs: 1.256e-03, Loss_res: 1.897e-04, Time: 0.07
# It: 3370, Loss: 1.201e-04, Loss_u: 4.264e-05, Loss_Scs: 2.240e-05, Loss_res: 5.509e-05, Time: 0.08
# It: 3380, Loss: 1.635e-04, Loss_u: 5.257e-05, Loss_Scs: 6.458e-05, Loss_res: 4.630e-05, Time: 0.07
# It: 3390, Loss: 2.216e-04, Loss_u: 8.426e-05, Loss_Scs: 7.300e-05, Loss_res: 6.430e-05, Time: 0.07
# It: 3400, Loss: 6.268e-04, Loss_u: 6.868e-05, Loss_Scs: 3.711e-04, Loss_res: 1.871e-04, Time: 0.07
# It: 3410, Loss: 5.425e-04, Loss_u: 9.804e-05, Loss_Scs: 3.346e-04, Loss_res: 1.099e-04, Time: 0.07
# It: 3420, Loss: 1.909e-04, Loss_u: 4.494e-05, Loss_Scs: 7.713e-05, Loss_res: 6.881e-05, Time: 0.07
# It: 3430, Loss: 2.695e-04, Loss_u: 8.125e-05, Loss_Scs: 5.079e-05, Loss_res: 1.375e-04, Time: 0.08
# It: 3440, Loss: 5.523e-04, Loss_u: 6.493e-05, Loss_Scs: 4.264e-04, Loss_res: 6.092e-05, Time: 0.07
# It: 3450, Loss: 5.667e-04, Loss_u: 6.786e-05, Loss_Scs: 2.712e-04, Loss_res: 2.276e-04, Time: 0.09
# It: 3460, Loss: 2.041e-04, Loss_u: 8.250e-05, Loss_Scs: 6.756e-05, Loss_res: 5.405e-05, Time: 0.07
# It: 3470, Loss: 7.138e-04, Loss_u: 1.951e-04, Loss_Scs: 2.928e-04, Loss_res: 2.259e-04, Time: 0.07
# It: 3480, Loss: 2.047e-04, Loss_u: 7.617e-05, Loss_Scs: 5.439e-05, Loss_res: 7.416e-05, Time: 0.07
# It: 3490, Loss: 3.247e-04, Loss_u: 6.796e-05, Loss_Scs: 2.135e-05, Loss_res: 2.354e-04, Time: 0.08
# It: 3500, Loss: 2.649e-04, Loss_u: 5.527e-05, Loss_Scs: 1.480e-04, Loss_res: 6.166e-05, Time: 0.07
# It: 3510, Loss: 4.883e-04, Loss_u: 1.341e-04, Loss_Scs: 1.571e-04, Loss_res: 1.971e-04, Time: 0.07
# It: 3520, Loss: 8.515e-04, Loss_u: 1.613e-04, Loss_Scs: 4.609e-04, Loss_res: 2.293e-04, Time: 0.07
# It: 3530, Loss: 2.268e-04, Loss_u: 6.521e-05, Loss_Scs: 4.275e-05, Loss_res: 1.189e-04, Time: 0.07
# It: 3540, Loss: 3.260e-04, Loss_u: 1.104e-04, Loss_Scs: 1.115e-04, Loss_res: 1.041e-04, Time: 0.07
# It: 3550, Loss: 3.741e-04, Loss_u: 3.597e-05, Loss_Scs: 2.712e-04, Loss_res: 6.688e-05, Time: 0.08
# It: 3560, Loss: 7.157e-04, Loss_u: 5.846e-05, Loss_Scs: 5.967e-04, Loss_res: 6.052e-05, Time: 0.07
# It: 3570, Loss: 2.523e-04, Loss_u: 7.161e-05, Loss_Scs: 5.435e-05, Loss_res: 1.264e-04, Time: 0.07
# It: 3580, Loss: 8.737e-04, Loss_u: 1.180e-04, Loss_Scs: 4.108e-04, Loss_res: 3.448e-04, Time: 0.09
# It: 3590, Loss: 1.172e-04, Loss_u: 4.383e-05, Loss_Scs: 2.605e-05, Loss_res: 4.730e-05, Time: 0.07
# It: 3600, Loss: 1.621e-04, Loss_u: 4.253e-05, Loss_Scs: 2.638e-05, Loss_res: 9.319e-05, Time: 0.07
# It: 3610, Loss: 2.029e-04, Loss_u: 4.354e-05, Loss_Scs: 5.700e-05, Loss_res: 1.023e-04, Time: 0.08
# It: 3620, Loss: 5.324e-04, Loss_u: 3.787e-05, Loss_Scs: 4.266e-04, Loss_res: 6.792e-05, Time: 0.07
# It: 3630, Loss: 2.485e-04, Loss_u: 9.791e-05, Loss_Scs: 1.038e-04, Loss_res: 4.677e-05, Time: 0.07
# It: 3640, Loss: 5.166e-04, Loss_u: 9.794e-05, Loss_Scs: 2.893e-04, Loss_res: 1.293e-04, Time: 0.07
# It: 3650, Loss: 3.341e-04, Loss_u: 9.426e-05, Loss_Scs: 8.631e-05, Loss_res: 1.535e-04, Time: 0.07
# It: 3660, Loss: 3.830e-04, Loss_u: 6.557e-05, Loss_Scs: 1.860e-04, Loss_res: 1.314e-04, Time: 0.07
# It: 3670, Loss: 4.608e-04, Loss_u: 4.496e-05, Loss_Scs: 3.724e-04, Loss_res: 4.335e-05, Time: 0.07
# It: 3680, Loss: 2.058e-04, Loss_u: 4.545e-05, Loss_Scs: 9.858e-05, Loss_res: 6.176e-05, Time: 0.07
# It: 3690, Loss: 1.327e-04, Loss_u: 4.354e-05, Loss_Scs: 4.859e-05, Loss_res: 4.055e-05, Time: 0.07
# It: 3700, Loss: 2.696e-04, Loss_u: 1.051e-04, Loss_Scs: 5.032e-05, Loss_res: 1.142e-04, Time: 0.07
# It: 3710, Loss: 1.510e-03, Loss_u: 9.884e-05, Loss_Scs: 1.303e-03, Loss_res: 1.085e-04, Time: 0.09
# It: 3720, Loss: 3.696e-04, Loss_u: 4.972e-05, Loss_Scs: 1.303e-04, Loss_res: 1.895e-04, Time: 0.07
# It: 3730, Loss: 4.919e-04, Loss_u: 2.799e-05, Loss_Scs: 4.302e-04, Loss_res: 3.368e-05, Time: 0.07
# It: 3740, Loss: 2.814e-04, Loss_u: 5.856e-05, Loss_Scs: 1.275e-04, Loss_res: 9.538e-05, Time: 0.08
# It: 3750, Loss: 1.144e-04, Loss_u: 4.105e-05, Loss_Scs: 2.296e-05, Loss_res: 5.041e-05, Time: 0.07
# It: 3760, Loss: 3.661e-04, Loss_u: 8.149e-05, Loss_Scs: 1.525e-04, Loss_res: 1.321e-04, Time: 0.08
# It: 3770, Loss: 8.146e-04, Loss_u: 1.190e-04, Loss_Scs: 4.045e-04, Loss_res: 2.912e-04, Time: 0.07
# It: 3780, Loss: 1.415e-04, Loss_u: 4.898e-05, Loss_Scs: 4.478e-05, Loss_res: 4.774e-05, Time: 0.07
# It: 3790, Loss: 8.266e-04, Loss_u: 7.237e-05, Loss_Scs: 6.416e-04, Loss_res: 1.126e-04, Time: 0.08
# It: 3800, Loss: 2.255e-04, Loss_u: 6.322e-05, Loss_Scs: 3.248e-05, Loss_res: 1.297e-04, Time: 0.07
# It: 3810, Loss: 1.351e-04, Loss_u: 4.116e-05, Loss_Scs: 4.156e-05, Loss_res: 5.238e-05, Time: 0.07
# It: 3820, Loss: 4.754e-04, Loss_u: 6.020e-05, Loss_Scs: 3.415e-04, Loss_res: 7.372e-05, Time: 0.07
# It: 3830, Loss: 1.104e-04, Loss_u: 3.141e-05, Loss_Scs: 1.848e-05, Loss_res: 6.048e-05, Time: 0.07
# It: 3840, Loss: 2.206e-04, Loss_u: 2.673e-05, Loss_Scs: 1.498e-04, Loss_res: 4.406e-05, Time: 0.09
# It: 3850, Loss: 1.288e-03, Loss_u: 9.864e-05, Loss_Scs: 1.061e-03, Loss_res: 1.283e-04, Time: 0.07
# It: 3860, Loss: 3.221e-04, Loss_u: 8.416e-05, Loss_Scs: 4.904e-05, Loss_res: 1.889e-04, Time: 0.08
# It: 3870, Loss: 1.912e-04, Loss_u: 4.101e-05, Loss_Scs: 1.084e-04, Loss_res: 4.184e-05, Time: 0.07
# It: 3880, Loss: 1.093e-04, Loss_u: 3.316e-05, Loss_Scs: 2.213e-05, Loss_res: 5.400e-05, Time: 0.08
# It: 3890, Loss: 1.863e-04, Loss_u: 2.786e-05, Loss_Scs: 4.792e-05, Loss_res: 1.105e-04, Time: 0.07
# It: 3900, Loss: 7.698e-04, Loss_u: 7.761e-05, Loss_Scs: 5.966e-04, Loss_res: 9.565e-05, Time: 0.07
# It: 3910, Loss: 2.388e-04, Loss_u: 5.197e-05, Loss_Scs: 1.520e-04, Loss_res: 3.482e-05, Time: 0.07
# It: 3920, Loss: 2.962e-04, Loss_u: 2.645e-05, Loss_Scs: 2.380e-04, Loss_res: 3.179e-05, Time: 0.07
# It: 3930, Loss: 2.422e-04, Loss_u: 5.352e-05, Loss_Scs: 7.277e-05, Loss_res: 1.160e-04, Time: 0.07
# It: 3940, Loss: 2.738e-04, Loss_u: 8.645e-05, Loss_Scs: 3.659e-05, Loss_res: 1.508e-04, Time: 0.07
# It: 3950, Loss: 2.138e-04, Loss_u: 6.825e-05, Loss_Scs: 3.184e-05, Loss_res: 1.137e-04, Time: 0.07
# It: 3960, Loss: 1.179e-04, Loss_u: 2.095e-05, Loss_Scs: 2.315e-05, Loss_res: 7.376e-05, Time: 0.07
# It: 3970, Loss: 9.708e-05, Loss_u: 3.367e-05, Loss_Scs: 1.935e-05, Loss_res: 4.406e-05, Time: 0.09
# It: 3980, Loss: 4.160e-04, Loss_u: 4.965e-05, Loss_Scs: 3.028e-04, Loss_res: 6.356e-05, Time: 0.07
# It: 3990, Loss: 1.774e-03, Loss_u: 6.523e-05, Loss_Scs: 1.649e-03, Loss_res: 6.009e-05, Time: 0.07
# It: 4000, Loss: 8.989e-04, Loss_u: 1.482e-04, Loss_Scs: 3.051e-04, Loss_res: 4.456e-04, Time: 0.08
# It: 4010, Loss: 4.121e-04, Loss_u: 7.115e-05, Loss_Scs: 4.942e-05, Loss_res: 2.915e-04, Time: 0.10
# It: 4020, Loss: 1.148e-04, Loss_u: 3.773e-05, Loss_Scs: 2.084e-05, Loss_res: 5.625e-05, Time: 0.13
# It: 4030, Loss: 1.805e-04, Loss_u: 5.529e-05, Loss_Scs: 4.216e-05, Loss_res: 8.310e-05, Time: 0.13
# It: 4040, Loss: 3.183e-04, Loss_u: 8.057e-05, Loss_Scs: 1.206e-04, Loss_res: 1.172e-04, Time: 0.13
# It: 4050, Loss: 9.038e-04, Loss_u: 8.535e-05, Loss_Scs: 4.552e-04, Loss_res: 3.633e-04, Time: 0.13
# It: 4060, Loss: 2.096e-04, Loss_u: 4.638e-05, Loss_Scs: 1.067e-04, Loss_res: 5.658e-05, Time: 0.14
# It: 4070, Loss: 6.868e-04, Loss_u: 1.559e-04, Loss_Scs: 1.859e-04, Loss_res: 3.451e-04, Time: 0.14
# It: 4080, Loss: 9.286e-04, Loss_u: 8.599e-05, Loss_Scs: 5.945e-04, Loss_res: 2.481e-04, Time: 0.13
# It: 4090, Loss: 2.336e-04, Loss_u: 7.669e-05, Loss_Scs: 1.068e-04, Loss_res: 5.009e-05, Time: 0.13
# It: 4100, Loss: 2.580e-04, Loss_u: 5.066e-05, Loss_Scs: 1.758e-04, Loss_res: 3.158e-05, Time: 0.13
# It: 4110, Loss: 1.136e-04, Loss_u: 2.810e-05, Loss_Scs: 5.437e-05, Loss_res: 3.118e-05, Time: 0.13
# It: 4120, Loss: 2.822e-04, Loss_u: 3.398e-05, Loss_Scs: 2.078e-04, Loss_res: 4.042e-05, Time: 0.13
# It: 4130, Loss: 1.643e-04, Loss_u: 3.181e-05, Loss_Scs: 1.450e-05, Loss_res: 1.180e-04, Time: 0.13
# It: 4140, Loss: 1.994e-04, Loss_u: 2.359e-05, Loss_Scs: 1.289e-04, Loss_res: 4.692e-05, Time: 0.14
# It: 4150, Loss: 1.084e-04, Loss_u: 2.376e-05, Loss_Scs: 5.444e-05, Loss_res: 3.017e-05, Time: 0.13
# It: 4160, Loss: 1.373e-04, Loss_u: 2.143e-05, Loss_Scs: 8.615e-05, Loss_res: 2.969e-05, Time: 0.13
# It: 4170, Loss: 1.136e-03, Loss_u: 1.361e-04, Loss_Scs: 7.664e-04, Loss_res: 2.338e-04, Time: 0.13
# It: 4180, Loss: 2.862e-04, Loss_u: 8.344e-05, Loss_Scs: 1.160e-04, Loss_res: 8.675e-05, Time: 0.13
# It: 4190, Loss: 2.089e-04, Loss_u: 3.579e-05, Loss_Scs: 5.831e-05, Loss_res: 1.148e-04, Time: 0.13
# It: 4200, Loss: 1.098e-04, Loss_u: 3.628e-05, Loss_Scs: 1.498e-05, Loss_res: 5.852e-05, Time: 0.12
# It: 4210, Loss: 6.576e-05, Loss_u: 2.000e-05, Loss_Scs: 1.602e-05, Loss_res: 2.974e-05, Time: 0.14
# It: 4220, Loss: 2.234e-04, Loss_u: 5.058e-05, Loss_Scs: 2.141e-05, Loss_res: 1.514e-04, Time: 0.13
# It: 4230, Loss: 3.007e-04, Loss_u: 3.192e-05, Loss_Scs: 2.089e-04, Loss_res: 5.984e-05, Time: 0.07
# It: 4240, Loss: 2.013e-04, Loss_u: 2.427e-05, Loss_Scs: 2.019e-05, Loss_res: 1.568e-04, Time: 0.07
# It: 4250, Loss: 1.225e-04, Loss_u: 1.688e-05, Loss_Scs: 1.905e-05, Loss_res: 8.656e-05, Time: 0.07
# It: 4260, Loss: 1.059e-04, Loss_u: 3.356e-05, Loss_Scs: 4.179e-05, Loss_res: 3.054e-05, Time: 0.07
# It: 4270, Loss: 2.473e-04, Loss_u: 6.092e-05, Loss_Scs: 1.148e-04, Loss_res: 7.150e-05, Time: 0.07
# It: 4280, Loss: 7.851e-04, Loss_u: 7.732e-05, Loss_Scs: 6.051e-04, Loss_res: 1.027e-04, Time: 0.07
# It: 4290, Loss: 4.738e-04, Loss_u: 9.856e-05, Loss_Scs: 1.457e-04, Loss_res: 2.295e-04, Time: 0.08
# It: 4300, Loss: 2.563e-04, Loss_u: 2.688e-05, Loss_Scs: 1.623e-04, Loss_res: 6.712e-05, Time: 0.07
# It: 4310, Loss: 1.048e-04, Loss_u: 2.668e-05, Loss_Scs: 3.244e-05, Loss_res: 4.573e-05, Time: 0.07
# It: 4320, Loss: 2.582e-04, Loss_u: 5.586e-05, Loss_Scs: 9.463e-05, Loss_res: 1.077e-04, Time: 0.07
# It: 4330, Loss: 1.492e-04, Loss_u: 5.415e-05, Loss_Scs: 1.844e-05, Loss_res: 7.663e-05, Time: 0.07
# It: 4340, Loss: 3.169e-04, Loss_u: 5.718e-05, Loss_Scs: 9.808e-05, Loss_res: 1.617e-04, Time: 0.10
# It: 4350, Loss: 1.928e-04, Loss_u: 4.794e-05, Loss_Scs: 1.110e-04, Loss_res: 3.382e-05, Time: 0.07
# It: 4360, Loss: 4.796e-04, Loss_u: 2.018e-05, Loss_Scs: 4.212e-04, Loss_res: 3.822e-05, Time: 0.07
# It: 4370, Loss: 4.602e-04, Loss_u: 4.793e-05, Loss_Scs: 3.623e-04, Loss_res: 4.998e-05, Time: 0.07
# It: 4380, Loss: 3.605e-04, Loss_u: 4.061e-05, Loss_Scs: 2.591e-04, Loss_res: 6.076e-05, Time: 0.07
# It: 4390, Loss: 1.473e-04, Loss_u: 5.308e-05, Loss_Scs: 6.104e-05, Loss_res: 3.314e-05, Time: 0.07
# It: 4400, Loss: 1.653e-04, Loss_u: 2.835e-05, Loss_Scs: 7.952e-05, Loss_res: 5.746e-05, Time: 0.08
# It: 4410, Loss: 7.405e-05, Loss_u: 1.531e-05, Loss_Scs: 1.516e-05, Loss_res: 4.357e-05, Time: 0.07
# It: 4420, Loss: 2.051e-04, Loss_u: 6.763e-05, Loss_Scs: 2.369e-05, Loss_res: 1.138e-04, Time: 0.07
# It: 4430, Loss: 7.962e-05, Loss_u: 2.892e-05, Loss_Scs: 1.690e-05, Loss_res: 3.380e-05, Time: 0.08
# It: 4440, Loss: 1.929e-04, Loss_u: 2.826e-05, Loss_Scs: 1.106e-04, Loss_res: 5.408e-05, Time: 0.07
# It: 4450, Loss: 1.967e-04, Loss_u: 1.625e-05, Loss_Scs: 1.435e-04, Loss_res: 3.691e-05, Time: 0.08
# It: 4460, Loss: 1.561e-04, Loss_u: 1.889e-05, Loss_Scs: 7.020e-05, Loss_res: 6.705e-05, Time: 0.07
# It: 4470, Loss: 4.808e-04, Loss_u: 8.162e-05, Loss_Scs: 2.493e-04, Loss_res: 1.499e-04, Time: 0.09
# It: 4480, Loss: 1.407e-03, Loss_u: 1.324e-04, Loss_Scs: 9.854e-04, Loss_res: 2.889e-04, Time: 0.07
# It: 4490, Loss: 4.256e-04, Loss_u: 2.405e-05, Loss_Scs: 3.692e-04, Loss_res: 3.232e-05, Time: 0.07
# It: 4500, Loss: 2.228e-04, Loss_u: 1.839e-05, Loss_Scs: 1.757e-04, Loss_res: 2.878e-05, Time: 0.07
# It: 4510, Loss: 7.862e-05, Loss_u: 1.864e-05, Loss_Scs: 1.762e-05, Loss_res: 4.236e-05, Time: 0.07
# It: 4520, Loss: 2.040e-04, Loss_u: 2.094e-05, Loss_Scs: 1.585e-04, Loss_res: 2.453e-05, Time: 0.08
# It: 4530, Loss: 4.006e-04, Loss_u: 2.308e-05, Loss_Scs: 3.051e-04, Loss_res: 7.236e-05, Time: 0.07
# It: 4540, Loss: 3.316e-04, Loss_u: 2.622e-05, Loss_Scs: 2.591e-04, Loss_res: 4.627e-05, Time: 0.07
# It: 4550, Loss: 9.717e-04, Loss_u: 6.533e-05, Loss_Scs: 8.211e-04, Loss_res: 8.521e-05, Time: 0.07
# It: 4560, Loss: 2.496e-04, Loss_u: 9.682e-05, Loss_Scs: 1.065e-04, Loss_res: 4.625e-05, Time: 0.07
# It: 4570, Loss: 4.916e-04, Loss_u: 1.373e-04, Loss_Scs: 4.874e-05, Loss_res: 3.055e-04, Time: 0.08
# It: 4580, Loss: 2.827e-04, Loss_u: 5.788e-05, Loss_Scs: 3.026e-05, Loss_res: 1.946e-04, Time: 0.07
# It: 4590, Loss: 5.168e-04, Loss_u: 1.134e-04, Loss_Scs: 2.928e-04, Loss_res: 1.106e-04, Time: 0.07
# It: 4600, Loss: 5.308e-04, Loss_u: 8.530e-05, Loss_Scs: 2.754e-04, Loss_res: 1.701e-04, Time: 0.09
# It: 4610, Loss: 3.481e-04, Loss_u: 6.113e-05, Loss_Scs: 8.308e-05, Loss_res: 2.039e-04, Time: 0.08
# It: 4620, Loss: 1.853e-04, Loss_u: 4.847e-05, Loss_Scs: 2.682e-05, Loss_res: 1.100e-04, Time: 0.07
# It: 4630, Loss: 1.536e-04, Loss_u: 4.109e-05, Loss_Scs: 3.331e-05, Loss_res: 7.924e-05, Time: 0.07
# It: 4640, Loss: 8.535e-05, Loss_u: 2.159e-05, Loss_Scs: 2.327e-05, Loss_res: 4.049e-05, Time: 0.08
# It: 4650, Loss: 2.241e-04, Loss_u: 2.598e-05, Loss_Scs: 1.405e-04, Loss_res: 5.764e-05, Time: 0.07
# It: 4660, Loss: 1.993e-04, Loss_u: 3.442e-05, Loss_Scs: 8.649e-05, Loss_res: 7.837e-05, Time: 0.07
# It: 4670, Loss: 6.299e-05, Loss_u: 1.904e-05, Loss_Scs: 1.333e-05, Loss_res: 3.063e-05, Time: 0.08
# It: 4680, Loss: 1.339e-03, Loss_u: 1.703e-04, Loss_Scs: 7.927e-04, Loss_res: 3.761e-04, Time: 0.07
# It: 4690, Loss: 4.250e-04, Loss_u: 9.809e-05, Loss_Scs: 1.479e-04, Loss_res: 1.790e-04, Time: 0.07
# It: 4700, Loss: 9.918e-05, Loss_u: 3.021e-05, Loss_Scs: 3.065e-05, Loss_res: 3.832e-05, Time: 0.08
# It: 4710, Loss: 6.913e-05, Loss_u: 2.465e-05, Loss_Scs: 1.709e-05, Loss_res: 2.740e-05, Time: 0.07
# It: 4720, Loss: 9.052e-05, Loss_u: 3.386e-05, Loss_Scs: 2.376e-05, Loss_res: 3.290e-05, Time: 0.07
# It: 4730, Loss: 1.917e-04, Loss_u: 5.572e-05, Loss_Scs: 3.313e-05, Loss_res: 1.029e-04, Time: 0.09
# It: 4740, Loss: 2.037e-04, Loss_u: 4.584e-05, Loss_Scs: 2.539e-05, Loss_res: 1.325e-04, Time: 0.07
# It: 4750, Loss: 2.071e-04, Loss_u: 3.070e-05, Loss_Scs: 5.297e-05, Loss_res: 1.235e-04, Time: 0.07
# It: 4760, Loss: 2.689e-04, Loss_u: 2.642e-05, Loss_Scs: 1.260e-04, Loss_res: 1.165e-04, Time: 0.08
# It: 4770, Loss: 1.339e-04, Loss_u: 5.213e-05, Loss_Scs: 3.751e-05, Loss_res: 4.423e-05, Time: 0.07
# It: 4780, Loss: 2.018e-04, Loss_u: 5.012e-05, Loss_Scs: 4.634e-05, Loss_res: 1.054e-04, Time: 0.07
# It: 4790, Loss: 1.112e-04, Loss_u: 3.192e-05, Loss_Scs: 5.067e-05, Loss_res: 2.864e-05, Time: 0.08
# It: 4800, Loss: 1.262e-04, Loss_u: 1.322e-05, Loss_Scs: 8.868e-05, Loss_res: 2.434e-05, Time: 0.07
# It: 4810, Loss: 5.511e-05, Loss_u: 1.456e-05, Loss_Scs: 8.208e-06, Loss_res: 3.234e-05, Time: 0.07
# It: 4820, Loss: 3.130e-04, Loss_u: 9.266e-06, Loss_Scs: 2.797e-04, Loss_res: 2.404e-05, Time: 0.08
# It: 4830, Loss: 2.570e-04, Loss_u: 9.671e-06, Loss_Scs: 2.280e-04, Loss_res: 1.931e-05, Time: 0.07
# It: 4840, Loss: 3.130e-04, Loss_u: 5.284e-05, Loss_Scs: 1.267e-04, Loss_res: 1.335e-04, Time: 0.07
# ...
# It: 38410, Loss: 2.246e-06, Loss_u: 4.667e-07, Loss_Scs: 2.010e-07, Loss_res: 1.578e-06, Time: 0.09
# It: 38420, Loss: 1.831e-06, Loss_u: 3.056e-07, Loss_Scs: 1.734e-07, Loss_res: 1.352e-06, Time: 0.07
# It: 38430, Loss: 2.601e-06, Loss_u: 5.902e-07, Loss_Scs: 2.893e-07, Loss_res: 1.722e-06, Time: 0.08
# It: 38440, Loss: 2.782e-06, Loss_u: 4.903e-07, Loss_Scs: 1.913e-07, Loss_res: 2.101e-06, Time: 0.07
# It: 38450, Loss: 1.777e-06, Loss_u: 3.820e-07, Loss_Scs: 1.831e-07, Loss_res: 1.212e-06, Time: 0.07
# It: 38460, Loss: 1.812e-06, Loss_u: 3.608e-07, Loss_Scs: 1.448e-07, Loss_res: 1.306e-06, Time: 0.08
# It: 38470, Loss: 1.662e-06, Loss_u: 2.797e-07, Loss_Scs: 1.568e-07, Loss_res: 1.226e-06, Time: 0.07
# It: 38480, Loss: 2.650e-06, Loss_u: 5.954e-07, Loss_Scs: 5.115e-07, Loss_res: 1.543e-06, Time: 0.07
# It: 38490, Loss: 1.652e-06, Loss_u: 4.464e-07, Loss_Scs: 2.347e-07, Loss_res: 9.713e-07, Time: 0.08
# It: 38500, Loss: 2.295e-06, Loss_u: 3.289e-07, Loss_Scs: 5.911e-07, Loss_res: 1.375e-06, Time: 0.07
# It: 38510, Loss: 1.647e-06, Loss_u: 3.096e-07, Loss_Scs: 1.612e-07, Loss_res: 1.176e-06, Time: 0.07
# It: 38520, Loss: 2.341e-06, Loss_u: 3.442e-07, Loss_Scs: 4.071e-07, Loss_res: 1.589e-06, Time: 0.08
# It: 38530, Loss: 1.886e-06, Loss_u: 4.085e-07, Loss_Scs: 2.154e-07, Loss_res: 1.262e-06, Time: 0.10
# It: 38540, Loss: 1.917e-06, Loss_u: 4.287e-07, Loss_Scs: 2.606e-07, Loss_res: 1.228e-06, Time: 0.08
# It: 38550, Loss: 1.959e-06, Loss_u: 3.877e-07, Loss_Scs: 1.895e-07, Loss_res: 1.382e-06, Time: 0.08
# It: 38560, Loss: 1.772e-06, Loss_u: 3.662e-07, Loss_Scs: 2.164e-07, Loss_res: 1.190e-06, Time: 0.08
# It: 38570, Loss: 2.054e-06, Loss_u: 4.170e-07, Loss_Scs: 6.206e-07, Loss_res: 1.016e-06, Time: 0.08
# It: 38580, Loss: 2.144e-06, Loss_u: 3.345e-07, Loss_Scs: 4.844e-07, Loss_res: 1.326e-06, Time: 0.08
# It: 38590, Loss: 1.847e-06, Loss_u: 3.523e-07, Loss_Scs: 1.691e-07, Loss_res: 1.325e-06, Time: 0.07
# It: 38600, Loss: 1.549e-06, Loss_u: 3.824e-07, Loss_Scs: 1.753e-07, Loss_res: 9.913e-07, Time: 0.07
# It: 38610, Loss: 1.802e-06, Loss_u: 3.135e-07, Loss_Scs: 2.049e-07, Loss_res: 1.283e-06, Time: 0.08
# It: 38620, Loss: 2.117e-06, Loss_u: 4.096e-07, Loss_Scs: 1.617e-07, Loss_res: 1.546e-06, Time: 0.08
# It: 38630, Loss: 1.930e-06, Loss_u: 3.723e-07, Loss_Scs: 2.505e-07, Loss_res: 1.308e-06, Time: 0.07
# It: 38640, Loss: 2.159e-06, Loss_u: 4.485e-07, Loss_Scs: 3.030e-07, Loss_res: 1.407e-06, Time: 0.08
# It: 38650, Loss: 2.617e-06, Loss_u: 5.185e-07, Loss_Scs: 4.813e-07, Loss_res: 1.617e-06, Time: 0.09
# It: 38660, Loss: 2.851e-06, Loss_u: 4.998e-07, Loss_Scs: 2.730e-07, Loss_res: 2.078e-06, Time: 0.07
# It: 38670, Loss: 2.453e-06, Loss_u: 5.269e-07, Loss_Scs: 4.493e-07, Loss_res: 1.476e-06, Time: 0.08
# It: 38680, Loss: 2.165e-06, Loss_u: 4.933e-07, Loss_Scs: 3.478e-07, Loss_res: 1.324e-06, Time: 0.08
# It: 38690, Loss: 2.004e-06, Loss_u: 3.759e-07, Loss_Scs: 2.600e-07, Loss_res: 1.368e-06, Time: 0.07
# It: 38700, Loss: 1.939e-06, Loss_u: 3.554e-07, Loss_Scs: 2.627e-07, Loss_res: 1.321e-06, Time: 0.08
# It: 38710, Loss: 2.130e-06, Loss_u: 4.578e-07, Loss_Scs: 2.277e-07, Loss_res: 1.444e-06, Time: 0.07
# It: 38720, Loss: 1.640e-06, Loss_u: 3.444e-07, Loss_Scs: 2.031e-07, Loss_res: 1.093e-06, Time: 0.07
# It: 38730, Loss: 1.937e-06, Loss_u: 3.774e-07, Loss_Scs: 3.656e-07, Loss_res: 1.194e-06, Time: 0.08
# It: 38740, Loss: 1.889e-06, Loss_u: 4.143e-07, Loss_Scs: 1.909e-07, Loss_res: 1.284e-06, Time: 0.08
# It: 38750, Loss: 2.782e-06, Loss_u: 4.663e-07, Loss_Scs: 1.963e-07, Loss_res: 2.120e-06, Time: 0.07
# It: 38760, Loss: 2.508e-06, Loss_u: 5.887e-07, Loss_Scs: 1.850e-07, Loss_res: 1.734e-06, Time: 0.08
# It: 38770, Loss: 2.189e-06, Loss_u: 5.374e-07, Loss_Scs: 2.060e-07, Loss_res: 1.446e-06, Time: 0.08
# It: 38780, Loss: 2.590e-06, Loss_u: 3.961e-07, Loss_Scs: 1.621e-07, Loss_res: 2.032e-06, Time: 0.09
# It: 38790, Loss: 3.602e-06, Loss_u: 3.918e-07, Loss_Scs: 1.628e-07, Loss_res: 3.048e-06, Time: 0.08
# It: 38800, Loss: 2.147e-06, Loss_u: 5.332e-07, Loss_Scs: 3.726e-07, Loss_res: 1.241e-06, Time: 0.08
# It: 38810, Loss: 2.217e-06, Loss_u: 5.476e-07, Loss_Scs: 1.815e-07, Loss_res: 1.488e-06, Time: 0.07
# It: 38820, Loss: 2.123e-06, Loss_u: 3.238e-07, Loss_Scs: 1.974e-07, Loss_res: 1.601e-06, Time: 0.09
# It: 38830, Loss: 2.340e-06, Loss_u: 2.541e-07, Loss_Scs: 4.956e-07, Loss_res: 1.591e-06, Time: 0.07
# It: 38840, Loss: 2.050e-06, Loss_u: 3.707e-07, Loss_Scs: 2.883e-07, Loss_res: 1.391e-06, Time: 0.07
# It: 38850, Loss: 2.133e-06, Loss_u: 3.570e-07, Loss_Scs: 4.596e-07, Loss_res: 1.316e-06, Time: 0.08
# It: 38860, Loss: 1.859e-06, Loss_u: 3.976e-07, Loss_Scs: 1.408e-07, Loss_res: 1.320e-06, Time: 0.07
# It: 38870, Loss: 1.855e-06, Loss_u: 3.477e-07, Loss_Scs: 2.939e-07, Loss_res: 1.214e-06, Time: 0.07
# It: 38880, Loss: 1.661e-06, Loss_u: 4.132e-07, Loss_Scs: 1.924e-07, Loss_res: 1.055e-06, Time: 0.08
# It: 38890, Loss: 1.892e-06, Loss_u: 3.473e-07, Loss_Scs: 2.431e-07, Loss_res: 1.301e-06, Time: 0.08
# It: 38900, Loss: 1.997e-06, Loss_u: 4.095e-07, Loss_Scs: 3.772e-07, Loss_res: 1.211e-06, Time: 0.09
# It: 38910, Loss: 2.083e-06, Loss_u: 3.777e-07, Loss_Scs: 2.379e-07, Loss_res: 1.467e-06, Time: 0.08
# It: 38920, Loss: 2.740e-06, Loss_u: 7.103e-07, Loss_Scs: 2.401e-07, Loss_res: 1.789e-06, Time: 0.08
# It: 38930, Loss: 2.401e-06, Loss_u: 4.556e-07, Loss_Scs: 3.289e-07, Loss_res: 1.616e-06, Time: 0.07
# It: 38940, Loss: 2.892e-06, Loss_u: 4.924e-07, Loss_Scs: 4.912e-07, Loss_res: 1.908e-06, Time: 0.08
# It: 38950, Loss: 2.012e-06, Loss_u: 3.670e-07, Loss_Scs: 3.039e-07, Loss_res: 1.341e-06, Time: 0.07
# It: 38960, Loss: 2.071e-06, Loss_u: 3.255e-07, Loss_Scs: 2.691e-07, Loss_res: 1.477e-06, Time: 0.07
# It: 38970, Loss: 1.724e-06, Loss_u: 3.741e-07, Loss_Scs: 1.576e-07, Loss_res: 1.193e-06, Time: 0.08
# It: 38980, Loss: 1.620e-06, Loss_u: 4.074e-07, Loss_Scs: 1.702e-07, Loss_res: 1.043e-06, Time: 0.08
# It: 38990, Loss: 1.490e-06, Loss_u: 3.888e-07, Loss_Scs: 1.644e-07, Loss_res: 9.372e-07, Time: 0.07
# It: 39000, Loss: 3.047e-06, Loss_u: 4.645e-07, Loss_Scs: 1.526e-07, Loss_res: 2.430e-06, Time: 0.08
# It: 39010, Loss: 5.440e-06, Loss_u: 5.425e-07, Loss_Scs: 4.702e-07, Loss_res: 4.427e-06, Time: 0.08
# It: 39020, Loss: 2.300e-06, Loss_u: 5.868e-07, Loss_Scs: 4.775e-07, Loss_res: 1.236e-06, Time: 0.07
# It: 39030, Loss: 1.806e-06, Loss_u: 5.044e-07, Loss_Scs: 1.447e-07, Loss_res: 1.156e-06, Time: 0.09
# It: 39040, Loss: 2.320e-06, Loss_u: 3.239e-07, Loss_Scs: 3.589e-07, Loss_res: 1.637e-06, Time: 0.08
# It: 39050, Loss: 2.505e-06, Loss_u: 3.676e-07, Loss_Scs: 4.373e-07, Loss_res: 1.700e-06, Time: 0.07
# It: 39060, Loss: 2.380e-06, Loss_u: 3.825e-07, Loss_Scs: 2.153e-07, Loss_res: 1.782e-06, Time: 0.08
# It: 39070, Loss: 1.836e-06, Loss_u: 3.504e-07, Loss_Scs: 1.718e-07, Loss_res: 1.313e-06, Time: 0.07
# It: 39080, Loss: 2.266e-06, Loss_u: 3.879e-07, Loss_Scs: 2.055e-07, Loss_res: 1.673e-06, Time: 0.07
# It: 39090, Loss: 2.497e-06, Loss_u: 3.888e-07, Loss_Scs: 2.576e-07, Loss_res: 1.851e-06, Time: 0.08
# It: 39100, Loss: 1.672e-06, Loss_u: 3.630e-07, Loss_Scs: 1.643e-07, Loss_res: 1.145e-06, Time: 0.08
# It: 39110, Loss: 2.119e-06, Loss_u: 5.067e-07, Loss_Scs: 4.492e-07, Loss_res: 1.163e-06, Time: 0.07
# It: 39120, Loss: 4.085e-06, Loss_u: 4.390e-07, Loss_Scs: 2.085e-07, Loss_res: 3.437e-06, Time: 0.08
# It: 39130, Loss: 2.543e-06, Loss_u: 7.034e-07, Loss_Scs: 1.831e-07, Loss_res: 1.657e-06, Time: 0.08
# It: 39140, Loss: 2.167e-06, Loss_u: 4.386e-07, Loss_Scs: 2.401e-07, Loss_res: 1.488e-06, Time: 0.07
# It: 39150, Loss: 6.423e-06, Loss_u: 4.746e-07, Loss_Scs: 2.250e-07, Loss_res: 5.723e-06, Time: 0.10
# It: 39160, Loss: 3.366e-06, Loss_u: 4.055e-07, Loss_Scs: 2.599e-07, Loss_res: 2.700e-06, Time: 0.09
# It: 39170, Loss: 2.589e-06, Loss_u: 7.086e-07, Loss_Scs: 3.636e-07, Loss_res: 1.517e-06, Time: 0.07
# It: 39180, Loss: 2.111e-06, Loss_u: 4.482e-07, Loss_Scs: 4.784e-07, Loss_res: 1.185e-06, Time: 0.08
# It: 39190, Loss: 1.966e-06, Loss_u: 3.328e-07, Loss_Scs: 3.356e-07, Loss_res: 1.297e-06, Time: 0.07
# It: 39200, Loss: 1.969e-06, Loss_u: 4.232e-07, Loss_Scs: 1.176e-07, Loss_res: 1.428e-06, Time: 0.08
# It: 39210, Loss: 2.308e-06, Loss_u: 4.354e-07, Loss_Scs: 4.181e-07, Loss_res: 1.455e-06, Time: 0.08
# It: 39220, Loss: 2.598e-06, Loss_u: 3.782e-07, Loss_Scs: 2.009e-07, Loss_res: 2.019e-06, Time: 0.08
# It: 39230, Loss: 3.774e-06, Loss_u: 4.134e-07, Loss_Scs: 2.219e-07, Loss_res: 3.138e-06, Time: 0.07
# It: 39240, Loss: 2.395e-06, Loss_u: 3.936e-07, Loss_Scs: 3.037e-07, Loss_res: 1.698e-06, Time: 0.09
# It: 39250, Loss: 3.174e-06, Loss_u: 2.731e-07, Loss_Scs: 2.544e-07, Loss_res: 2.646e-06, Time: 0.08
# It: 39260, Loss: 2.738e-06, Loss_u: 4.762e-07, Loss_Scs: 2.463e-07, Loss_res: 2.016e-06, Time: 0.08
# It: 39270, Loss: 2.098e-06, Loss_u: 4.750e-07, Loss_Scs: 1.708e-07, Loss_res: 1.452e-06, Time: 0.10
# It: 39280, Loss: 2.542e-06, Loss_u: 6.327e-07, Loss_Scs: 3.153e-07, Loss_res: 1.594e-06, Time: 0.08
# It: 39290, Loss: 1.592e-06, Loss_u: 3.849e-07, Loss_Scs: 3.834e-07, Loss_res: 8.241e-07, Time: 0.07
# It: 39300, Loss: 2.457e-06, Loss_u: 3.682e-07, Loss_Scs: 1.848e-07, Loss_res: 1.904e-06, Time: 0.08
# It: 39310, Loss: 2.117e-06, Loss_u: 5.070e-07, Loss_Scs: 2.019e-07, Loss_res: 1.408e-06, Time: 0.07
# It: 39320, Loss: 1.643e-06, Loss_u: 3.266e-07, Loss_Scs: 1.473e-07, Loss_res: 1.169e-06, Time: 0.07
# It: 39330, Loss: 1.646e-06, Loss_u: 2.671e-07, Loss_Scs: 1.675e-07, Loss_res: 1.211e-06, Time: 0.08
# It: 39340, Loss: 2.598e-06, Loss_u: 4.773e-07, Loss_Scs: 2.187e-07, Loss_res: 1.902e-06, Time: 0.07
# It: 39350, Loss: 2.300e-06, Loss_u: 5.373e-07, Loss_Scs: 2.435e-07, Loss_res: 1.519e-06, Time: 0.07
# It: 39360, Loss: 2.269e-06, Loss_u: 4.709e-07, Loss_Scs: 2.003e-07, Loss_res: 1.598e-06, Time: 0.08
# It: 39370, Loss: 2.412e-06, Loss_u: 5.180e-07, Loss_Scs: 2.423e-07, Loss_res: 1.652e-06, Time: 0.08
# It: 39380, Loss: 2.599e-06, Loss_u: 6.493e-07, Loss_Scs: 7.724e-07, Loss_res: 1.177e-06, Time: 0.07
# It: 39390, Loss: 2.283e-06, Loss_u: 3.685e-07, Loss_Scs: 3.077e-07, Loss_res: 1.607e-06, Time: 0.08
# It: 39400, Loss: 1.744e-06, Loss_u: 3.466e-07, Loss_Scs: 1.254e-07, Loss_res: 1.272e-06, Time: 0.10
# It: 39410, Loss: 2.261e-06, Loss_u: 3.324e-07, Loss_Scs: 4.291e-07, Loss_res: 1.499e-06, Time: 0.07
# It: 39420, Loss: 1.883e-06, Loss_u: 3.433e-07, Loss_Scs: 6.010e-07, Loss_res: 9.391e-07, Time: 0.08
# It: 39430, Loss: 1.733e-06, Loss_u: 4.866e-07, Loss_Scs: 3.804e-07, Loss_res: 8.659e-07, Time: 0.08
# It: 39440, Loss: 2.135e-06, Loss_u: 3.914e-07, Loss_Scs: 4.039e-07, Loss_res: 1.340e-06, Time: 0.12
# It: 39450, Loss: 1.925e-06, Loss_u: 4.424e-07, Loss_Scs: 1.778e-07, Loss_res: 1.305e-06, Time: 0.13
# It: 39460, Loss: 1.868e-06, Loss_u: 4.712e-07, Loss_Scs: 2.148e-07, Loss_res: 1.182e-06, Time: 0.13
# It: 39470, Loss: 1.562e-06, Loss_u: 3.924e-07, Loss_Scs: 2.098e-07, Loss_res: 9.594e-07, Time: 0.13
# It: 39480, Loss: 1.862e-06, Loss_u: 4.903e-07, Loss_Scs: 2.023e-07, Loss_res: 1.169e-06, Time: 0.13
# It: 39490, Loss: 6.683e-06, Loss_u: 4.465e-07, Loss_Scs: 1.527e-07, Loss_res: 6.084e-06, Time: 0.14
# It: 39500, Loss: 1.924e-06, Loss_u: 4.404e-07, Loss_Scs: 1.808e-07, Loss_res: 1.303e-06, Time: 0.13
# It: 39510, Loss: 1.979e-06, Loss_u: 6.409e-07, Loss_Scs: 1.692e-07, Loss_res: 1.169e-06, Time: 0.13
# It: 39520, Loss: 1.777e-06, Loss_u: 3.571e-07, Loss_Scs: 2.008e-07, Loss_res: 1.219e-06, Time: 0.14
# It: 39530, Loss: 1.943e-06, Loss_u: 4.040e-07, Loss_Scs: 2.815e-07, Loss_res: 1.258e-06, Time: 0.13
# It: 39540, Loss: 2.048e-06, Loss_u: 4.651e-07, Loss_Scs: 5.517e-07, Loss_res: 1.031e-06, Time: 0.14
# It: 39550, Loss: 2.107e-06, Loss_u: 3.687e-07, Loss_Scs: 3.403e-07, Loss_res: 1.398e-06, Time: 0.13
# It: 39560, Loss: 2.616e-06, Loss_u: 4.668e-07, Loss_Scs: 3.603e-07, Loss_res: 1.789e-06, Time: 0.13
# It: 39570, Loss: 1.726e-06, Loss_u: 3.636e-07, Loss_Scs: 2.115e-07, Loss_res: 1.151e-06, Time: 0.13
# It: 39580, Loss: 1.904e-06, Loss_u: 5.225e-07, Loss_Scs: 1.554e-07, Loss_res: 1.226e-06, Time: 0.14
# It: 39590, Loss: 2.770e-06, Loss_u: 3.598e-07, Loss_Scs: 2.768e-07, Loss_res: 2.134e-06, Time: 0.13
# It: 39600, Loss: 2.377e-06, Loss_u: 6.028e-07, Loss_Scs: 1.606e-07, Loss_res: 1.614e-06, Time: 0.15
# It: 39610, Loss: 1.728e-06, Loss_u: 4.116e-07, Loss_Scs: 2.289e-07, Loss_res: 1.088e-06, Time: 0.13
# It: 39620, Loss: 2.291e-06, Loss_u: 5.490e-07, Loss_Scs: 1.944e-07, Loss_res: 1.548e-06, Time: 0.15
# It: 39630, Loss: 1.914e-06, Loss_u: 3.832e-07, Loss_Scs: 2.158e-07, Loss_res: 1.315e-06, Time: 0.13
# It: 39640, Loss: 1.859e-06, Loss_u: 4.052e-07, Loss_Scs: 2.253e-07, Loss_res: 1.229e-06, Time: 0.16
# It: 39650, Loss: 1.885e-06, Loss_u: 3.727e-07, Loss_Scs: 2.019e-07, Loss_res: 1.311e-06, Time: 0.10
# It: 39660, Loss: 5.343e-06, Loss_u: 5.327e-07, Loss_Scs: 1.820e-07, Loss_res: 4.628e-06, Time: 0.07
# It: 39670, Loss: 2.636e-06, Loss_u: 6.392e-07, Loss_Scs: 5.632e-07, Loss_res: 1.434e-06, Time: 0.08
# It: 39680, Loss: 1.885e-06, Loss_u: 5.286e-07, Loss_Scs: 3.160e-07, Loss_res: 1.040e-06, Time: 0.07
# It: 39690, Loss: 1.736e-06, Loss_u: 3.645e-07, Loss_Scs: 1.741e-07, Loss_res: 1.197e-06, Time: 0.08
# It: 39700, Loss: 2.116e-06, Loss_u: 4.381e-07, Loss_Scs: 2.560e-07, Loss_res: 1.422e-06, Time: 0.08
# It: 39710, Loss: 2.408e-06, Loss_u: 5.205e-07, Loss_Scs: 2.624e-07, Loss_res: 1.625e-06, Time: 0.07
# It: 39720, Loss: 1.830e-06, Loss_u: 5.138e-07, Loss_Scs: 1.424e-07, Loss_res: 1.173e-06, Time: 0.08
# It: 39730, Loss: 1.864e-06, Loss_u: 4.487e-07, Loss_Scs: 1.597e-07, Loss_res: 1.255e-06, Time: 0.08
# It: 39740, Loss: 1.868e-06, Loss_u: 4.287e-07, Loss_Scs: 2.170e-07, Loss_res: 1.222e-06, Time: 0.07
# It: 39750, Loss: 2.347e-06, Loss_u: 4.032e-07, Loss_Scs: 2.135e-07, Loss_res: 1.730e-06, Time: 0.08
# It: 39760, Loss: 1.815e-06, Loss_u: 3.618e-07, Loss_Scs: 3.205e-07, Loss_res: 1.133e-06, Time: 0.10
# It: 39770, Loss: 2.757e-06, Loss_u: 5.631e-07, Loss_Scs: 5.006e-07, Loss_res: 1.693e-06, Time: 0.07
# It: 39780, Loss: 2.010e-06, Loss_u: 4.104e-07, Loss_Scs: 3.855e-07, Loss_res: 1.214e-06, Time: 0.08
# It: 39790, Loss: 1.602e-06, Loss_u: 3.422e-07, Loss_Scs: 3.446e-07, Loss_res: 9.151e-07, Time: 0.09
# It: 39800, Loss: 1.658e-06, Loss_u: 3.170e-07, Loss_Scs: 1.736e-07, Loss_res: 1.167e-06, Time: 0.08
# It: 39810, Loss: 1.740e-06, Loss_u: 3.433e-07, Loss_Scs: 1.738e-07, Loss_res: 1.223e-06, Time: 0.07
# It: 39820, Loss: 1.912e-06, Loss_u: 5.609e-07, Loss_Scs: 2.324e-07, Loss_res: 1.118e-06, Time: 0.08
# It: 39830, Loss: 2.182e-06, Loss_u: 4.255e-07, Loss_Scs: 2.632e-07, Loss_res: 1.493e-06, Time: 0.07
# It: 39840, Loss: 1.935e-06, Loss_u: 3.779e-07, Loss_Scs: 2.366e-07, Loss_res: 1.321e-06, Time: 0.08
# It: 39850, Loss: 1.904e-06, Loss_u: 4.201e-07, Loss_Scs: 2.566e-07, Loss_res: 1.227e-06, Time: 0.08
# It: 39860, Loss: 2.034e-06, Loss_u: 5.074e-07, Loss_Scs: 2.461e-07, Loss_res: 1.281e-06, Time: 0.07
# It: 39870, Loss: 2.221e-06, Loss_u: 4.219e-07, Loss_Scs: 2.837e-07, Loss_res: 1.516e-06, Time: 0.07
# It: 39880, Loss: 1.790e-06, Loss_u: 3.898e-07, Loss_Scs: 2.201e-07, Loss_res: 1.180e-06, Time: 0.08
# It: 39890, Loss: 2.329e-06, Loss_u: 3.708e-07, Loss_Scs: 1.246e-07, Loss_res: 1.834e-06, Time: 0.09
# It: 39900, Loss: 2.173e-06, Loss_u: 4.583e-07, Loss_Scs: 2.465e-07, Loss_res: 1.468e-06, Time: 0.08
# It: 39910, Loss: 2.120e-06, Loss_u: 6.692e-07, Loss_Scs: 2.562e-07, Loss_res: 1.194e-06, Time: 0.08
# It: 39920, Loss: 2.163e-06, Loss_u: 3.973e-07, Loss_Scs: 2.620e-07, Loss_res: 1.503e-06, Time: 0.08
# It: 39930, Loss: 2.513e-06, Loss_u: 3.610e-07, Loss_Scs: 2.304e-07, Loss_res: 1.922e-06, Time: 0.08
# It: 39940, Loss: 1.461e-06, Loss_u: 3.573e-07, Loss_Scs: 2.423e-07, Loss_res: 8.610e-07, Time: 0.08
# It: 39950, Loss: 1.575e-06, Loss_u: 3.100e-07, Loss_Scs: 1.994e-07, Loss_res: 1.065e-06, Time: 0.07
# It: 39960, Loss: 1.733e-06, Loss_u: 4.437e-07, Loss_Scs: 1.724e-07, Loss_res: 1.117e-06, Time: 0.08
# It: 39970, Loss: 2.617e-06, Loss_u: 4.068e-07, Loss_Scs: 2.034e-07, Loss_res: 2.007e-06, Time: 0.08
# It: 39980, Loss: 1.641e-06, Loss_u: 4.449e-07, Loss_Scs: 2.150e-07, Loss_res: 9.812e-07, Time: 0.07
# It: 39990, Loss: 1.946e-06, Loss_u: 5.276e-07, Loss_Scs: 2.922e-07, Loss_res: 1.126e-06, Time: 0.07
# Relative L2 error_u: 4.29e-03
# Relative L2 error_s: 6.71e-04

# %%
model.loss_total_log[-1]
# Out:
# np.float32(1.9458785e-06)

# %%
fig = plt.figure(figsize=(12, 8))
iterations = np.arange(0, len(model.loss_total_log)) * 10  # Every 10 iterations

# Subplot 1
plt.subplot(2, 2, 1)
plt.semilogy(iterations, model.loss_total_log)
plt.xlabel('Iterations')
plt.ylabel('Total Loss')
plt.title('a) Total Loss History')
plt.grid(True)

# Subplot 2
plt.subplot(2, 2, 2)
plt.semilogy(iterations, model.loss_u_log)
plt.xlabel('Iterations')
plt.ylabel('u Loss')
plt.title('b) Boundary & Initial Condition Loss')
plt.grid(True)

# Subplot 3
plt.subplot(2, 2, 3)
plt.semilogy(iterations, model.loss_Scs_log)
plt.xlabel('Iterations')
plt.ylabel('Stefan Condition Loss')
plt.title('c) Stefan Condition Loss')
plt.grid(True)

# Subplot 4
plt.subplot(2, 2, 4)
plt.semilogy(iterations, model.loss_res_log)
plt.xlabel('Iterations')
plt.ylabel('Residual Loss')
plt.title('d) PDE Residual Loss')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
    U_star = griddata(X_star, u_star.flatten(), (X, T), method='cubic')
    U_pred = griddata(X_star, u_pred.flatten(), (X, T), method='cubic')

    t = np.linspace(0, 1, 100)[:, None]
    x = np.zeros_like(t)
    x_star = np.concatenate((x, t), axis=1)
    s_star = s(x_star)
    s_pred = model.predict_s(x_star)
    error_s = np.abs(s_star - s_pred)

    # Plot for solution u
    fig_1 = plt.figure(1, figsize=(18, 5))
    plt.subplot(1, 3, 1)
    plt.plot(s_star, t, color='black', linewidth=2)
    plt.pcolor(X, T, U_star, cmap='jet')
    plt.colorbar()
    plt.xlabel(r'$x$')
    plt.ylabel(r'$t$')
    plt.title('a) Exact $u(x,t)$')

    plt.subplot(1, 3, 2)
    plt.pcolor(X, T, U_pred, cmap='jet')
    plt.plot(s_pred, t, color='black', linewidth=2)
    plt.colorbar()
    plt.xlabel(r'$x$')
    plt.ylabel(r'$t$')
    plt.title('b) Predicted $u(x,t)$')

    plt.subplot(1, 3, 3)
    plt.pcolor(X, T, np.abs(U_star - U_pred), cmap='jet')
    plt.colorbar(format='%.0e')
    plt.xlabel(r'$x$')
    plt.ylabel(r'$t$')
    plt.title('c) Absolute Error')

    plt.tight_layout()
    plt.show()

    # Plot for solution s
    fig_2 = plt.figure(2, figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(t, s_star, label='Exact')
    plt.plot(t, s_pred, '--', label='Predicted')
    plt.xlabel(r'$t$')
    plt.ylabel(r'$s(t)$')
    plt.title('a) Moving Boundary')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(t, error_s)
    plt.xlabel(r'$t$')
    plt.ylabel(r'Point-wise Error')
    plt.title('b) Absolute Error')
    plt.yscale('log')

    plt.tight_layout()
    plt.show()
